# %%
#ADVENTURE

import time
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np
import re

# Function to convert raw votes(eg: 2k) to integer(eg: 2000)
def parse_votes(text):
    if not text:
        return 0
    text = text.strip("()").replace(",", "").upper()
    match = re.match(r"([\d\.]+)([KM]?)", text)
    if not match:
        return 0
    number, suffix = match.groups()
    number = float(number)
    if suffix == "K":
        return int(number * 1_000)
    elif suffix == "M":
        return int(number * 1_000_000)
    else:
        return int(number)
# Convert duration string(eg: 1h 50m) to minutes of integer datatype
def duration_to_minutes(duration_str):
    hours = minutes = 0
    if 'h' in duration_str:
        h_match = re.search(r'(\d+)\s*h', duration_str)
        if h_match:
            hours = int(h_match.group(1))
    if 'm' in duration_str:
        m_match = re.search(r'(\d+)\s*m', duration_str)
        if m_match:
            minutes = int(m_match.group(1))
    return hours * 60 + minutes

# Setup WebDriver
driver = webdriver.Chrome()
driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=adventure')
time.sleep(5)

# Click more button several times to display all the movies on the IMDb search results page
for _ in range(12):
    try:
        load_more = driver.find_element(By.XPATH, "//span[contains(text(),'more')]")
        driver.execute_script("arguments[0].click();", load_more)
        time.sleep(2.5)
    except:
        break

# Data collection
movie_details = {
    'movie_names': [],
    'ratings': [],
    'voting_counts': [],
    'duration_minutes': []
}
# Finds all movie blocks on the IMDb search results page
movie_blocks = driver.find_elements(By.CSS_SELECTOR, "li[class='ipc-metadata-list-summary-item']")

for block in movie_blocks:
# Title
    title = block.find_element(By.CSS_SELECTOR, 'h3').text.split('. ', 1)[-1].strip()
# Duration
    duration_str = np.nan
    spans = block.find_elements(By.TAG_NAME, "span")
    for span in spans:
        text = span.text.strip()
        if ('h' in text or 'm' in text) and any(char.isdigit() for char in text):
            duration_str = text
            break
    if isinstance(duration_str, str):
        duration_minutes = duration_to_minutes(duration_str)
    else:
        duration_minutes = np.nan
# Ratings
    try:
        rating = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--rating']").text.strip()
    except:
        rating = np.nan
# Votes
    try:
        vote_element = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--voteCount']")
        raw_votes_text = vote_element.text.strip() 
        votes = parse_votes(raw_votes_text)
    except:
        votes = 0

# Store movie data and print it
    movie_details['movie_names'].append(title)
    movie_details['ratings'].append(rating)
    movie_details['voting_counts'].append(votes)
    movie_details['duration_minutes'].append(duration_minutes)
    print(f"{title} | Rating: {rating} | Votes: {votes} | Duration: {duration_minutes}")
    
print("Total movies scraped:", len(movie_details['movie_names']))

# %%
# Data cleaning

import pandas as pd

adventure = pd.DataFrame(movie_details)
# Adds a new column named "genre" and sets every row's value to "adventure"
adventure['genre'] = "adventure"
# Checks for missing values (NaNs) in each column.
adventure.isna().sum()
# Converts the 'ratings' column to numeric (float) values.
adventure['ratings'] = pd.to_numeric(adventure['ratings'])
# Fills missing values
adventure = adventure.fillna(value={
                'ratings':float(adventure['ratings'].mean()),
                'duration_minutes':int(adventure['duration_minutes'].mean())
                })
# Makes sure the duration_minutes column is of integer type (not float) — because duration is a whole number
adventure['duration_minutes'] = adventure['duration_minutes'].astype(int)
# Prints a summary of the DataFrame:
adventure.info()
# Saves the cleaned DataFrame to a CSV file
adventure.to_csv("adventure.csv")

# %%
#Animation

import time
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np
import re

# Function to convert raw votes(eg: 2k) to integer(eg: 2000)
def parse_votes(text):
    if not text:
        return 0
    text = text.strip("()").replace(",", "").upper()
    match = re.match(r"([\d\.]+)([KM]?)", text)
    if not match:
        return 0
    number, suffix = match.groups()
    number = float(number)
    if suffix == "K":
        return int(number * 1_000)
    elif suffix == "M":
        return int(number * 1_000_000)
    else:
        return int(number)
# Convert duration string(eg: 1h 50m) to minutes of integer datatype
def duration_to_minutes(duration_str):
    hours = minutes = 0
    if 'h' in duration_str:
        h_match = re.search(r'(\d+)\s*h', duration_str)
        if h_match:
            hours = int(h_match.group(1))
    if 'm' in duration_str:
        m_match = re.search(r'(\d+)\s*m', duration_str)
        if m_match:
            minutes = int(m_match.group(1))
    return hours * 60 + minutes

# Setup WebDriver
driver = webdriver.Chrome()
driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=animation')
time.sleep(5)

# Click more button several times to display all the movies on the IMDb search results page
for _ in range(8):
    try:
        load_more = driver.find_element(By.XPATH, "//span[contains(text(),'more')]")
        driver.execute_script("arguments[0].click();", load_more)
        time.sleep(2.5)
    except:
        break
# Data collection
movie_details = {
    'movie_names': [],
    'ratings': [],
    'voting_counts': [],
    'duration_minutes': []
}
# Finds all movie blocks on the IMDb search results page
movie_blocks = driver.find_elements(By.CSS_SELECTOR, "li[class='ipc-metadata-list-summary-item']")

for block in movie_blocks:
# Title
    title = block.find_element(By.CSS_SELECTOR, 'h3').text.split('. ', 1)[-1].strip()

# Duration
    duration_str = np.nan
    spans = block.find_elements(By.TAG_NAME, "span")
    for span in spans:
        text = span.text.strip()
        if ('h' in text or 'm' in text) and any(char.isdigit() for char in text):
            duration_str = text
            break
    if isinstance(duration_str, str):
        duration_minutes = duration_to_minutes(duration_str)
    else:
        duration_minutes = np.nan
# Ratings 
    try:
        rating = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--rating']").text.strip()
    except:
        rating = np.nan
# Votes
    try:
        vote_element = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--voteCount']")
        raw_votes_text = vote_element.text.strip()  # e.g. "246K"
        votes = parse_votes(raw_votes_text)
    except:
        votes = 0
# Store movie data and print it
    movie_details['movie_names'].append(title)
    movie_details['ratings'].append(rating)
    movie_details['voting_counts'].append(votes)
    movie_details['duration_minutes'].append(duration_minutes)
    
    print(f"{title} | Rating: {rating} | Votes: {votes} | Duration: {duration_minutes}")

print("Total movies scraped:", len(movie_details['movie_names']))

# %%
# Data cleaning

import pandas as pd

animation= pd.DataFrame(movie_details)
# Adds a new column named "genre" and sets every row's value to "animation"
animation['genre'] = "animation"
# Checks for missing values (NaNs) in each column.
animation.isna().sum()
# Converts the 'ratings' column to numeric (float) values.
animation['ratings'] = pd.to_numeric(animation['ratings'])
# Fills missing values
animation= animation.fillna(value={
                'ratings':float(animation['ratings'].mean()),
                'duration_minutes':int(animation['duration_minutes'].mean())
                })
# Makes sure the duration_minutes column is of integer type (not float) — because duration is a whole number
animation['duration_minutes'] = animation['duration_minutes'].astype(int)
# Prints a summary of the DataFrame:
animation.info()
# Saves the cleaned DataFrame to a CSV file
animation.to_csv("animation.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   movie_names       420 non-null    object
#  1   ratings           420 non-null    float64
#  2   voting_counts     420 non-null    int64
#  3   duration_minutes  420 non-null    int64
#  4   genre             420 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 16.5+ KB

# %%
#Biography

import time
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np
import re

# Function to convert raw votes(eg: 2k) to integer(eg: 2000)
def parse_votes(text):
    if not text:
        return 0
    text = text.strip("()").replace(",", "").upper()
    match = re.match(r"([\d\.]+)([KM]?)", text)
    if not match:
        return 0
    number, suffix = match.groups()
    number = float(number)
    if suffix == "K":
        return int(number * 1_000)
    elif suffix == "M":
        return int(number * 1_000_000)
    else:
        return int(number)
    
# Convert duration string(eg: 1h 50m) to minutes of integer datatype
def duration_to_minutes(duration_str):
    hours = minutes = 0
    if 'h' in duration_str:
        h_match = re.search(r'(\d+)\s*h', duration_str)
        if h_match:
            hours = int(h_match.group(1))
    if 'm' in duration_str:
        m_match = re.search(r'(\d+)\s*m', duration_str)
        if m_match:
            minutes = int(m_match.group(1))
    return hours * 60 + minutes

# Setup WebDriver
driver = webdriver.Chrome()
driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=biography')
time.sleep(5)

# Click more button several times to display all the movies on the IMDb search results page
for _ in range(9):
    try:
        load_more = driver.find_element(By.XPATH, "//span[contains(text(),'more')]")
        driver.execute_script("arguments[0].click();", load_more)
        time.sleep(2.5)
    except:
        break

# Data collection
movie_details = {
    'movie_names': [],
    'ratings': [],
    'voting_counts': [],
    'duration_minutes': []
}
# Finds all movie blocks on the IMDb search results page
movie_blocks = driver.find_elements(By.CSS_SELECTOR, "li[class='ipc-metadata-list-summary-item']")

for block in movie_blocks:
# Title
    title = block.find_element(By.CSS_SELECTOR, 'h3').text.split('. ', 1)[-1].strip()
# Duration
    duration_str = np.nan
    spans = block.find_elements(By.TAG_NAME, "span")
    for span in spans:
        text = span.text.strip()
        if ('h' in text or 'm' in text) and any(char.isdigit() for char in text):
            duration_str = text
            break
    if isinstance(duration_str, str):
        duration_minutes = duration_to_minutes(duration_str)
    else:
        duration_minutes = np.nan
# Ratings
    try:
        rating = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--rating']").text.strip()
    except:
        rating = np.nan
# Votes
    try:
        vote_element = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--voteCount']")
        raw_votes_text = vote_element.text.strip()  # e.g. "246K"
        votes = parse_votes(raw_votes_text)
    except:
        votes = 0
# Store movie data and print it
    movie_details['movie_names'].append(title)
    movie_details['ratings'].append(rating)
    movie_details['voting_counts'].append(votes)
    movie_details['duration_minutes'].append(duration_minutes)

    print(f"{title} | Rating: {rating} | Votes: {votes} | Duration: {duration_minutes}")

print("Total movies scraped:", len(movie_details['movie_names']))
# Out:
# A Complete Unknown | Rating: 7.4 | Votes: 88000 | Duration: 141
# I'm Still Here | Rating: 8.2 | Votes: 111000 | Duration: 137
# Saturday Night | Rating: 6.9 | Votes: 32000 | Duration: 109
# The Apprentice | Rating: 7.1 | Votes: 59000 | Duration: 122
# Better Man | Rating: 7.6 | Votes: 30000 | Duration: 135
# Queer | Rating: 6.4 | Votes: 23000 | Duration: 137
# Queen of the Ring | Rating: 6.4 | Votes: 1900 | Duration: 129
# Maria | Rating: 6.4 | Votes: 20000 | Duration: 124
# Reagan | Rating: 6.1 | Votes: 11000 | Duration: 141
# De erfenis van Els Borst | Rating: nan | Votes: 0 | Duration: nan
# Señor Jazz, la película de Carlos Inzillo | Rating: nan | Votes: 0 | Duration: 82
# Mi última Gran Montaña | Rating: nan | Votes: 0 | Duration: nan
# Gaston - Last Clown Standing | Rating: nan | Votes: 0 | Duration: 90
# Hamzeh Kassab | Rating: nan | Votes: 0 | Duration: nan
# Ouka Leele. El viaje de una estrella | Rating: nan | Votes: 0 | Duration: 60
# On Air | Rating: nan | Votes: 0 | Duration: nan
# Colbert: All Students Can Learn | Rating: nan | Votes: 0 | Duration: nan
# Norma: rosso sangue | Rating: nan | Votes: 0 | Duration: nan
# Doris Soffel - Mezzosopran Ein Leben im Labyrinth | Rating: nan | Votes: 0 | Duration: 59
# Antonio Mairena, la raiz del cante | Rating: nan | Votes: 0 | Duration: nan
# Sefi | Rating: nan | Votes: 0 | Duration: 58
# Alzheimer mezhdu baba i men | Rating: nan | Votes: 0 | Duration: 51

# %%
# Data cleaning
import pandas as pd

biography= pd.DataFrame(movie_details)
# Adds a new column named "genre" and sets every row's value to "biography"
biography['genre'] = "biography"
# Checks for missing values (NaNs) in each column.
biography.isna().sum()
# Converts the 'ratings' column to numeric (float) values.
biography['ratings'] = pd.to_numeric(biography['ratings'])
# Fills missing values
biography= biography.fillna(value={
                'ratings':float(biography['ratings'].mean()),
                'duration_minutes':int(biography['duration_minutes'].mean())
                })
# Makes sure the duration_minutes column is of integer type (not float) — because duration is a whole number
biography['duration_minutes'] = biography['duration_minutes'].astype(int)
# Prints a summary of the DataFrame:
biography.info()
# Saves the cleaned DataFrame to a CSV file
biography.to_csv("biography.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   movie_names       483 non-null    object
#  1   ratings           483 non-null    float64
#  2   voting_counts     483 non-null    int64
#  3   duration_minutes  483 non-null    int64
#  4   genre             483 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 19.0+ KB

# %%
#History

import time
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np
import re
# Function to convert raw votes(eg: 2k) to integer(eg: 2000
def parse_votes(text):
    if not text:
        return 0
    text = text.strip("()").replace(",", "").upper()
    match = re.match(r"([\d\.]+)([KM]?)", text)
    if not match:
        return 0
    number, suffix = match.groups()
    number = float(number)
    if suffix == "K":
        return int(number * 1_000)
    elif suffix == "M":
        return int(number * 1_000_000)
    else:
        return int(number)
# Convert duration string(eg: 1h 50m) to minutes of integer datatype
def duration_to_minutes(duration_str):
    hours = minutes = 0
    if 'h' in duration_str:
        h_match = re.search(r'(\d+)\s*h', duration_str)
        if h_match:
            hours = int(h_match.group(1))
    if 'm' in duration_str:
        m_match = re.search(r'(\d+)\s*m', duration_str)
        if m_match:
            minutes = int(m_match.group(1))
    return hours * 60 + minutes

# Setup WebDriver
driver = webdriver.Chrome()
driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=history')
time.sleep(5)

# Click more button several times to display all the movies on the IMDb search results page
for _ in range(6):
    try:
        load_more = driver.find_element(By.XPATH, "//span[contains(text(),'more')]")
        driver.execute_script("arguments[0].click();", load_more)
        time.sleep(2.5)
    except:
        break

# Data collection
movie_details = {
    'movie_names': [],
    'ratings': [],
    'voting_counts': [],
    'duration_minutes': []
}
# Finds all movie blocks on the IMDb search results page
movie_blocks = driver.find_elements(By.CSS_SELECTOR, "li[class='ipc-metadata-list-summary-item']")

for block in movie_blocks:
# Title
    title = block.find_element(By.CSS_SELECTOR, 'h3').text.split('. ', 1)[-1].strip()
# Duration
    duration_str = np.nan
    spans = block.find_elements(By.TAG_NAME, "span")
    for span in spans:
        text = span.text.strip()
        if ('h' in text or 'm' in text) and any(char.isdigit() for char in text):
            duration_str = text
            break
    if isinstance(duration_str, str):
        duration_minutes = duration_to_minutes(duration_str)
    else:
        duration_minutes = np.nan
# Ratings
    try:
        rating = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--rating']").text.strip()
    except:
        rating = np.nan
# Votes
    try:
        vote_element = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--voteCount']")
        raw_votes_text = vote_element.text.strip()  # e.g. "246K"
        votes = parse_votes(raw_votes_text)
    except:
        votes = 0
# Store movie data and print it
    movie_details['movie_names'].append(title)
    movie_details['ratings'].append(rating)
    movie_details['voting_counts'].append(votes)
    movie_details['duration_minutes'].append(duration_minutes)

    print(f"{title} | Rating: {rating} | Votes: {votes} | Duration: {duration_minutes}")

print("Total movies scraped:", len(movie_details['movie_names']))
# Out:
# Small Things Like These | Rating: 6.7 | Votes: 26000 | Duration: 98
# I'm Still Here | Rating: 8.2 | Votes: 111000 | Duration: 137
# Saturday Night | Rating: 6.9 | Votes: 32000 | Duration: 109
# The Apprentice | Rating: 7.1 | Votes: 59000 | Duration: 122
# September 5 | Rating: 7.1 | Votes: 26000 | Duration: 95
# Queer | Rating: 6.4 | Votes: 23000 | Duration: 137
# The Return | Rating: 6.2 | Votes: 9800 | Duration: 116
# The Six Triple Eight | Rating: 6.7 | Votes: 27000 | Duration: 127
# The Girl with the Needle | Rating: 7.5 | Votes: 15000 | Duration: 123
# Reagan | Rating: 6.1 | Votes: 11000 | Duration: 141
# Blitz | Rating: 6.2 | Votes: 17000 | Duration: 120
# William Tell | Rating: 5.7 | Votes: 2900 | Duration: 133
# Joy | Rating: 7.1 | Votes: 9800 | Duration: 115
# Bonhoeffer: Pastor. Spy. Assassin. | Rating: 6.2 | Votes: 3800 | Duration: 133
# The Children's Train | Rating: 7.4 | Votes: 7600 | Duration: 106
# Unfrosted | Rating: 5.5 | Votes: 35000 | Duration: 97
# Vermiglio | Rating: 6.9 | Votes: 4600 | Duration: 119
# Lilies Not for Me | Rating: 7.1 | Votes: 566 | Duration: 99
# The Devil's Bath | Rating: 6.6 | Votes: 6600 | Duration: 121
# Saint-Exupéry | Rating: 5.4 | Votes: 453 | Duration: 98
# Uprising | Rating: 6.6 | Votes: 5800 | Duration: 126
# Goebbels and the Führer | Rating: 6.7 | Votes: 2500 | Duration: 135
# 11 Rebels | Rating: 6.3 | Votes: 582 | Duration: 155
# Grand Tour | Rating: 6.5 | Votes: 2000 | Duration: 129
# Waves | Rating: 7.9 | Votes: 1900 | Duration: 131
# Being Maria | Rating: 6.1 | Votes: 720 | Duration: 100
# The New Year That Never Came | Rating: 8.1 | Votes: 5300 | Duration: 138
# Harvest | Rating: 6.1 | Votes: 451 | Duration: 131
# Harbin | Rating: 6.2 | Votes: 893 | Duration: 108
# Krigsvarsleren | Rating: 7.8 | Votes: 8 | Duration: 55
# O Último Papagaio de Timneh | Rating: nan | Votes: 0 | Duration: 49
# Zle smierci | Rating: nan | Votes: 0 | Duration: nan
# Testimoni del tempo | Rating: nan | Votes: 0 | Duration: nan
# Sivestan | Rating: nan | Votes: 0 | Duration: nan
# The Way of Internal Strength | Rating: nan | Votes: 0 | Duration: 45
# Al Kafi | Rating: nan | Votes: 0 | Duration: 110
# Zhambyl: New Era | Rating: nan | Votes: 0 | Duration: 92
# Nerah Documaentary Film | Rating: nan | Votes: 0 | Duration: nan
# Testimoni del tempo | Rating: nan | Votes: 0 | Duration: nan
# Area 2 | Rating: nan | Votes: 0 | Duration: nan
# The Coastal Map of Britain | Rating: nan | Votes: 0 | Duration: 60
# Um Tempo de Todos | Rating: nan | Votes: 0 | Duration: 132
# Okufere | Rating: nan | Votes: 0 | Duration: 91
# Kabarettistinnen in der Weimarer Republik und im Dritten Reich | Rating: nan | Votes: 0 | Duration: 90
# Nancy & Bill: The Story Before Oliver Twist | Rating: nan | Votes: 0 | Duration: nan
# International Resonance of the April Uprising | Rating: nan | Votes: 0 | Duration: 51
# Drachten Journaals | Rating: nan | Votes: 0 | Duration: 51
# Twin Falls, 2001-2024 | Rating: nan | Votes: 0 | Duration: 180
# Tatai Patara 1597 | Rating: nan | Votes: 0 | Duration: 70
# On Air | Rating: nan | Votes: 0 | Duration: nan
# The Storm | Rating: nan | Votes: 0 | Duration: 165
# Le Temple d'Hatchepsout, Reine d'Egypte | Rating: nan | Votes: 0 | Duration: nan
# Andrew Trimble: For Ulster & Ireland | Rating: nan | Votes: 0 | Duration: nan

# %%
# Data cleaning
import pandas as pd

history= pd.DataFrame(movie_details)
# Adds a new column named "genre" and sets every row's value to "history"
history['genre'] = "history"
# Checks for missing values (NaNs) in each column.
history.isna().sum()
# Converts the 'ratings' column to numeric (float) values.
history['ratings'] = pd.to_numeric(history['ratings'])
# Fills missing values
history= history.fillna(value={
                'ratings':float(history['ratings'].mean()),
                'duration_minutes':int(history['duration_minutes'].mean())
                })
# Makes sure the duration_minutes column is of integer type (not float) — because duration is a whole number
history['duration_minutes'] = history['duration_minutes'].astype(int)
# Prints a summary of the DataFrame:
history.info()
# Saves the cleaned DataFrame to a CSV file
history.to_csv("history.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   movie_names       344 non-null    object
#  1   ratings           344 non-null    float64
#  2   voting_counts     344 non-null    int64
#  3   duration_minutes  344 non-null    int64
#  4   genre             344 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 13.6+ KB

# %%
#Sport

import time
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np
import re

# Function to convert raw votes(eg: 2k) to integer(eg: 2000)
def parse_votes(text):
    if not text:
        return 0
    text = text.strip("()").replace(",", "").upper()
    match = re.match(r"([\d\.]+)([KM]?)", text)
    if not match:
        return 0
    number, suffix = match.groups()
    number = float(number)
    if suffix == "K":
        return int(number * 1_000)
    elif suffix == "M":
        return int(number * 1_000_000)
    else:
        return int(number)

# Convert duration string(eg: 1h 50m) to minutes of integer datatype
def duration_to_minutes(duration_str):
    hours = minutes = 0
    if 'h' in duration_str:
        h_match = re.search(r'(\d+)\s*h', duration_str)
        if h_match:
            hours = int(h_match.group(1))
    if 'm' in duration_str:
        m_match = re.search(r'(\d+)\s*m', duration_str)
        if m_match:
            minutes = int(m_match.group(1))
    return hours * 60 + minutes

# Setup WebDriver
driver = webdriver.Chrome()
driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=sport')
time.sleep(5)
# Click more button several times to display all the movies on the IMDb search results page
for _ in range(5):
    try:
        load_more = driver.find_element(By.XPATH, "//span[contains(text(),'more')]")
        driver.execute_script("arguments[0].click();", load_more)
        time.sleep(2.5)
    except:
        break

# Data collection
movie_details = {
    'movie_names': [],
    'ratings': [],
    'voting_counts': [],
    'duration_minutes': []
}
# Finds all movie blocks on the IMDb search results page
movie_blocks = driver.find_elements(By.CSS_SELECTOR, "li[class='ipc-metadata-list-summary-item']")

for block in movie_blocks:
# Title
    title = block.find_element(By.CSS_SELECTOR, 'h3').text.split('. ', 1)[-1].strip()
# Duration
    duration_str = np.nan
    spans = block.find_elements(By.TAG_NAME, "span")
    for span in spans:
        text = span.text.strip()
        if ('h' in text or 'm' in text) and any(char.isdigit() for char in text):
            duration_str = text
            break
    if isinstance(duration_str, str):
        duration_minutes = duration_to_minutes(duration_str)
    else:
        duration_minutes = np.nan
# Ratings
    try:
        rating = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--rating']").text.strip()
    except:
        rating = np.nan
# Votes
    try:
        vote_element = block.find_element(By.CSS_SELECTOR, "span[class ='ipc-rating-star--voteCount']")
        raw_votes_text = vote_element.text.strip()  # e.g. "246K"
        votes = parse_votes(raw_votes_text)
    except:
        votes = 0
# Store movie data and print it
    movie_details['movie_names'].append(title)
    movie_details['ratings'].append(rating)
    movie_details['voting_counts'].append(votes)
    movie_details['duration_minutes'].append(duration_minutes)

    print(f"{title} | Rating: {rating} | Votes: {votes} | Duration: {duration_minutes}")

print("Total movies scraped:", len(movie_details['movie_names']))
# Out:
# Challengers | Rating: 7.0 | Votes: 158000 | Duration: 131
# Queen of the Ring | Rating: 6.4 | Votes: 2000 | Duration: 129
# The Fire Inside | Rating: 6.7 | Votes: 2900 | Duration: 109
# Under Paris | Rating: 5.2 | Votes: 37000 | Duration: 104
# Young Woman and the Sea | Rating: 7.5 | Votes: 18000 | Duration: 129
# Unstoppable | Rating: 6.8 | Votes: 4400 | Duration: 116
# Arthur the King | Rating: 7.0 | Votes: 35000 | Duration: 107
# Lal Salaam | Rating: 4.4 | Votes: 1400 | Duration: 150
# Kill the Jockey | Rating: 6.4 | Votes: 1800 | Duration: 96
# Chandu Champion | Rating: 7.8 | Votes: 34000 | Duration: 142
# You Gotta Believe | Rating: 5.8 | Votes: 1400 | Duration: 104
# Haikyu!! The Dumpster Battle | Rating: 7.7 | Votes: 6500 | Duration: 85
# Rez Ball | Rating: 6.3 | Votes: 2600 | Duration: 111
# Diving Into the Darkness | Rating: 8.9 | Votes: 88 | Duration: 96
# Sweet Dreams | Rating: 5.4 | Votes: 1500 | Duration: 95
# Race for Glory: Audi vs. Lancia | Rating: 5.8 | Votes: 5000 | Duration: 109
# Maidaan | Rating: 7.9 | Votes: 23000 | Duration: 181
# Adds a new column named "genre" and sets every row's value to "sport"
sport['genre'] = "sport"
# Checks for missing values (NaNs) in each column.
sport.isna().sum()
# Converts the 'ratings' column to numeric (float) values.
sport['ratings'] = pd.to_numeric(sport['ratings'])

# Fills missing values
sport= sport.fillna(value={
                'ratings':float(sport['ratings'].mean()),
                'duration_minutes':int(sport['duration_minutes'].mean())
                })
# Makes sure the duration_minutes column is of integer type (not float) — because duration is a whole number
sport['duration_minutes'] = sport['duration_minutes'].astype(int)
# Prints a summary of the DataFrame:
sport.info()
# Saves the cleaned DataFrame to a CSV file
sport.to_csv("sport.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   movie_names       266 non-null    object
#  1   ratings           266 non-null    float64
#  2   voting_counts     266 non-null    int64
#  3   duration_minutes  266 non-null    int64
#  4   genre             266 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 10.5+ KB

# %%
# Reading csv file into dataframe and concatenates multiple dataframes

path = r"E:/AI and ML/Project imdb/adventure.csv"
# index_col=0 :  Uses the first column (0th) of the CSV as the index
df1= pd.read_csv(path ,index_col=0)
path = r"E:/AI and ML/Project imdb/animation.csv"
df2= pd.read_csv(path ,index_col=0)
path = r"E:/AI and ML/Project imdb/biography.csv"
df3= pd.read_csv(path ,index_col=0)
path = r"E:/AI and ML/Project imdb/history.csv"
df4= pd.read_csv(path ,index_col=0)
path = r"E:/AI and ML/Project imdb/sport.csv"
df5= pd.read_csv(path ,index_col=0)

imdb =pd.concat([df1,df2,df3,df4,df5])
# Resets the index of the combined DataFrame. Discards the old index (from the CSV), so it won’t be added as a new column.
imdb = imdb.reset_index(drop=True)
imdb
# Out:
#                                            movie_names   ratings  \
# 0                                         Gladiator II  6.500000
# 1                                       Dune: Part Two  8.500000
# 2                                             Twisters  6.500000
# 3                                    Kraven the Hunter  5.500000
# 4                                 Deadpool & Wolverine  7.500000
# ...                                                ...       ...
# 2120                            11 Brothers: The Movie  6.891566
# 2121                                        Kick Start  6.891566
# 2122                       Natural Selection Tour 2024  6.891566
# 2123  Leuchtend Schwarz - Sturm und der Weg zum Double  6.891566
# 2124                    1984: 40 Years Strong and True  6.891566
#
#       voting_counts  duration_minutes      genre
# 0            246000               148  adventure
# 1            637000               166  adventure
# 2            174000               122  adventure
# 3             61000               127  adventure
# 4            503000               128  adventure
# ...             ...               ...        ...
# 2120              0                88      sport
# 2121              0                88      sport
# 2122              0                88      sport
# 2123              0                88      sport
# 2124              0                88      sport
#
# [2125 rows x 5 columns]

# %%
imdb.to_csv("imdb.csv")

# %%
path = r"E:/AI and ML/Project imdb/imdb.csv"
imdb= pd.read_csv(path ,index_col=0)
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2125 entries, 0 to 2124
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   movie_names       2125 non-null   object
#  1   ratings           2125 non-null   float64
#  2   voting_counts     2125 non-null   int64
#  3   duration_minutes  2125 non-null   int64
#  4   genre             2125 non-null   object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 99.6+ KB

# %%
#Connection to mysql server

import mysql.connector
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
   
)
cursor = connection.cursor()
cursor

# %%
query = "create database imdb"
cursor.execute(query)

# %%
query = "use imdb"
cursor.execute(query)

# %%
connection.commit()

# %%
query = "create table imdb(movie_names varchar(1000),ratings float, voting_counts int, duration_minutes int,genre varchar(100))"
cursor.execute(query)

# %%
# Inserting values inside imdb table

data = []
for index in imdb.index:
    row = imdb.loc[index].values
    row = (row[0]),float(row[1]),int(row[2]),int(row[3]),(row[4])
    print(row)
    data.append(row)
query = "insert into imdb values(%s,%s,%s,%s,%s)"
cursor.executemany(query,data)
# Out:
# ('Gladiator II', 6.5, 246000, 148, 'adventure')
# ('Dune: Part Two', 8.5, 637000, 166, 'adventure')
# ('Twisters', 6.5, 174000, 122, 'adventure')
# ('Kraven the Hunter', 5.5, 61000, 127, 'adventure')
# ('Deadpool & Wolverine', 7.5, 503000, 128, 'adventure')
# ('Venom: The Last Dance', 6.0, 126000, 110, 'adventure')
# ('Mufasa: The Lion King', 6.6, 69000, 118, 'adventure')
# ('Moana 2', 6.6, 107000, 100, 'adventure')
# ('Flow', 7.9, 81000, 85, 'adventure')
# ('The Count of Monte-Cristo', 7.6, 37000, 178, 'adventure')
# ('Sonic the Hedgehog 3', 6.9, 63000, 110, 'adventure')
# ('Furiosa: A Mad Max Saga', 7.5, 289000, 148, 'adventure')
# ('Paddington in Peru', 6.7, 24000, 106, 'adventure')
# ('Freaky Tales', 6.2, 6400, 107, 'adventure')
# ('Inside Out 2', 7.5, 220000, 96, 'adventure')
# ('The Unholy Trinity', 6.069212962962963, 0, 93, 'adventure')
# ('Borderlands', 4.7, 50000, 101, 'adventure')
# ('Transformers One', 7.6, 53000, 104, 'adventure')
# ('Bad Boys: Ride or Die', 6.5, 102000, 115, 'adventure')
# ('Despicable Me 4', 6.2, 67000, 94, 'adventure')
# ('The Return', 6.2, 9800, 116, 'adventure')
# ('Godzilla x Kong: The New Empire', 6.0, 123000, 115, 'adventure')
# ('Kingdom of the Planet of the Apes', 6.8, 154000, 145, 'adventure')
# ('The Day the Earth Blew Up: A Looney Tunes Movie', 7.0, 5100, 91, 'adventure')
# ('The Lord of the Rings: The War of the Rohirrim', 6.3, 32000, 134, 'adventure')
# ('Damsel', 6.1, 111000, 110, 'adventure')
# ('Ghostbusters: Frozen Empire', 6.1, 95000, 115, 'adventure')
# ('Red One', 6.3, 142000, 123, 'adventure')
# ('Kung Fu Panda 4', 6.3, 70000, 94, 'adventure')
# ('Spaceman', 5.7, 44000, 107, 'adventure')
# ('Attack on Titan the Movie: The Last Attack', 9.2, 17000, 145, 'adventure')
# ('Uglies', 4.7, 33000, 100, 'adventure')
# ('The Garfield Movie', 5.7, 25000, 101, 'adventure')
# ('Solo Leveling: ReAwakening', 8.8, 13000, 121, 'adventure')
# ('Harold and the Purple Crayon', 5.7, 8700, 90, 'adventure')
# ('Sketch', 8.3, 63, 92, 'adventure')
# ('Arthur the King', 7.0, 35000, 107, 'adventure')
# ('Atlas', 5.6, 57000, 118, 'adventure')
# ('Wallace & Gromit: Vengeance Most Fowl', 7.5, 36000, 82, 'adventure')
# ('Kalki 2898 AD', 7.0, 67000, 180, 'adventure')
# ('Survive', 4.6, 2900, 90, 'adventure')
# ('Monster Summer', 5.7, 4000, 97, 'adventure')
# ('My Penguin Friend', 6.8, 5600, 97, 'adventure')
# ('Rebel Moon - Part Two: The Scargiver', 5.3, 60000, 122, 'adventure')
# ('Descendants: The Rise of Red', 4.7, 7200, 91, 'adventure')
# ('Spellbound', 5.5, 7700, 109, 'adventure')
# ('Sasquatch Sunset', 5.4, 5500, 88, 'adventure')
# ('Manjummel Boys', 8.2, 28000, 135, 'adventure')
# ('Lost on a Mountain in Maine', 6.1, 1400, 98, 'adventure')
# ('Orion and the Dark', 6.3, 17000, 93, 'adventure')
# ('Saint-Exupéry', 5.4, 453, 98, 'adventure')
# ('No Way Up', 4.6, 11000, 90, 'adventure')
# ('River of Blood', 5.1, 1900, 86, 'adventure')
# ('Family Pack', 5.5, 9400, 94, 'adventure')
# ('The Goat Life', 7.1, 48000, 173, 'adventure')
# ("Doraemon the Movie: Nobita's Earth Symphony", 6.6, 1600, 115, 'adventure')
# ('Crayon Shin-chan: Our Dinosaur Diary', 6.6, 559, 106, 'adventure')
# ('Justice League: Crisis on Infinite Earths - Part One', 6.2, 8700, 93, 'adventure')
# ('Winner', 6.5, 2600, 103, 'adventure')
# ('Badland Hunters', 5.9, 13000, 107, 'adventure')
# ('The Best Christmas Pageant Ever', 6.8, 6200, 99, 'adventure')
# ('Justice League: Crisis on Infinite Earths - Part Three', 6.1, 4700, 94, 'adventure')
# ('Escape from the 21st Century', 6.4, 971, 98, 'adventure')
# ('Sunlight', 7.8, 24, 96, 'adventure')
# ('Night of the Zoopocalypse', 6.0, 863, 91, 'adventure')
# ('Megamind vs. The Doom Syndicate', 2.5, 5700, 83, 'adventure')
# ('The Wages of Fear', 4.6, 4200, 104, 'adventure')
# ('Kaizen', 7.1, 717, 160, 'adventure')
# ("Son's Will", 7.4, 1000, 148, 'adventure')
# ('That Christmas', 6.8, 17000, 91, 'adventure')
# ('Bookworm', 6.0, 2000, 103, 'adventure')
# ('Escape', 6.4, 2200, 94, 'adventure')
# ('Justice League: Crisis on Infinite Earths - Part Two', 5.6, 5500, 94, 'adventure')
# ('Demon Slayer: Kimetsu No Yaiba - To the Hashira Training', 7.2, 8700, 104, 'adventure')
# ('Overlord: The Sacred Kingdom', 6.9, 1300, 135, 'adventure')
# ('Cult Killer', 4.8, 2800, 105, 'adventure')
# ('The Empire', 5.2, 1300, 110, 'adventure')
# ('Thelma the Unicorn', 5.7, 3000, 93, 'adventure')
# ('I, the Executioner', 6.3, 1900, 118, 'adventure')
# ('Golden Kamuy', 6.3, 2600, 127, 'adventure')
# ('Ultraman: Rising', 6.9, 6500, 117, 'adventure')
# ('Something in the Water', 4.1, 4900, 86, 'adventure')
# ('Unspeakable: Beyond the Wall of Sleep', 5.9, 63, 90, 'adventure')
# ('At Her Feet', 7.2, 50, 100, 'adventure')
# ("My Hero Academia: You're Next", 7.0, 2500, 110, 'adventure')
# ('Hanu Man', 7.7, 29000, 158, 'adventure')
# ('A.R.M', 7.1, 8900, 150, 'adventure')
# ('The Price of Money: A Largo Winch Adventure', 5.1, 1200, 100, 'adventure')
# ("Devil's Knight", 5.3, 955, 90, 'adventure')
# ('Lumina', 2.2, 692, 113, 'adventure')
# ('Bureau 749', 4.0, 568, 123, 'adventure')
# ('Seeds', 4.9, 209, 82, 'adventure')
# ('Panda Bear in Africa', 5.5, 364, 84, 'adventure')
# ('Bambi: A Tale of Life in the Woods', 5.6, 231, 78, 'adventure')
# ('Hitpig', 5.1, 1000, 86, 'adventure')
# ('No Chains No Masters', 6.3, 637, 98, 'adventure')
# ('The Courier', 6.0, 4500, 101, 'adventure')
# ('Sixty Minutes', 5.7, 5200, 88, 'adventure')
# ('A Legend', 4.7, 980, 129, 'adventure')
# ('Operation Blood Hunt', 3.5, 505, 93, 'adventure')
# ('Dongeng Sang Kancil', 6.7, 207, 99, 'adventure')
# ('Anaconda', 4.9, 657, 84, 'adventure')
# ('Formed Police Unit', 4.7, 1300, 120, 'adventure')
# ('The Firing Squad', 5.1, 5100, 93, 'adventure')
# ('Rebellious', 6.1, 226, 94, 'adventure')
# ('The Twisters', 2.5, 370, 86, 'adventure')
# ('Operation: Raqqa', 5.6, 283, 107, 'adventure')
# ('Dragonkeeper', 5.7, 1800, 98, 'adventure')
# ('Diplodocus', 6.3, 193, 90, 'adventure')
# ('Kanguva', 4.5, 15000, 152, 'adventure')
# ('Gracie and Pedro: Pets to the Rescue', 5.1, 283, 87, 'adventure')
# ('The Mountain', 6.6, 163, 89, 'adventure')
# ('Diving Into the Darkness', 9.1, 84, 96, 'adventure')
# ('Thangalaan', 6.5, 6700, 156, 'adventure')
# ('The Last Redemption', 6.8, 5200, 122, 'adventure')
# ('Buffalo Kids', 6.6, 755, 93, 'adventure')
# ('Dalia and the Red Book', 5.9, 140, 107, 'adventure')
# ('Saving Bikini Bottom: The Sandy Cheeks Movie', 3.7, 4000, 82, 'adventure')
# ('Robin and the Hoods', 4.3, 537, 100, 'adventure')
# ('Gladiators', 4.6, 106, 95, 'adventure')
# ('Empire Queen: The Golden Age of Magic', 3.2, 214, 148, 'adventure')
# ("The Tiger's Apprentice", 5.7, 2200, 84, 'adventure')
# ('Now or Never!', 2.2, 17000, 0, 'adventure')
# ('A Sloth Story', 5.6, 227, 90, 'adventure')
# ('Woody Woodpecker Goes to Camp', 4.5, 2600, 100, 'adventure')
# ('Autumn and the Black Jaguar', 5.6, 1000, 100, 'adventure')
# ('Angels Fallen: Warriors of Peace', 4.8, 5800, 103, 'adventure')
# ('Five Friends', 6.7, 944, 112, 'adventure')
# ('Cells at Work!', 6.7, 336, 109, 'adventure')
# ('Treasure Trackers', 5.8, 169, 92, 'adventure')
# ('200% Wolf', 5.9, 1300, 98, 'adventure')
# ('Never Look Away', 7.2, 282, 85, 'adventure')
# ('WWII: Operation Phoenix', 5.8, 98, 106, 'adventure')
# ('Naa Saami Ranga', 4.5, 1200, 150, 'adventure')
# ('Roadkill', 3.7, 690, 90, 'adventure')
# ('Kalvan', 5.6, 989, 142, 'adventure')
# ('Bade Miyan Chote Miyan', 3.7, 39000, 163, 'adventure')
# ('Man and Witch: The Dance of a Thousand Steps', 5.5, 343, 94, 'adventure')
# ('Big City Greens the Movie: Spacecation', 6.2, 562, 83, 'adventure')
# ('The Kingdom', 7.0, 131, 133, 'adventure')
# ('Return to Wickensburg', 5.2, 39, 88, 'adventure')
# ('Bionic', 4.3, 1700, 110, 'adventure')
# ('The Last Ronin', 4.9, 591, 115, 'adventure')
# ('The Last of Us: Immunity', 4.2, 29, 64, 'adventure')
# ("Noah's Ark", 4.3, 687, 96, 'adventure')
# ('War of the Worlds: Extinction', 3.0, 211, 84, 'adventure')
# ('Seven Seas Seven Hills', 8.5, 94, 90, 'adventure')
# ('Eat the Night', 6.0, 544, 106, 'adventure')
# ('Guest from the Future', 6.0, 1200, 141, 'adventure')
# ('No Time to Spy: A Loud House Movie', 6.3, 485, 81, 'adventure')
# ('Un lío de millones', 5.3, 248, 91, 'adventure')
# ('Dragon Ball Z Kai', 8.6, 79, 82, 'adventure')
# ('Mong Vuot', 5.0, 166, 96, 'adventure')
# ('My Oni Girl', 6.0, 1800, 112, 'adventure')
# ('School of Magical Animals 3', 5.8, 338, 105, 'adventure')
# ('This Too Shall Pass', 9.1, 17, 105, 'adventure')
# ('Marianengraben', 7.3, 92, 87, 'adventure')
# ("The Magician's Raincoat", 5.6, 125, 0, 'adventure')
# ('Chuck Billy and the Marvelous Guava Tree', 7.4, 1200, 90, 'adventure')
# ('The Keepers of the 5 Kingdoms', 4.0, 225, 109, 'adventure')
# ('Going Viral', 8.3, 300, 90, 'adventure')
# ('Pimpinero: Blood and Oil', 5.6, 568, 121, 'adventure')
# ('Era Oculta', 6.069212962962963, 0, 80, 'adventure')
# ('My Freaky Family', 6.3, 419, 86, 'adventure')
# ('Mobile Suit Gundam SEED Freedom', 6.6, 975, 124, 'adventure')
# ('Niko: Beyond the Northern Lights', 6.2, 351, 86, 'adventure')
# ('Road Wars: Max Fury', 2.0, 365, 83, 'adventure')
# ('Barroz: Guardian of Treasures', 3.4, 1000, 155, 'adventure')
# ('The Casagrandes Movie', 5.6, 687, 89, 'adventure')
# ('The Waves of Madness', 5.9, 94, 68, 'adventure')
# ('Witch Hunter', 5.0, 25, 80, 'adventure')
# ('Ayalaan', 5.9, 4000, 155, 'adventure')
# ('Rally Caps', 5.5, 142, 100, 'adventure')
# ('Meanwhile on Earth', 6.0, 944, 89, 'adventure')
# ('One Million Babes BC', 2.1, 87, 75, 'adventure')
# ('Gaami', 6.3, 2000, 147, 'adventure')
# ('The Backrooms', 8.2, 15, 63, 'adventure')
# ('Ice Maiden', 8.6, 79, 90, 'adventure')
# ('Little Emma', 5.4, 129, 106, 'adventure')
# ('Sam and Colby: The Legends of the Paranormal', 4.8, 314, 98, 'adventure')
# ('Alpha.', 6.9, 256, 100, 'adventure')
# ('Buddy', 3.8, 355, 137, 'adventure')
# ('The Goat', 5.9, 386, 91, 'adventure')
# ('The Lost Tiger', 7.9, 50, 90, 'adventure')
# ('Storm Crashers', 6.2, 571, 88, 'adventure')
# ('The Adventures of Jurassic Pet: Return to the Wild', 5.5, 73, 90, 'adventure')
# ('Spiders on a Plane', 4.9, 379, 78, 'adventure')
# ('All for One', 1.4, 675, 97, 'adventure')
# ('Captain Miller', 6.9, 11000, 157, 'adventure')
# ('The Blinkless', 7.3, 14, 59, 'adventure')
# ('Z-Mom', 5.0, 46, 90, 'adventure')
# ('The Big Trip 3: Race Around the World', 5.7, 66, 85, 'adventure')
# ("My Fathers' Daughter", 6.5, 82, 78, 'adventure')
# ('Teenz', 4.4, 866, 122, 'adventure')
# ('Chhota Bheem and the Curse of Damyaan', 4.8, 2300, 145, 'adventure')
# ('Ghost Island', 7.4, 50, 95, 'adventure')
# ('Planetquake', 3.0, 319, 85, 'adventure')
# ('Major Grom: The Game', 6.1, 1900, 168, 'adventure')
# ('The Phantom Warrior', 2.4, 556, 119, 'adventure')
# ('Fox & Hare Save the Forest', 5.9, 213, 71, 'adventure')
# ('Space Ranger', 3.4, 81, 0, 'adventure')
# ('Nintama Rantaro Dokutake Ninja-tai Saikyou no Gunshi', 7.2, 32, 90, 'adventure')
# ('Elli and the Ghostly Ghost Train', 5.0, 108, 86, 'adventure')
# ('Stinky Summer', 5.6, 55, 90, 'adventure')
# ('Next to Us', 4.8, 228, 125, 'adventure')
# ('Earthquake Underground', 3.3, 201, 83, 'adventure')
# ('Oculus', 6.0, 15, 113, 'adventure')
# ('Shrek 5: The Contract - A Fan Made Film', 7.2, 21, 84, 'adventure')
# ('Appu', 8.5, 186, 92, 'adventure')
# ('Mr Zoo Keeper', 8.3, 17, 0, 'adventure')
# ('Jurassic Triangle', 2.4, 287, 84, 'adventure')
# ('The Epidemic', 5.9, 71, 95, 'adventure')
# ('The Secret of Pin-Up Island', 7.4, 97, 107, 'adventure')
# ('Its Name Was Mormo', 3.6, 123, 93, 'adventure')
# ('I Heart Robots', 4.6, 2400, 76, 'adventure')
# ('Tanning Zone', 6.069212962962963, 0, 90, 'adventure')
# ('Taklee Genesis x Worlds Collide', 5.4, 426, 146, 'adventure')
# ('Trifole', 7.5, 59, 100, 'adventure')
# ('Dünya Varmis', 6.6, 65, 100, 'adventure')
# ('Molar', 6.069212962962963, 0, 117, 'adventure')
# ('Game On', 2.6, 357, 85, 'adventure')
# ('The Traveller', 5.2, 212, 134, 'adventure')
# ("Luigi's Mansion", 6.2, 19, 60, 'adventure')
# ('Bull Shark 3', 3.5, 91, 76, 'adventure')
# ("Dead Dead Demon's Dededede Destruction", 7.1, 148, 120, 'adventure')
# ('Odio el verano', 5.1, 605, 103, 'adventure')
# ('Memes & Nightmares', 5.7, 90, 81, 'adventure')
# ('Ahl Al Kahf', 5.3, 281, 120, 'adventure')
# ('The Epic of Gilgamesh', 6.069212962962963, 0, 79, 'adventure')
# ('Warrior Awang and Master Tok Gajah', 4.6, 481, 118, 'adventure')
# ('A Trip Elsewhere', 5.5, 109, 93, 'adventure')
# ('My Redneck Neighbor: Chapter 2 - Let the Games Begin', 6.6, 9, 55, 'adventure')
# ('Kodaikanal', 9.2, 70, 173, 'adventure')
# ('Vertical', 5.2, 146, 111, 'adventure')
# ("Transformers Prime: Galavatron's Revenge", 4.3, 14, 104, 'adventure')
# ('Death Game', 6.3, 26, 88, 'adventure')
# ('Birds Flying East', 5.8, 594, 100, 'adventure')
# ('Maya, donne-moi un titre', 6.4, 60, 61, 'adventure')
# ('Kvitebjørn', 5.9, 74, 85, 'adventure')
# ('I Left My Heart in Colombia', 8.7, 419, 0, 'adventure')
# ('Killer Witches from Outer Space', 6.9, 80, 0, 'adventure')
# ('Kiyma: Orman Kanunlari', 3.9, 40, 81, 'adventure')
# ('Tapori Nayak', 8.6, 19, 0, 'adventure')
# ('Ivan Tsarevich i Seryy Volk 6', 5.7, 97, 85, 'adventure')
# ("Peter Brook's the Mahabharata (8K)", 6.069212962962963, 0, 173, 'adventure')
# ('LasseMajas detektivbyrå - Maskoten som försvann', 6.0, 62, 90, 'adventure')
# ('Bremenskie muzykanty', 4.6, 691, 115, 'adventure')
# ('Amazon Bullseye', 5.2, 216, 113, 'adventure')
# ('Zak & Wowo: The Legend of Lendarys', 5.7, 103, 85, 'adventure')
# ('Letuchiy korabl', 3.8, 303, 100, 'adventure')
# ('Rocky Road to Berlin', 7.2, 1500, 104, 'adventure')
# ('Tales from the Table', 6.069212962962963, 0, 90, 'adventure')
# ('Hain', 2.9, 49, 95, 'adventure')
# ('Powder Pup', 6.1, 78, 89, 'adventure')
# ('Iron Dusk', 5.5, 19, 0, 'adventure')
# ('Spirit Riser', 6.6, 37, 98, 'adventure')
# ('Sentinelese', 6.069212962962963, 0, 90, 'adventure')
# ('Duffle Bag Boy', 6.8, 60, 0, 'adventure')
# ('Güzel Bir Rüya', 4.6, 47, 79, 'adventure')
# ('Si Juki the Movie: Harta Pulau Monyet', 6.0, 127, 107, 'adventure')
# ("Triple 7: They Said It Couldn't Be Done", 8.5, 14, 97, 'adventure')
# ('Tokusou Sentai Dekaranger 20th: Fireball Booster', 7.2, 36, 50, 'adventure')
# ('STEVE (A Minecraft Movie)', 6.9, 12, 61, 'adventure')
# ('Water Park', 6.069212962962963, 0, 25, 'adventure')
# ('StarGazer: The Need of the Many', 5.0, 11, 47, 'adventure')
# ('Oscar Wilde About America', 4.2, 33, 98, 'adventure')
# ('Samaya bolshaya luna', 2.5, 137, 105, 'adventure')
# ('Igrisca ne damo!', 7.1, 30, 79, 'adventure')
# ('Fuuto PI: Portrait of Kamen Rider Skull', 7.5, 48, 82, 'adventure')
# ('Game of Death: The Six Doors to Hell', 6.069212962962963, 0, 145, 'adventure')
# ('Tulang Belulang Tulang', 7.1, 50, 95, 'adventure')
# ('Friendly Fire', 5.3, 65, 105, 'adventure')
# ('Dogman Territory: Werewolves in the Land Between the Lakes', 5.6, 35, 0, 'adventure')
# ('Mr. Blue Shirt: The Inspiration', 4.8, 10, 0, 'adventure')
# ('The Slave and the Sorcerer', 6.7, 42, 86, 'adventure')
# ('The Star City Murders', 4.1, 145, 79, 'adventure')
# ('Seeking the King', 6.069212962962963, 0, 90, 'adventure')
# ('Art Work', 6.069212962962963, 0, 91, 'adventure')
# ('Yolki 11', 4.7, 177, 92, 'adventure')
# ('Tay 2: Ebabil Takimi', 5.0, 44, 78, 'adventure')
# ('My Redneck Neighbor: Chapter 1 - The Rednecks Are Coming', 6.4, 10, 74, 'adventure')
# ('Ognivo', 5.5, 238, 105, 'adventure')
# ('Son of the Wolf', 6.069212962962963, 0, 82, 'adventure')
# ('Permafrost', 5.7, 115, 80, 'adventure')
# ('76 Days Adrift', 6.069212962962963, 0, 105, 'adventure')
# ('Kade', 6.3, 17, 92, 'adventure')
# ('Mountain Boy', 8.3, 28, 93, 'adventure')
# ('Finding Christmas', 6.3, 14, 0, 'adventure')
# ('Masha i Medved v kino: Park chudes', 7.4, 18, 58, 'adventure')
# ('Kral Sakir: Devler Uyandi', 5.3, 69, 0, 'adventure')
# ('Askepote', 3.5, 84, 72, 'adventure')
# ("Surge of Power: Where There's Smoke", 6.5, 13, 68, 'adventure')
# ("Dead Dead Demon's Dededede Destruction Zenpen", 7.1, 142, 120, 'adventure')
# ('Two Breaths', 7.9, 34, 18, 'adventure')
# ('The Worlds Divide', 7.9, 40, 120, 'adventure')
# ('Steal the Naughty List', 6.3, 126, 90, 'adventure')
# ('The Trail', 7.8, 38, 80, 'adventure')
# ('Arctic Hollow', 2.3, 184, 70, 'adventure')
# ('Anytime', 8.9, 25, 62, 'adventure')
# ('Silex and the City, le film', 5.0, 52, 77, 'adventure')
# ('Nanoshark', 5.3, 21, 0, 'adventure')
# ('Cazatesoros', 6.4, 29, 106, 'adventure')
# ('Baba Yaga spasaet Novyy god', 4.4, 122, 99, 'adventure')
# ('Six Nine Five (695)', 7.0, 706, 137, 'adventure')
# ('Tipppsy', 8.1, 33, 115, 'adventure')
# ('Shadows of Betrayal: Chronicles of Ian Blair', 7.5, 14, 65, 'adventure')
# ('Håkan Bråkan 2', 5.3, 142, 92, 'adventure')
# ('Turma da Mônica Jovem: Reflexos do Medo', 2.8, 259, 88, 'adventure')
# ('Life with Quincy 3', 6.069212962962963, 0, 73, 'adventure')
# ('Daye: Seret ahl el Daye', 7.9, 18, 104, 'adventure')
# ('Poklad', 4.6, 44, 100, 'adventure')
# ('Colour Palette', 9.4, 52, 87, 'adventure')
# ('Captain Avispa', 5.7, 180, 96, 'adventure')
# ("Nature Cat's Nature Movie Special Extraordinaire", 7.3, 19, 53, 'adventure')
# ('Satu - Year of the Rabbit', 9.1, 58, 93, 'adventure')
# ('Orango', 7.3, 75, 94, 'adventure')
# ('Dreams', 6.9, 9, 106, 'adventure')
# ('Family Vacation', 6.6, 6, 0, 'adventure')
# ('Gepack', 6.6, 368, 97, 'adventure')
# ('The Forest', 6.3, 49, 77, 'adventure')
# ('Chernyy zamok', 4.9, 56, 115, 'adventure')
# ('Rocky and Bullwinkle', 9.2, 15, 100, 'adventure')
# ('Bar MoskvaChiki', 5.1, 106, 91, 'adventure')
# ('Return', 6.069212962962963, 0, 90, 'adventure')
# ('Pui Pui Molcar the Movie: Molmax', 7.0, 9, 69, 'adventure')
# ('Tri kota. Zimnie kanikuly', 6.6, 35, 65, 'adventure')
# ('Benjamin Bat', 7.8, 33, 75, 'adventure')
# ('Wilhelm Gustloff', 8.7, 9, 110, 'adventure')
# ('Lion King: A Tale of Mufasa', 6.069212962962963, 0, 90, 'adventure')
# ('Fights Break Sphere 3', 5.0, 11, 81, 'adventure')
# ('Gladiator II: The Art and Making of the Ridley Scott Film', 6.069212962962963, 0, 90, 'adventure')
# ('Road to Dreamland', 6.069212962962963, 0, 90, 'adventure')
# ('Yaren Leylek', 5.6, 33, 95, 'adventure')
# ('Shanghai Story', 8.2, 64, 71, 'adventure')
# ('Troy the Bharat Putra', 5.5, 33, 134, 'adventure')
# ('Tri bogatyrya. Ni dnya bez podviga', 5.7, 71, 61, 'adventure')
# ('Il cammino: Viaggio in Calabria', 6.069212962962963, 0, 58, 'adventure')
# ('Wonderland', 6.8, 13, 120, 'adventure')
# ('Heavens: The Boy and His Robot', 6.3, 22, 98, 'adventure')
# ('Moy dikiy drug', 6.5, 63, 100, 'adventure')
# ('Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik', 7.4, 75, 70, 'adventure')
# ('Get Close 2', 5.7, 47, 0, 'adventure')
# ('Beyond existence', 4.1, 23, 95, 'adventure')
# ('Advent', 7.5, 6, 119, 'adventure')
# ('Die Chaosschwestern und Pinguin Paul', 5.6, 73, 100, 'adventure')
# ('QAnon Avenue', 10.0, 7, 57, 'adventure')
# ('Stranded Pearl', 6.0, 27, 90, 'adventure')
# ('Cândido', 6.3, 63, 99, 'adventure')
# ('Dikkie Dik en de Verdwenen Knuffel', 7.3, 131, 62, 'adventure')
# ('Wonderful Precure! The Movie! Doki Doki Game no Sekai de Daiboken', 6.8, 36, 71, 'adventure')
# ('Mama', 8.5, 7, 100, 'adventure')
# ("Penelope & Everly's Holiday Adventure", 6.069212962962963, 0, 90, 'adventure')
# ('Tur s Ivanushkami', 5.3, 162, 111, 'adventure')
# ('Joachim and the Apocalypse', 7.5, 16, 90, 'adventure')
# ("Alex and Mia's Awesome Movie!!", 6.069212962962963, 0, 75, 'adventure')
# ('Spider-Man: Blue', 5.8, 12, 0, 'adventure')
# ('Oro Negro', 6.069212962962963, 0, 90, 'adventure')
# ('Uttarakaanda', 6.069212962962963, 0, 90, 'adventure')
# ('Jathara', 6.2, 1100, 129, 'adventure')
# ('The Space in Between', 6.069212962962963, 0, 90, 'adventure')
# ('Xibalba Monster', 6.7, 31, 76, 'adventure')
# ('The Very Last Christmas', 8.6, 12, 75, 'adventure')
# ('The Umbrella Fairy', 5.7, 61, 95, 'adventure')
# ('Manyunya. Priklyucheniya v Moskve', 5.7, 111, 87, 'adventure')
# ('Dünya Mali: Eksi Bir', 7.2, 18, 133, 'adventure')
# ('Mobile Suit Gundam: Silver Phantom', 6.1, 13, 90, 'adventure')
# ('Operation Wakaliga: Fate and Blood', 6.7, 11, 66, 'adventure')
# ('Fallen Leaves, Broken Lighters', 7.7, 8, 96, 'adventure')
# ('Famous Patrick (A Super SpongeBob Fan Movie)', 4.9, 29, 53, 'adventure')
# ('The Apples Gang: The Movie by Wright', 6.069212962962963, 0, 90, 'adventure')
# ('The Yoshi Movie', 7.9, 14, 105, 'adventure')
# ('The Last Five Days: The Freak Building', 3.7, 59, 61, 'adventure')
# ("Dans l'ombre de Marlow", 6.069212962962963, 0, 80, 'adventure')
# ('Elephant Steps', 6.9, 41, 0, 'adventure')
# ('Manyunya. Priklyucheniya v derevne', 5.8, 121, 84, 'adventure')
# ('Piraty galaktiki Barrakuda', 4.6, 86, 92, 'adventure')
# ('Dragon Gate Inn', 6.069212962962963, 0, 90, 'adventure')
# ('Goodbye Hamdi', 6.2, 11, 85, 'adventure')
# ('BAM!', 7.0, 30, 80, 'adventure')
# ('Petualangan Anak Penangkap Hantu', 5.9, 27, 99, 'adventure')
# ('Boom!', 8.3, 11, 90, 'adventure')
# ('Tracing the Divide', 8.8, 173, 84, 'adventure')
# ('23 Horas', 7.0, 21, 0, 'adventure')
# ('The Eye of the Salamander', 8.4, 21, 81, 'adventure')
# ("Yasmeen's Element", 7.6, 21, 76, 'adventure')
# ('Spooky Society', 6.069212962962963, 0, 90, 'adventure')
# ('Abudeka Is Back', 5.3, 40, 120, 'adventure')
# ('Moy lyubimyy chempion', 2.3, 420, 95, 'adventure')
# ('Vikaasaparva', 8.7, 542, 134, 'adventure')
# ('The Bigfoot Prophecy', 4.8, 23, 117, 'adventure')
# ('Banana Boat', 5.5, 21, 78, 'adventure')
# ('Hope & Glory', 6.6, 148, 44, 'adventure')
# ('Militant Monster 2024', 8.7, 29, 0, 'adventure')
# ('Treasure Fellowship', 6.069212962962963, 0, 86, 'adventure')
# ('The Cold Father', 6.8, 19, 0, 'adventure')
# ('Pirates & Slaves', 5.8, 6, 53, 'adventure')
# ('No More Trouble - Cosa rimane di una tempesta', 8.6, 20, 97, 'adventure')
# ('Historia de pastores', 5.5, 34, 80, 'adventure')
# ('Zoloto Umalty', 4.9, 114, 109, 'adventure')
# ('Target Jeremy', 6.069212962962963, 0, 90, 'adventure')
# ('Jaunt', 8.7, 8, 78, 'adventure')
# ("Lakeside's Mission: Impossible", 6.069212962962963, 0, 90, 'adventure')
# ('The Sasqualogist', 6.069212962962963, 0, 89, 'adventure')
# ('Minecraft But I Survive Again in Parkour Civilization', 9.0, 30, 0, 'adventure')
# ('Xin Longmen kezhan', 2.9, 7, 73, 'adventure')
# ('Knight', 6.069212962962963, 0, 90, 'adventure')
# ('Adam i Eva', 5.1, 96, 95, 'adventure')
# ('This Land of Mine', 5.5, 11, 90, 'adventure')
# ('The Last Survivor', 6.069212962962963, 0, 115, 'adventure')
# ('Abar Arownne Din Ratri', 8.0, 8, 111, 'adventure')
# ('Gumshoe Jon and the Mystery of the Saucer Men - The Even Better Version', 6.069212962962963, 0, 90, 'adventure')
# ('Bratya', 2.7, 129, 103, 'adventure')
# ('Cursed Waters: Creature of Lake Okanagan', 6.069212962962963, 0, 90, 'adventure')
# ('Oyunda Kal: Eglence Arenasi', 2.5, 38, 92, 'adventure')
# ('De Legende van Familie Vos', 5.7, 59, 81, 'adventure')
# ('Old Wild Mob', 6.069212962962963, 0, 90, 'adventure')
# ('Toy Kids: The Movie', 6.069212962962963, 0, 65, 'adventure')
# ('The Lost Colony', 6.069212962962963, 0, 90, 'adventure')
# ('The Ballad of Straw Hat Sam', 9.1, 10, 45, 'adventure')
# ('Mai Martaba', 4.8, 10, 86, 'adventure')
# ('The Artifact', 6.069212962962963, 0, 108, 'adventure')
# ('Cacophony the Animated Movie', 6.069212962962963, 0, 81, 'adventure')
# ('Chyortov kamen', 4.4, 21, 105, 'adventure')
# ('Príncipe Lu e a Lenda do Dragão', 4.1, 29, 90, 'adventure')
# ('The Puffins & the Magic Portal', 7.7, 32, 0, 'adventure')
# ('The 9th Raider', 6.069212962962963, 0, 105, 'adventure')
# ('Changle Zhen Gui Shi', 6.069212962962963, 0, 88, 'adventure')
# ('Mesken (Messuage)', 7.3, 43, 102, 'adventure')
# ('A Christmas Carol', 9.8, 11, 39, 'adventure')
# ('Lo carga el diablo', 7.5, 28, 103, 'adventure')
# ('Adrian', 6.069212962962963, 0, 90, 'adventure')
# ('Mera Number Beess', 6.069212962962963, 0, 109, 'adventure')
# ('Robo Puffin', 6.069212962962963, 0, 90, 'adventure')
# ('Hyacinthe', 6.069212962962963, 0, 90, 'adventure')
# ('Commonheart. from A Childish Mind.', 6.069212962962963, 0, 83, 'adventure')
# ('Il ricercatore', 6.4, 9, 71, 'adventure')
# ('The Pray', 6.069212962962963, 0, 90, 'adventure')
# ('The Same Picture Group Holiday Special', 6.069212962962963, 0, 55, 'adventure')
# ('The Farm', 6.069212962962963, 0, 104, 'adventure')
# ('Jackpot', 6.069212962962963, 0, 90, 'adventure')
# ('Emma', 6.069212962962963, 0, 90, 'adventure')
# ('The Pizza Guys', 6.069212962962963, 0, 89, 'adventure')
# ('Skazochnyy patrul. Shou prodolzhayetsya', 7.2, 11, 65, 'adventure')
# ('The Age Mate', 6.069212962962963, 0, 87, 'adventure')
# ('Vasilisa i khraniteli vremeni', 3.1, 70, 98, 'adventure')
# ('Suchana', 8.7, 511, 90, 'adventure')
# ('Luccas e Gi em: Dinossauros', 3.5, 28, 91, 'adventure')
# ('La Familia del Barrio: La Película', 4.5, 7, 0, 'adventure')
# ("The Dragon's Tomb", 6.8, 52, 77, 'adventure')
# ('Lost and Found', 6.069212962962963, 0, 60, 'adventure')
# ('V potoke trekh stikhiy', 5.2, 42, 85, 'adventure')
# ('The Embers of Domsheria', 6.069212962962963, 0, 95, 'adventure')
# ('Dandelion', 8.9, 9, 95, 'adventure')
# ('Longe da Estrada', 6.0, 9, 68, 'adventure')
# ('Unhappy 25 Years Little Brat', 6.069212962962963, 0, 90, 'adventure')
# ('The Lion Dog', 6.069212962962963, 0, 122, 'adventure')
# ('Turbozavry. God drakona', 9.2, 43, 48, 'adventure')
# ('The Stand at Alder Creek', 6.069212962962963, 0, 53, 'adventure')
# ('Dushu', 6.069212962962963, 0, 96, 'adventure')
# ('Novyy god v Beryozovke', 7.1, 100, 94, 'adventure')
# ('Montserrat, Integral 107', 6.069212962962963, 0, 85, 'adventure')
# ('I racconti del mare', 6.069212962962963, 0, 89, 'adventure')
# ('Aliens Uncovered: Buried Cities & Lost Tribes', 8.8, 11, 0, 'adventure')
# ('Carjorski Clan: Tale of the Fallen Knight', 6.069212962962963, 0, 90, 'adventure')
# ('Nijari', 6.069212962962963, 0, 106, 'adventure')
# ('Tinpot & Yello', 6.069212962962963, 0, 51, 'adventure')
# ('Kage & Celeste', 6.069212962962963, 0, 69, 'adventure')
# ('Superman: Jubilation', 6.069212962962963, 0, 176, 'adventure')
# ('The Long Quiet', 6.069212962962963, 0, 94, 'adventure')
# ('Wild Boys', 6.069212962962963, 0, 119, 'adventure')
# ('Bernadotte, Louise & Napoleon', 6.069212962962963, 0, 74, 'adventure')
# ('Filmmaker', 6.069212962962963, 0, 97, 'adventure')
# ('One Day the Movie', 6.069212962962963, 0, 90, 'adventure')
# ('Applepictures the Poseidon Legacy', 6.4, 19, 84, 'adventure')
# ('Qianhe xiansheng', 6.069212962962963, 0, 82, 'adventure')
# ('Wheelies Inc', 6.069212962962963, 0, 90, 'adventure')
# ('LUDA', 7.2, 6, 86, 'adventure')
# ('Frankenstein Theater: The Magic Sword', 4.1, 24, 82, 'adventure')
# ('Big Water Theory', 6.069212962962963, 0, 83, 'adventure')
# ('Antarctic Voyage', 6.8, 6, 48, 'adventure')
# ('Women, Dreams and Bread', 6.069212962962963, 0, 90, 'adventure')
# ('Xiang Xi Gui Shi', 6.069212962962963, 0, 72, 'adventure')
# ('The Lost Coast', 6.069212962962963, 0, 90, 'adventure')
# ('Deux hommes un destin', 6.069212962962963, 0, 94, 'adventure')
# ('Altered', 6.069212962962963, 0, 90, 'adventure')
# ('Sathur: Part1', 6.069212962962963, 0, 90, 'adventure')
# ('Piri Reis: The Incredible Chart', 7.0, 27, 138, 'adventure')
# ('Psycho Rhythm', 6.069212962962963, 0, 90, 'adventure')
# ('Mortadella', 8.4, 8, 90, 'adventure')
# ('Purgatorio', 6.069212962962963, 0, 59, 'adventure')
# ('Lajjpal', 9.0, 8, 252, 'adventure')
# ('Novogodniy ekspress', 8.5, 8, 47, 'adventure')
# ('Mult v kino. Vypusk # 168: Idyom na piknik!', 6.069212962962963, 0, 51, 'adventure')
# ("Whites Only: Ade's Extremist Adventure", 7.0, 27, 65, 'adventure')
# ("Let's Go! Anpanman: Baikinman and Lulun", 6.5, 7, 64, 'adventure')
# ('Nothing Unusual', 8.8, 13, 92, 'adventure')
# ('Le mystère de Waza', 6.069212962962963, 0, 90, 'adventure')
# ('A New Dawn', 6.069212962962963, 0, 60, 'adventure')
# ('La bruja del bosque oscuro', 6.069212962962963, 0, 92, 'adventure')
# ('The Road Long', 6.069212962962963, 0, 90, 'adventure')
# ('Lapse', 6.069212962962963, 0, 90, 'adventure')
# ('Poymay sobaku, esli smozhesh', 3.5, 39, 96, 'adventure')
# ('Ngesot', 4.8, 18, 87, 'adventure')
# ('Suvorovets 1944', 3.3, 27, 90, 'adventure')
# ('Tayna Chyornoy Ruki', 5.7, 24, 84, 'adventure')
# ('The Ghost of Annie Lee', 4.8, 5, 103, 'adventure')
# ('YA - medved', 5.0, 61, 97, 'adventure')
# ('Soul Trekkers', 6.069212962962963, 0, 90, 'adventure')
# ('Dracu Ra', 5.6, 41, 106, 'adventure')
# ('A Babá - Operação Game Over', 4.9, 11, 0, 'adventure')
# ('Isle: Alpha One', 8.4, 7, 97, 'adventure')
# ('DCLXVI', 6.069212962962963, 0, 200, 'adventure')
# ('Mukhadrakon', 5.3, 18, 109, 'adventure')
# ('Pra Sempre', 6.069212962962963, 0, 75, 'adventure')
# ('The Bigfoot prophecy 2', 6.069212962962963, 0, 118, 'adventure')
# ('Kyle and the Last Emerald 2', 8.4, 9, 15, 'adventure')
# ('Aruanda - Sentido da Vida', 6.069212962962963, 0, 90, 'adventure')
# ('I am the girl 3 me and my girlfriend', 6.069212962962963, 0, 90, 'adventure')
# ('Tobia e i colori del mondo', 4.2, 6, 0, 'adventure')
# ('Huaquero Tierra Maldita', 6.069212962962963, 0, 90, 'adventure')
# ('Harmonie', 6.069212962962963, 0, 74, 'adventure')
# ('Analogistan', 6.069212962962963, 0, 85, 'adventure')
# ("Florp's Solar Vacation", 6.069212962962963, 0, 2, 'adventure')
# ("I'm Professional", 3.7, 8, 95, 'adventure')
# ('Pueblo En Llamas', 6.069212962962963, 0, 82, 'adventure')
# ('Unscripted - In the Heart of Africa', 6.069212962962963, 0, 82, 'adventure')
# ('Fat Chance! the Movie', 7.6, 6, 0, 'adventure')
# ('Emu War: A Subtle Examination of the Sheer Caucasity of Colonialism', 6.069212962962963, 0, 90, 'adventure')
# ('El Regreso Del Campero 3', 6.069212962962963, 0, 81, 'adventure')
# ('Mult v kino. Vypusk # 174. Dobrye dela!', 6.069212962962963, 0, 48, 'adventure')
# ('My Only Relative.', 6.069212962962963, 0, 105, 'adventure')
# ('The Puffins: Arctic Games', 6.069212962962963, 0, 90, 'adventure')
# ('The Road to OVC Champions', 6.069212962962963, 0, 62, 'adventure')
# ("L'Elisir di Leonardo da Vinci e la Banda del Buffardello", 6.069212962962963, 0, 90, 'adventure')
# ('The Veyshal Movie', 6.069212962962963, 0, 120, 'adventure')
# ('Katzie in Marokko', 6.069212962962963, 0, 90, 'adventure')
# ('EP Break the Multiverse', 6.069212962962963, 0, 76, 'adventure')
# ('Upanga Kingdom', 6.069212962962963, 0, 115, 'adventure')
# ('Bragow', 6.069212962962963, 0, 120, 'adventure')
# ('Okhota na russkogo geniya', 5.1, 12, 71, 'adventure')
# ('ABC Life: The Movie', 6.069212962962963, 0, 60, 'adventure')
# ('Moving Targets', 6.069212962962963, 0, 90, 'adventure')
# ('Lost & Found', 6.069212962962963, 0, 90, 'adventure')
# ('The Brofessors Return', 6.069212962962963, 0, 78, 'adventure')
# ('Yan Hu Ji Hua', 6.069212962962963, 0, 90, 'adventure')
# ('Bear Kid: Super Hero', 6.069212962962963, 0, 80, 'adventure')
# ('The Seed', 6.069212962962963, 0, 100, 'adventure')
# ("Melissa's Birthday", 6.069212962962963, 0, 90, 'adventure')
# ('Ba Jie', 6.069212962962963, 0, 90, 'adventure')
# ('Salem, SOS-ed!', 6.069212962962963, 0, 91, 'adventure')
# ('Gostya iz kosmosa', 8.7, 7, 70, 'adventure')
# ('Road to Paradise', 6.069212962962963, 0, 76, 'adventure')
# ('Marraia', 6.069212962962963, 0, 77, 'adventure')
# ('Project Block', 6.069212962962963, 0, 66, 'adventure')
# ('The Moon Asks for Help', 6.069212962962963, 0, 96, 'adventure')
# ('PW V: Tears of the Fallen', 8.2, 11, 60, 'adventure')
# ('Kleurenpalet 3: De Definitie Van Het Multiversum', 6.069212962962963, 0, 77, 'adventure')
# ('Selebryata', 3.8, 20, 93, 'adventure')
# ('Non succederà più', 6.069212962962963, 0, 90, 'adventure')
# ('The Koopas', 6.069212962962963, 0, 90, 'adventure')
# ('Cobrazilla', 6.069212962962963, 0, 60, 'adventure')
# ('Madeline & Silverfrost', 6.069212962962963, 0, 90, 'adventure')
# ('One in a million chance', 6.069212962962963, 0, 70, 'adventure')
# ('Dream 1', 6.069212962962963, 0, 90, 'adventure')
# ('Oda: Vlucht door de Eeuwen', 6.4, 7, 0, 'adventure')
# ('Beyaz Zenciler: Yapim Asamasi', 8.6, 5, 55, 'adventure')
# ('Hasta Que Nos Encontremos De Neuvo', 6.069212962962963, 0, 90, 'adventure')
# ('Línguas de Fogo', 6.069212962962963, 0, 69, 'adventure')
# ('Maverick from the Edge', 6.069212962962963, 0, 107, 'adventure')
# ('Lung ta - Cavalli al vento', 6.069212962962963, 0, 90, 'adventure')
# ("Le Vrai Kaizen (Vod // La Cacabox Monte L'everest - Grimkujow, Potatoz, Mnkway, Diego, Hugo)", 6.069212962962963, 0, 63, 'adventure')
# ('Eroi in crestere: Aventura celor 7 ani de acasa', 6.069212962962963, 0, 90, 'adventure')
# ('Amphibia: Endgame', 6.069212962962963, 0, 84, 'adventure')
# ('The Kingfish 2', 7.9, 11, 72, 'adventure')
# ('Sehnsucht nach Firdaws', 8.5, 6, 103, 'adventure')
# ('Jake Danger and the Sword of the Explorer', 6.069212962962963, 0, 90, 'adventure')
# ('Summer on a solitary beach', 6.069212962962963, 0, 100, 'adventure')
# ('Katarina, ili Doch razboynika', 6.069212962962963, 0, 157, 'adventure')
# ('Isola degli sguardi', 6.069212962962963, 0, 90, 'adventure')
# ('The Grand Stroke', 6.069212962962963, 0, 128, 'adventure')
# ('Demibook', 6.069212962962963, 0, 90, 'adventure')
# ('SITV Presents: Tabsentia', 6.069212962962963, 0, 80, 'adventure')
# ('Vandringen', 6.069212962962963, 0, 78, 'adventure')
# ('Anywhere Wherever', 6.069212962962963, 0, 46, 'adventure')
# ('New Day', 6.069212962962963, 0, 48, 'adventure')
# ('Les Nouveaux Candides', 6.069212962962963, 0, 90, 'adventure')
# ('NJPW SMP: The Movie', 6.069212962962963, 0, 50, 'adventure')
# ('Stunts I', 6.069212962962963, 0, 90, 'adventure')
# ("Five Nights at TK's: The Curse of TK", 6.069212962962963, 0, 60, 'adventure')
# ('My New Country Biacuimyneco', 6.069212962962963, 0, 95, 'adventure')
# ('Geo Magazine', 6.069212962962963, 0, 90, 'adventure')
# ('Son Though He Was: the Young Saint Francis of Assisi', 6.069212962962963, 0, 90, 'adventure')
# ('Captain Toad and the Mystery Mine', 6.069212962962963, 0, 77, 'adventure')
# ('My World 2', 6.069212962962963, 0, 90, 'adventure')
# ('Tripping', 6.069212962962963, 0, 90, 'adventure')
# ('The Final Kick', 6.069212962962963, 0, 10, 'adventure')
# ('Once upon a bridge in Vietnam', 6.069212962962963, 0, 52, 'adventure')
# ('7 Day Fast', 6.069212962962963, 0, 50, 'adventure')
# ('The Redemption of Zack & Heather (Remastered)', 6.069212962962963, 0, 90, 'adventure')
# ('I V Y: World of the Future', 6.069212962962963, 0, 90, 'adventure')
# ('Across America', 6.069212962962963, 0, 48, 'adventure')
# ('Kamilota', 6.069212962962963, 0, 90, 'adventure')
# ('The multiverse arc', 6.069212962962963, 0, 82, 'adventure')
# ('Boyz', 6.069212962962963, 0, 132, 'adventure')
# ("TAÏ: 33 jours dans la dernière forêt d'Afrique de l'Ouest", 6.069212962962963, 0, 90, 'adventure')
# ('Mouse Tales Movie 2', 6.069212962962963, 0, 60, 'adventure')
# ('Sur les Chemins du Temps', 6.069212962962963, 0, 90, 'adventure')
# ('Mystic Odyssey', 6.069212962962963, 0, 144, 'adventure')
# ('Dream of Resurrection', 6.069212962962963, 0, 95, 'adventure')
# ('Meorisogeul', 6.069212962962963, 0, 119, 'adventure')
# ('Spin War', 6.069212962962963, 0, 104, 'adventure')
# ('Exipsosi', 6.069212962962963, 0, 90, 'adventure')
# ('Phantom Lights: UAPs of the Forest', 6.069212962962963, 0, 81, 'adventure')
# ('The Wild Robot', 8.2, 175000, 102, 'animation')
# ('Mufasa: The Lion King', 6.6, 69000, 118, 'animation')
# ('Moana 2', 6.6, 107000, 100, 'animation')
# ('Flow', 7.9, 81000, 85, 'animation')
# ('Paddington in Peru', 6.7, 24000, 106, 'animation')
# ('Inside Out 2', 7.5, 220000, 96, 'animation')
# ('Transformers One', 7.6, 53000, 104, 'animation')
# ('Despicable Me 4', 6.2, 67000, 94, 'animation')
# ('IF', 6.4, 59000, 104, 'animation')
# ('The Day the Earth Blew Up: A Looney Tunes Movie', 7.0, 5100, 91, 'animation')
# ('The Lord of the Rings: The War of the Rohirrim', 6.3, 32000, 134, 'animation')
# ('Kung Fu Panda 4', 6.3, 70000, 94, 'animation')
# ('Memoir of a Snail', 7.8, 19000, 95, 'animation')
# ('Attack on Titan the Movie: The Last Attack', 9.2, 17000, 145, 'animation')
# ('The Garfield Movie', 5.7, 25000, 101, 'animation')
# ('Solo Leveling: ReAwakening', 8.8, 13000, 121, 'animation')
# ('Harold and the Purple Crayon', 5.7, 8700, 90, 'animation')
# ('Look Back', 7.8, 16000, 58, 'animation')
# ('Wallace & Gromit: Vengeance Most Fowl', 7.5, 36000, 82, 'animation')
# ('Spellbound', 5.5, 7700, 109, 'animation')
# ('Orion and the Dark', 6.3, 17000, 93, 'animation')
# ('Dan Da Dan: First Encounter', 8.2, 2800, 83, 'animation')
# ('Spermageddon', 5.6, 967, 80, 'animation')
# ('Watchmen: Chapter I', 7.1, 6900, 83, 'animation')
# ('The Remarkable Life of Ibelin', 8.2, 13000, 103, 'animation')
# ("Doraemon the Movie: Nobita's Earth Symphony", 6.6, 1600, 115, 'animation')
# ('Crayon Shin-chan: Our Dinosaur Diary', 6.6, 559, 106, 'animation')
# ('Justice League: Crisis on Infinite Earths - Part One', 6.2, 8700, 93, 'animation')
# ('The Most Precious of Cargoes', 7.1, 1300, 81, 'animation')
# ('Justice League: Crisis on Infinite Earths - Part Three', 6.1, 4700, 94, 'animation')
# ('Night of the Zoopocalypse', 6.0, 863, 91, 'animation')
# ('Megamind vs. The Doom Syndicate', 2.5, 5700, 83, 'animation')
# ('Piece by Piece', 6.9, 5800, 93, 'animation')
# ('That Christmas', 6.8, 17000, 91, 'animation')
# ('Haikyu!! The Dumpster Battle', 7.7, 6400, 85, 'animation')
# ('Justice League: Crisis on Infinite Earths - Part Two', 5.6, 5500, 94, 'animation')
# ('Demon Slayer: Kimetsu No Yaiba - To the Hashira Training', 7.2, 8700, 104, 'animation')
# ('Overlord: The Sacred Kingdom', 6.9, 1300, 135, 'animation')
# ('Thelma the Unicorn', 5.7, 3000, 93, 'animation')
# ('Watchmen: Chapter II', 7.1, 3300, 90, 'animation')
# ('The Colors Within', 7.1, 1100, 101, 'animation')
# ('Grand Theft Hamlet', 6.9, 2100, 89, 'animation')
# ('Ultraman: Rising', 6.9, 6500, 117, 'animation')
# ('Boys Go to Jupiter', 6.9, 108, 90, 'animation')
# ('White Snake: Afloat', 6.9, 534, 133, 'animation')
# ('The Glassworker', 7.3, 1900, 98, 'animation')
# ('Mars', 8.3, 23, 84, 'animation')
# ("My Hero Academia: You're Next", 7.0, 2500, 110, 'animation')
# ('Given 3: To the Sea', 7.9, 110, 80, 'animation')
# ('10 Lives', 5.9, 2000, 88, 'animation')
# ('Panda Bear in Africa', 5.5, 364, 84, 'animation')
# ('Hitpig', 5.1, 1000, 86, 'animation')
# ('Baki Hanma VS Kengan Ashura', 5.7, 2000, 62, 'animation')
# ('Mononoke the Movie: The Phantom in the Rain', 6.7, 1300, 89, 'animation')
# ('Blue Lock: Episode Nagi', 6.6, 2600, 91, 'animation')
# ('Dongeng Sang Kancil', 6.7, 207, 99, 'animation')
# ('Savages', 6.8, 377, 87, 'animation')
# ('Rebellious', 6.1, 226, 94, 'animation')
# ('Dragonkeeper', 5.7, 1800, 98, 'animation')
# ('Sabbath Queen', 8.0, 68, 105, 'animation')
# ('Diplodocus', 6.3, 193, 90, 'animation')
# ('Gracie and Pedro: Pets to the Rescue', 5.1, 283, 87, 'animation')
# ('Ghost Cat Anzu', 6.5, 844, 97, 'animation')
# ('Buffalo Kids', 6.6, 755, 93, 'animation')
# ('From Ground Zero', 7.9, 562, 112, 'animation')
# ('Dalia and the Red Book', 5.9, 140, 107, 'animation')
# ('Saving Bikini Bottom: The Sandy Cheeks Movie', 3.7, 4000, 82, 'animation')
# ('Johnny Puff: Secret Mission', 4.9, 458, 87, 'animation')
# ('I Am What I Am 2', 7.5, 260, 134, 'animation')
# ("The Tiger's Apprentice", 5.7, 2200, 84, 'animation')
# ('A Sloth Story', 5.6, 227, 90, 'animation')
# ('Detective Conan: The Million-Dollar Pentagram', 6.7, 1500, 111, 'animation')
# ('Woody Woodpecker Goes to Camp', 4.5, 2600, 100, 'animation')
# ('Limonov: The Ballad of Eddie', 5.9, 1000, 138, 'animation')
# ('Super-Charlie', 5.8, 156, 80, 'animation')
# ('200% Wolf', 5.9, 1300, 98, 'animation')
# ('Out of the Nest', 6.4, 119, 84, 'animation')
# ("Ryan's World the Movie: Titan Universe Adventure", 1.8, 713, 80, 'animation')
# ('The Night Before Christmas in Wonderland', 6.3, 527, 80, 'animation')
# ('Big City Greens the Movie: Spacecation', 6.2, 562, 83, 'animation')
# ('Frida', 7.5, 1500, 87, 'animation')
# ("Noah's Ark", 4.3, 687, 96, 'animation')
# ('Terra Incognita 1901', 5.4, 61, 78, 'animation')
# ("Re: Zero - Starting Life in Another World- Season 3 Episode 1 90-minute Special 'Theatrical Malice'", 8.7, 1200, 90, 'animation')
# ('No Time to Spy: A Loud House Movie', 6.3, 485, 81, 'animation')
# ('Dragon Ball Z Kai', 8.6, 79, 82, 'animation')
# ('The Proud Princess', 6.5, 133, 84, 'animation')
# ('My Oni Girl', 6.0, 1800, 112, 'animation')
# ('Norbert', 6.7, 15, 75, 'animation')
# ('Mochi-chon', 8.2, 10, 0, 'animation')
# ('Boonie Bears: Time Twist', 6.0, 174, 105, 'animation')
# ('My Freaky Family', 6.3, 419, 86, 'animation')
# ('Mobile Suit Gundam SEED Freedom', 6.6, 975, 124, 'animation')
# ('Niko: Beyond the Northern Lights', 6.2, 351, 86, 'animation')
# ("Peppa's Cinema Party", 4.9, 155, 65, 'animation')
# ('The Casagrandes Movie', 5.6, 687, 89, 'animation')
# ('Movie Given Hiiragi Mix.', 7.6, 213, 70, 'animation')
# ('Little Emma', 5.4, 129, 106, 'animation')
# ('The Lost Tiger', 7.9, 50, 90, 'animation')
# ('Storm Crashers', 6.2, 571, 88, 'animation')
# ('Monkey King: The Beginning', 9.6, 6, 0, 'animation')
# ('Living Large', 7.0, 154, 80, 'animation')
# ('Rafadan Tayfa: Kapadokya', 6.6, 129, 84, 'animation')
# ('The Quintessential Quintuplets Specials 2', 6.9, 147, 46, 'animation')
# ("Peppa Pig: Peppa's Adventures Around the World", 8.0, 7, 0, 'animation')
# ('Uma & Haggen: Mitos', 7.4, 53, 94, 'animation')
# ('The Big Trip 3: Race Around the World', 5.7, 66, 85, 'animation')
# ('Mariposas Negras', 7.2, 67, 83, 'animation')
# ('Fox & Hare Save the Forest', 5.9, 213, 71, 'animation')
# ('Nintama Rantaro Dokutake Ninja-tai Saikyou no Gunshi', 7.2, 32, 90, 'animation')
# ('Isla Monstro', 7.8, 10, 0, 'animation')
# ('Elli and the Ghostly Ghost Train', 5.0, 108, 86, 'animation')
# ('Die Heinzels: Neue Mützen, Neue Mission', 6.4, 102, 76, 'animation')
# ('Shrek 5: The Contract - A Fan Made Film', 7.2, 21, 84, 'animation')
# ('Appu', 8.5, 186, 92, 'animation')
# ('Into the Mortal World', 6.8, 171, 118, 'animation')
# ('Kid Santa', 6.625769230769232, 0, 78, 'animation')
# ('Uma Musume: Pretty Derby - Beginning of a New Era', 7.4, 145, 108, 'animation')
# ('Angelo dans la forêt mystérieuse', 6.0, 129, 81, 'animation')
# ('Sanatorium Under the Sign of the Hourglass', 5.4, 128, 75, 'animation')
# ('Trapezium', 6.2, 164, 95, 'animation')
# ('Bocchi the Rock! Recap Part 1', 7.5, 192, 90, 'animation')
# ('Bloody Escape: Bats out of Hell', 5.5, 57, 100, 'animation')
# ('Ya Boy Kongming! Road to Summer Sonia', 7.4, 40, 119, 'animation')
# ("Dead Dead Demon's Dededede Destruction", 7.1, 148, 120, 'animation')
# ('(S)KiDS', 8.6, 112, 85, 'animation')
# ('Kizumonogatari: Koyomi Vamp', 7.1, 102, 144, 'animation')
# ('Cille 2069', 7.1, 96, 0, 'animation')
# ('Exorcism Chronicles: The Beginning', 6.4, 123, 85, 'animation')
# ('Heartsping : Teenieping of Love', 7.1, 26, 0, 'animation')
# ('My Redneck Neighbor: Chapter 2 - Let the Games Begin', 6.6, 9, 55, 'animation')
# ("Transformers Prime: Galavatron's Revenge", 4.3, 14, 104, 'animation')
# ('Where the Robots Grow', 2.7, 523, 0, 'animation')
# ('Maya, donne-moi un titre', 6.4, 60, 61, 'animation')
# ('Inanimate Insanity II: The Movie', 8.3, 239, 106, 'animation')
# ('The Formula for Water', 4.6, 37, 86, 'animation')
# ('Kvitebjørn', 5.9, 74, 85, 'animation')
# ('Maxxie LaWow: Drag Super-shero', 8.7, 64, 114, 'animation')
# ('A Few Moments of Cheers', 7.2, 50, 68, 'animation')
# ('Fureru', 6.3, 38, 107, 'animation')
# ('Ivan Tsarevich i Seryy Volk 6', 5.7, 97, 85, 'animation')
# ('Rock Bottom', 6.4, 52, 86, 'animation')
# ('Bocchi the Rock! Recap Part 2', 7.4, 130, 77, 'animation')
# ('SuperKlaus', 4.3, 204, 88, 'animation')
# ('Zak & Wowo: The Legend of Lendarys', 5.7, 103, 85, 'animation')
# ('Tobias and the Arcane Merchant', 9.0, 45, 167, 'animation')
# ('Luntik. Vozvrashchenie domoy', 6.3, 79, 0, 'animation')
# ("Le parfum d'Irak", 8.0, 47, 95, 'animation')
# ('Taisu Xilie', 6.625769230769232, 0, 100, 'animation')
# ('Schirkoa: In Lies We Trust', 5.6, 162, 103, 'animation')
# ('The Storm', 6.0, 144, 102, 'animation')
# ('Woolina and the No Birds', 8.1, 50, 80, 'animation')
# ('Si Juki the Movie: Harta Pulau Monyet', 6.0, 127, 107, 'animation')
# ('STEVE (A Minecraft Movie)', 6.9, 12, 61, 'animation')
# ('God with Three Eyes', 5.7, 23, 112, 'animation')
# ('Fuuto PI: Portrait of Kamen Rider Skull', 7.5, 48, 82, 'animation')
# ('Jon Vardar protiv Galaksijata', 8.2, 77, 86, 'animation')
# ('TWST: Things We Said Today', 7.0, 62, 86, 'animation')
# ('Ganbatte Ikimasshoi', 5.2, 13, 95, 'animation')
# ('Hola Frida', 7.2, 35, 82, 'animation')
# ('Tay 2: Ebabil Takimi', 5.0, 44, 78, 'animation')
# ('Code Geass: Rozé of the Recapture - Part 1', 7.6, 42, 74, 'animation')
# ("DreadClub: Vampire's Verdict", 4.9, 62, 0, 'animation')
# ('PAPmusic - Animation for Fashion', 1.0, 163, 85, 'animation')
# ('Masha i Medved v kino: Park chudes', 7.4, 18, 58, 'animation')
# ('Double Tuckerr', 4.9, 1200, 120, 'animation')
# ('Robotia, the Movie', 7.6, 31, 86, 'animation')
# ('Kral Sakir: Devler Uyandi', 5.3, 69, 0, 'animation')
# ('Askepote', 3.5, 84, 72, 'animation')
# ("Yumi's Cells: The Movie", 6.2, 53, 93, 'animation')
# ('Quo Vadis', 6.4, 514, 90, 'animation')
# ("Dead Dead Demon's Dededede Destruction Zenpen", 7.1, 142, 120, 'animation')
# ('Mustafa', 6.9, 76, 75, 'animation')
# ('Bob a Bobek ve filmu: Na stope Mrkvojeda', 7.2, 32, 80, 'animation')
# ('The Summer of Mermaid', 7.9, 108, 0, 'animation')
# ('The Worlds Divide', 7.9, 40, 120, 'animation')
# ('Steal the Naughty List', 6.3, 126, 90, 'animation')
# ('Silex and the City, le film', 5.0, 52, 77, 'animation')
# ('Slocum et moi', 7.3, 77, 75, 'animation')
# ('Lilla spöket Laban spökar igen', 6.1, 29, 44, 'animation')
# ('Hello My Beautiful Creatures', 6.8, 173, 142, 'animation')
# ('Astra', 6.8, 8, 80, 'animation')
# ('Life with Quincy 3', 6.625769230769232, 0, 73, 'animation')
# ('Captain Avispa', 5.7, 180, 96, 'animation')
# ('Olivia & the Clouds', 7.3, 56, 81, 'animation')
# ("Nature Cat's Nature Movie Special Extraordinaire", 7.3, 19, 53, 'animation')
# ('Rocket Club: Across the Cosmos', 8.4, 19, 68, 'animation')
# ('Balentes', 6.625769230769232, 0, 70, 'animation')
# ('Rocky and Bullwinkle', 9.2, 15, 100, 'animation')
# ('Apocalypse Love', 6.4, 5, 0, 'animation')
# ('Return', 6.625769230769232, 0, 90, 'animation')
# ('Pui Pui Molcar the Movie: Molmax', 7.0, 9, 69, 'animation')
# ('Tri kota. Zimnie kanikuly', 6.6, 35, 65, 'animation')
# ('The Cheshire Cat', 6.625769230769232, 0, 64, 'animation')
# ('Benjamin Bat', 7.8, 33, 75, 'animation')
# ("Teacher's Pet", 5.4, 36, 0, 'animation')
# ('Motu Patlu & The Race to the Diamond Valley', 7.8, 28, 72, 'animation')
# ('Tri bogatyrya. Ni dnya bez podviga', 5.7, 71, 61, 'animation')
# ('The Fifth Element', 6.625769230769232, 0, 78, 'animation')
# ('Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik', 7.4, 75, 70, 'animation')
# ('Il segreto di Liberato', 7.3, 227, 90, 'animation')
# ('Love Live! Nijigasaki High School Idol Club Final Chapter Part 1', 7.4, 15, 59, 'animation')
# ('Inazuma Eleven Movie: The Legendary Kickoff', 8.3, 7, 0, 'animation')
# ('Transformers: 40th Anniversary Event', 7.4, 30, 96, 'animation')
# ('Becho', 7.2, 10, 0, 'animation')
# ('Riki Rhino: The Bird Kingdom', 5.1, 25, 109, 'animation')
# ('Dikkie Dik en de Verdwenen Knuffel', 7.3, 131, 62, 'animation')
# ('The Greatest Surf Movie in the Universe', 4.7, 9, 81, 'animation')
# ('Wonderful Precure! The Movie! Doki Doki Game no Sekai de Daiboken', 6.8, 36, 71, 'animation')
# ("Penelope & Everly's Holiday Adventure", 6.625769230769232, 0, 78, 'animation')
# ("Alex and Mia's Awesome Movie!!", 6.625769230769232, 0, 75, 'animation')
# ('Spider-Man: Blue', 5.8, 12, 0, 'animation')
# ('Kuramerukagari', 5.8, 84, 61, 'animation')
# ('Nie Xiaoqian', 6.2, 18, 112, 'animation')
# ('The Umbrella Fairy', 5.7, 61, 95, 'animation')
# ('Dinosaur Empire', 6.625769230769232, 0, 78, 'animation')
# ('Mobile Suit Gundam: Silver Phantom', 6.1, 13, 90, 'animation')
# ('Bread Barbershop: Celeb in Bakery Town', 6.625769230769232, 0, 77, 'animation')
# ('Pikmin Forever', 6.625769230769232, 0, 78, 'animation')
# ('Love and Friendship', 6.625769230769232, 0, 57, 'animation')
# ('Code Geass: Rozé of the Recapture: Part 2', 7.8, 28, 76, 'animation')
# ('Pleasant Goat and Big Big Wolf: The World Guardians', 6.6, 16, 96, 'animation')
# ('Adventures of Mickey Sherlock Mouse & Winnie the Pooh', 4.9, 12, 0, 'animation')
# ('Dinonauts', 6.625769230769232, 0, 77, 'animation')
# ('Motu Patlu & The Rise of Zombies', 6.6, 15, 74, 'animation')
# ('Max Beyond', 6.6, 18, 93, 'animation')
# ('Treasure Fellowship', 6.625769230769232, 0, 86, 'animation')
# ('Meitantei Conan Bâsasu Kaitô Kiddo', 6.1, 169, 81, 'animation')
# ('Arne Alligator och djungelkompisarna', 4.6, 49, 61, 'animation')
# ('Zuzubalândia: O Filme', 5.4, 11, 60, 'animation')
# ('Jin Ling Yu Mao', 7.8, 6, 97, 'animation')
# ('Shed 17 & Project G-1 the Movie', 6.625769230769232, 0, 85, 'animation')
# ('Rhythm of a Flower', 7.4, 15, 81, 'animation')
# ('Piril: Sayilarin Gizemi', 9.0, 67, 0, 'animation')
# ('Gintama the Movie 2D: Courtesan of the Nation Arc', 8.0, 9, 109, 'animation')
# ('Luv You Shankar', 5.8, 44, 120, 'animation')
# ("Marvel's Civil War Full Comic Dub Movie", 6.625769230769232, 0, 75, 'animation')
# ('Bigfoot in Wonderland', 6.625769230769232, 0, 61, 'animation')
# ('Code Geass: Rozé of the Recapture: Part 4', 6.6, 15, 70, 'animation')
# ('The Ballad of Straw Hat Sam', 9.1, 10, 45, 'animation')
# ...
# ('Triumf', 7.3, 9, 113, 'history')
# ('Ukku Satyagraham', 6.771806167400881, 0, 139, 'history')
# ('Ek Chilte Jol', 9.2, 13, 119, 'history')
# ("C'era una volta il Derby Club", 7.4, 17, 90, 'history')
# ('The Canal Map of Britain', 6.8, 10, 59, 'history')
# ('Krigsvarsleren', 7.8, 8, 55, 'history')
# ('O Último Papagaio de Timneh', 6.771806167400881, 0, 49, 'history')
# ('Zle smierci', 6.771806167400881, 0, 91, 'history')
# ('Testimoni del tempo', 6.771806167400881, 0, 91, 'history')
# ('Sivestan', 6.771806167400881, 0, 91, 'history')
# ('The Way of Internal Strength', 6.771806167400881, 0, 45, 'history')
# ('Al Kafi', 6.771806167400881, 0, 110, 'history')
# ('Zhambyl: New Era', 6.771806167400881, 0, 92, 'history')
# ('Nerah Documaentary Film', 6.771806167400881, 0, 91, 'history')
# ('Testimoni del tempo', 6.771806167400881, 0, 91, 'history')
# ('Area 2', 6.771806167400881, 0, 91, 'history')
# ('The Coastal Map of Britain', 6.771806167400881, 0, 60, 'history')
# ('Um Tempo de Todos', 6.771806167400881, 0, 132, 'history')
# ('Okufere', 6.771806167400881, 0, 91, 'history')
# ('Kabarettistinnen in der Weimarer Republik und im Dritten Reich', 6.771806167400881, 0, 90, 'history')
# ('Nancy & Bill: The Story Before Oliver Twist', 6.771806167400881, 0, 91, 'history')
# ('International Resonance of the April Uprising', 6.771806167400881, 0, 51, 'history')
# ('Drachten Journaals', 6.771806167400881, 0, 51, 'history')
# ('Twin Falls, 2001-2024', 6.771806167400881, 0, 180, 'history')
# ('Tatai Patara 1597', 6.771806167400881, 0, 70, 'history')
# ('On Air', 6.771806167400881, 0, 91, 'history')
# ('The Storm', 6.771806167400881, 0, 165, 'history')
# ("Le Temple d'Hatchepsout, Reine d'Egypte", 6.771806167400881, 0, 91, 'history')
# ('Andrew Trimble: For Ulster & Ireland', 6.771806167400881, 0, 91, 'history')
# ('Challengers', 7.0, 158000, 131, 'sport')
# ('Queen of the Ring', 6.4, 1900, 129, 'sport')
# ('The Fire Inside', 6.7, 2900, 109, 'sport')
# ('Arthur the King', 7.0, 35000, 107, 'sport')
# ('Under Paris', 5.2, 37000, 104, 'sport')
# ('Young Woman and the Sea', 7.5, 17000, 129, 'sport')
# ('Unstoppable', 6.8, 4400, 116, 'sport')
# ('Kill the Jockey', 6.4, 1800, 96, 'sport')
# ('You Gotta Believe', 5.8, 1400, 104, 'sport')
# ('Chandu Champion', 7.8, 34000, 142, 'sport')
# ('The Beautiful Game', 6.3, 8200, 125, 'sport')
# ('Haikyu!! The Dumpster Battle', 7.7, 6400, 85, 'sport')
# ('Uranus 2324', 6.4, 4900, 130, 'sport')
# ('Rez Ball', 6.3, 2600, 111, 'sport')
# ('Maidaan', 7.9, 23000, 181, 'sport')
# ('Race for Glory: Audi vs. Lancia', 5.8, 4900, 109, 'sport')
# ('Lubber Pandhu', 8.1, 6200, 146, 'sport')
# ('The Underdoggs', 5.6, 4600, 96, 'sport')
# ('Yolo', 6.9, 3800, 129, 'sport')
# ('Sweet Dreams', 5.4, 1500, 95, 'sport')
# ('Gundi: Legend of Love', 9.0, 5600, 166, 'sport')
# ('Baki Hanma VS Kengan Ashura', 5.7, 2000, 62, 'sport')
# ('Blue Lock: Episode Nagi', 6.6, 2600, 91, 'sport')
# ('Sixty Minutes', 5.7, 5200, 88, 'sport')
# ('The Swedish Torpedo', 6.3, 192, 120, 'sport')
# ('Diving Into the Darkness', 9.1, 84, 96, 'sport')
# ('My Sunshine', 7.0, 1400, 100, 'sport')
# ('Cup', 8.6, 82, 146, 'sport')
# ('Hayatla Baris', 6.3, 391, 125, 'sport')
# ('El Harifa 2: El Remontada', 6.4, 466, 130, 'sport')
# ('Boxer', 6.4, 1400, 150, 'sport')
# ('Mond', 7.0, 296, 92, 'sport')
# ('Bionic', 4.3, 1700, 110, 'sport')
# ('Little Wing', 6.1, 947, 100, 'sport')
# ('Mr. & Mrs. Mahi', 5.9, 16000, 139, 'sport')
# ('Vijay 69', 6.1, 1200, 112, 'sport')
# ('Balestra', 5.1, 538, 145, 'sport')
# ('Federer: Twelve Final Days', 7.3, 4200, 88, 'sport')
# ('Giannis: The Marvelous Journey', 8.3, 1800, 109, 'sport')
# ('Crakk: Jeetega... Toh Jiyegaa', 4.7, 6500, 154, 'sport')
# ('Samia', 6.8, 151, 102, 'sport')
# ('Havnaa', 7.1, 277, 110, 'sport')
# ('Color of Victory', 6.1, 40000, 157, 'sport')
# ('My Annoying Brother', 7.4, 274, 114, 'sport')
# ('Alpha.', 6.9, 256, 100, 'sport')
# ('The Champion', 5.5, 905, 106, 'sport')
# ('Untold: The Murder of Air McNair', 5.6, 2100, 57, 'sport')
# ('The Final: Attack on Wembley', 6.3, 2500, 82, 'sport')
# ('Lal Salaam', 4.4, 1300, 150, 'sport')
# ('El Hareefa', 6.8, 1100, 117, 'sport')
# ('Free Falling', 5.2, 300, 89, 'sport')
# ('Wingless', 7.3, 186, 110, 'sport')
# ('Uma Musume: Pretty Derby - Beginning of a New Era', 7.4, 145, 108, 'sport')
# ('Las super estrellas de la lucha libre', 8.8, 55, 98, 'sport')
# ('Concussed: The American Dream', 7.8, 43, 0, 'sport')
# ('Ski', 7.7, 70, 95, 'sport')
# ('The Miranda Brothers', 4.4, 191, 99, 'sport')
# ('Blue Star', 6.9, 1600, 166, 'sport')
# ('Memes & Nightmares', 5.7, 90, 81, 'sport')
# ('Nasty', 7.7, 1100, 103, 'sport')
# ('Off the Line', 8.6, 17, 0, 'sport')
# ('Pegasus 2', 6.9, 1300, 121, 'sport')
# ('Minor Leaguer', 5.1, 93, 77, 'sport')
# ('Champions of the Golden Valley', 9.2, 76, 81, 'sport')
# ('First Class: Full Speed!', 7.0, 334, 0, 'sport')
# ('Sunshine', 7.3, 64, 91, 'sport')
# ('Swamiji Club', 6.891566265060241, 0, 88, 'sport')
# ('Grace by Night', 7.1, 25, 0, 'sport')
# ('Undisputed', 6.8, 106, 64, 'sport')
# ('Return to the Ring', 5.4, 733, 106, 'sport')
# ('The Tale of Texas Pool', 7.8, 79, 0, 'sport')
# ('Kulej. Dwie strony medalu', 6.4, 337, 148, 'sport')
# ('Pierce', 6.5, 144, 109, 'sport')
# ('Keluar Main 1994', 7.8, 55, 112, 'sport')
# ('Topuria Matador', 7.2, 168, 95, 'sport')
# ('4 Zéros', 3.6, 150, 105, 'sport')
# ('Friendly Fire', 5.3, 65, 105, 'sport')
# ('Nayab', 7.4, 269, 153, 'sport')
# ('GG (Good Game)', 5.9, 80, 100, 'sport')
# ('EFC', 7.7, 1200, 87, 'sport')
# ('Pay Dirt: The Story of Supercross', 6.891566265060241, 0, 91, 'sport')
# ('Fuchsia Libre', 4.9, 60, 112, 'sport')
# ('Fight Like a Girl', 8.2, 19, 118, 'sport')
# ('Unbreakable: England 2003', 8.1, 38, 66, 'sport')
# ('Gold', 7.7, 75, 126, 'sport')
# ('Anytime', 8.9, 25, 62, 'sport')
# ('Challenger', 5.6, 179, 95, 'sport')
# ('Lyod 3', 6.0, 311, 134, 'sport')
# ('Final Heat', 3.8, 214, 83, 'sport')
# ('Knock Out Blonde: The Kellie Maloney Story', 6.0, 23, 90, 'sport')
# ('Padu', 5.1, 81, 97, 'sport')
# ("It's All Over: The Kiss That Changed Spanish Football", 6.9, 639, 95, 'sport')
# ('Game Changers', 4.7, 232, 78, 'sport')
# ('Dabaru', 8.9, 651, 131, 'sport')
# ('Numéro 10', 5.3, 51, 91, 'sport')
# ('I am Al Ittihad', 4.9, 230, 90, 'sport')
# ('Home Plate', 6.891566265060241, 0, 85, 'sport')
# ('Salty Amazons', 6.891566265060241, 0, 32, 'sport')
# ('A Horse Named Winx', 8.7, 99, 117, 'sport')
# ('Runaway Wrestler', 7.6, 16, 105, 'sport')
# ('See Her Be Her', 7.1, 27, 110, 'sport')
# ('Inazuma Eleven Movie: The Legendary Kickoff', 8.3, 7, 0, 'sport')
# ('Harimau Malaya: The Untold Journey', 8.2, 23, 125, 'sport')
# ("Argentina '78", 7.1, 209, 0, 'sport')
# ('Daley', 7.8, 180, 102, 'sport')
# ('Ice Aged', 7.0, 8, 110, 'sport')
# ('La valanga azzurra', 7.6, 11, 90, 'sport')
# ('Loser is Winner', 8.1, 554, 0, 'sport')
# ('The Unbreakable Tatiana Suarez', 6.6, 171, 78, 'sport')
# ('Tracing the Divide', 8.8, 173, 84, 'sport')
# ('Patang', 6.891566265060241, 0, 88, 'sport')
# ('Nos Amours: The Saga of the Montreal Expos', 6.2, 23, 92, 'sport')
# ('V de Victor', 5.2, 77, 100, 'sport')
# ('In Inima Nationalei', 7.8, 200, 103, 'sport')
# ('All American', 9.6, 18, 87, 'sport')
# ('Clash of Dynasties: St. Edward vs Walsh Jesuit', 6.891566265060241, 0, 88, 'sport')
# ('Puffing Iron', 7.5, 20, 98, 'sport')
# ('Linford', 7.3, 149, 89, 'sport')
# ('Parviz Khan', 5.9, 216, 110, 'sport')
# ('Dolly: Story of a Warrior', 6.891566265060241, 0, 88, 'sport')
# ('Graciano Rocchigiani - Das Herz eines Boxers', 9.2, 51, 123, 'sport')
# ('The Spoils: Selling the Future of American Basketball', 6.8, 7, 87, 'sport')
# ('Gabru Gang', 8.7, 214, 123, 'sport')
# ('DitO', 4.4, 23, 117, 'sport')
# ('The Streak', 6.891566265060241, 0, 87, 'sport')
# ('Together: 4-in-a-Row', 6.4, 68, 92, 'sport')
# ('Il tempo è ancora nostro', 6.891566265060241, 0, 88, 'sport')
# ('Below the Rim', 5.0, 16, 89, 'sport')
# ('Trailblazers', 6.4, 18, 38, 'sport')
# ('1600 Meter', 6.891566265060241, 0, 106, 'sport')
# ('Hatching Eagles', 6.9, 23, 63, 'sport')
# ("UFC 299: O'Malley vs. Vera 2", 7.4, 83, 180, 'sport')
# ("Bartali's Bicycle", 7.5, 8, 80, 'sport')
# ('Qajymuqan', 4.8, 5, 0, 'sport')
# ('Take the Steps', 8.3, 74, 83, 'sport')
# ('The Netflix Slam', 7.2, 147, 150, 'sport')
# ('Volare più in alto', 6.891566265060241, 0, 51, 'sport')
# ('Fedya. Narodnyy futbolist', 6.0, 130, 125, 'sport')
# ('Battle of the Baddest', 6.1, 94, 61, 'sport')
# ('Deathgrip 2', 6.891566265060241, 0, 59, 'sport')
# ('Giroud', 6.4, 25, 80, 'sport')
# ('Fútbol desde el corazón', 6.891566265060241, 0, 90, 'sport')
# ('Rafa Márquez: El Capitán', 6.6, 199, 82, 'sport')
# ('For the Love of Basketball', 6.891566265060241, 0, 88, 'sport')
# ('Grudge', 6.891566265060241, 0, 104, 'sport')
# ('Ping pang nan hai', 7.1, 19, 108, 'sport')
# ('Ice Cross: Life on the Edge', 8.5, 16, 90, 'sport')
# ('Hai, Romania!', 8.1, 426, 98, 'sport')
# ('Welcome to the J-Rod Show', 6.891566265060241, 0, 44, 'sport')
# ('Khapsyhyy', 5.4, 7, 90, 'sport')
# ('V potoke trekh stikhiy', 5.2, 42, 85, 'sport')
# ('Top Rider', 6.891566265060241, 0, 84, 'sport')
# ('Rylan: Homophobia, Football & Me', 5.5, 24, 0, 'sport')
# ('Beta Squad vs AMP Charity Match 2024', 6.891566265060241, 0, 210, 'sport')
# ('Quote 10.35', 8.0, 24, 35, 'sport')
# ('Traineras, pasión por el remo', 6.0, 7, 0, 'sport')
# ('Nema ne mogu', 6.891566265060241, 0, 54, 'sport')
# ('Gyakorlat teszi a mestert', 6.1, 15, 46, 'sport')
# ('Eclipse', 9.4, 84, 79, 'sport')
# ('Roman Kostomarov. Rozhdennyy dvazhdy', 6.891566265060241, 0, 77, 'sport')
# ('Passion of Iron', 9.3, 18, 0, 'sport')
# ('The Incredibles', 9.3, 116, 0, 'sport')
# ('Basketball Jones: The First Chapter', 6.891566265060241, 0, 88, 'sport')
# ('A Game of Two Halves', 7.3, 24, 100, 'sport')
# ('87 Candles', 9.0, 10, 55, 'sport')
# ('Beyond the Podium: Celebrating Canadian Women Champions', 6.891566265060241, 0, 88, 'sport')
# ('Big Water Theory', 6.891566265060241, 0, 83, 'sport')
# ('Vincenzo Nibali - Il 7° campione', 6.891566265060241, 0, 52, 'sport')
# ('Surf on, Europe!', 7.5, 25, 92, 'sport')
# ('Rhythm Masters: A Mickey Hart Experience', 7.3, 23, 0, 'sport')
# ('Welcome Back', 7.4, 5, 119, 'sport')
# ('UFC 303: Pereira vs. Prochazka 2', 6.4, 71, 195, 'sport')
# ('¡Qué suerte hemos tenido!', 7.5, 16, 62, 'sport')
# ('EL DESAFÍO IMPOSIBLE: LA CUMBRE DE LOS 7000 METROS', 6.891566265060241, 0, 88, 'sport')
# ('Episodes: Ukraine at the World Cup (2024)', 8.1, 72, 79, 'sport')
# ('Veljko od mora', 7.2, 16, 53, 'sport')
# ('Senza volto - Storia di Fabrizio Maiello', 6.891566265060241, 0, 99, 'sport')
# ('The Next Centimeter', 7.5, 35, 26, 'sport')
# ('Inazuma Eleven the Movie: Prologue to the New Heroes', 6.891566265060241, 0, 88, 'sport')
# ('Golpe a Golpe (Blow by Blow)', 8.1, 23, 90, 'sport')
# ('UFC 308: Topuria vs. Holloway in COSM Shared Reality', 6.891566265060241, 0, 88, 'sport')
# ('UFC 309: Jones vs. Miocic in COSM Shared Reality', 6.891566265060241, 0, 88, 'sport')
# ('Ice Fishing Hardcore: On the Road', 9.6, 7, 0, 'sport')
# ('I Am Kevin Harvick', 9.1, 17, 0, 'sport')
# ('Rising Tennis Star Meloni Jones', 6.891566265060241, 0, 88, 'sport')
# ("Secrets of Women's Mat Wrestling", 6.891566265060241, 0, 60, 'sport')
# ('I am the girl 2 and my black belt', 6.891566265060241, 0, 122, 'sport')
# ('Until the end', 6.891566265060241, 0, 88, 'sport')
# ('Dare to Dream', 6.891566265060241, 0, 114, 'sport')
# ('Quest for the Shield', 9.2, 12, 112, 'sport')
# ("UFC 306: O'Malley vs. Dvalishvili in COSM Shared Reality", 6.891566265060241, 0, 88, 'sport')
# ('O Fenômeno eSports', 6.891566265060241, 0, 88, 'sport')
# ('Za predelami. Snezhnye psy', 6.891566265060241, 0, 72, 'sport')
# ('Phantom of the Ice', 7.6, 735, 0, 'sport')
# ('Sportzal', 6.891566265060241, 0, 65, 'sport')
# ('La vida en rojo', 6.891566265060241, 0, 64, 'sport')
# ('UNDERDROGS: a League of Ireland Story', 6.891566265060241, 0, 30, 'sport')
# ('A Piece of Home', 6.891566265060241, 0, 88, 'sport')
# ('UFC 304: Edwards vs. Muhammad 2', 6.0, 73, 200, 'sport')
# ('Altitude FC: Rising Together', 6.891566265060241, 0, 88, 'sport')
# ('Choices & Decisions', 6.891566265060241, 0, 74, 'sport')
# ('The Road to OVC Champions', 6.891566265060241, 0, 62, 'sport')
# ('Peleamos', 8.7, 26, 0, 'sport')
# ('More Than a Whistle', 6.891566265060241, 0, 88, 'sport')
# ('Emirates NBA Cup in COSM Shared Reality', 6.891566265060241, 0, 88, 'sport')
# ('Freedom Shred: A Juneteenth Declaration', 6.891566265060241, 0, 55, 'sport')
# ('Faster: Only one lap', 6.9, 24, 90, 'sport')
# ('Twitch', 6.891566265060241, 0, 88, 'sport')
# ('Wölfinnen - Die Jagd nach dem Triple', 6.891566265060241, 0, 93, 'sport')
# ('UFC 297: Strickland vs. du Plessis', 6.3, 64, 180, 'sport')
# ('Wave Warriors IV', 6.891566265060241, 0, 88, 'sport')
# ('Za predelami. Semdesyat pervyy', 6.891566265060241, 0, 74, 'sport')
# ('Transitalia Marathon International Classic Motorbike Challenge', 6.891566265060241, 0, 88, 'sport')
# ('Fencing for the Edge', 6.891566265060241, 0, 75, 'sport')
# ('Snow Going Back: Comic Relief v the Arctic', 6.891566265060241, 0, 59, 'sport')
# ('Paulsbyen: Verdensmester', 6.891566265060241, 0, 88, 'sport')
# ('8 secondes', 6.891566265060241, 0, 89, 'sport')
# ('9 Hao Chuan Qi', 6.891566265060241, 0, 88, 'sport')
# ('Fotbollsåret 2023', 6.891566265060241, 0, 88, 'sport')
# ('Hard 90 to Home', 6.891566265060241, 0, 46, 'sport')
# ("Prost itinéraire, d'une légende", 6.891566265060241, 0, 88, 'sport')
# ('Gaffer', 6.891566265060241, 0, 88, 'sport')
# ('Not Just A Shot: A Disc Golf Story', 6.891566265060241, 0, 59, 'sport')
# ('Athletes of War', 6.891566265060241, 0, 95, 'sport')
# ('Champions in May', 6.891566265060241, 0, 127, 'sport')
# ('Triumf', 7.3, 9, 113, 'sport')
# ('Zlatan Ibrahimovic hyllningsmatch (Sweden vs Serbia)', 6.6, 6, 170, 'sport')
# ('UFC 302: Makhachev vs. Poirier', 6.7, 96, 180, 'sport')
# ('Za predelami. Nad vodoy', 6.891566265060241, 0, 67, 'sport')
# ('A La Fin du Film - Real Madrid v Bayern Münich', 6.891566265060241, 0, 48, 'sport')
# ('Is University Really Worth It?', 5.1, 12, 60, 'sport')
# ('Chava. El ciclista del pueblo', 6.5, 13, 0, 'sport')
# ('Me to stahy sti fanela', 6.891566265060241, 0, 48, 'sport')
# ('Phoenix: A Purdue Basketball Story', 6.891566265060241, 0, 82, 'sport')
# ('Gangwon 2024 Winter Youth Olympics - Closing Ceremony', 6.891566265060241, 0, 88, 'sport')
# ('Za predelami. Ostavit sled', 6.891566265060241, 0, 80, 'sport')
# ('El Chilote: Gloria del Béisbol Dominicano', 6.891566265060241, 0, 75, 'sport')
# ('The Path Full of Stars', 6.891566265060241, 0, 60, 'sport')
# ('Ocoee Rafting Trip Pilot', 6.891566265060241, 0, 55, 'sport')
# ('Sport Gives Back Awards 2024', 6.891566265060241, 0, 70, 'sport')
# ('Obseassion', 6.891566265060241, 0, 32, 'sport')
# ('Nine: The Big Break', 6.891566265060241, 0, 88, 'sport')
# ('Gangwon 2024 Winter Youth Olympics - Opening Ceremony', 6.891566265060241, 0, 88, 'sport')
# ('Invicta FC 59: Bernardo vs. Maia', 6.891566265060241, 0, 88, 'sport')
# ('Drachten Journaals', 6.891566265060241, 0, 51, 'sport')
# ('Rafting Middle Ocoee River with Melissa', 6.891566265060241, 0, 125, 'sport')
# ('Not That NB', 6.891566265060241, 0, 88, 'sport')
# ('The IV Crown Showdown Final Press Conference', 6.891566265060241, 0, 114, 'sport')
# ('Seamus', 6.891566265060241, 0, 62, 'sport')
# ("TAÏ: 33 jours dans la dernière forêt d'Afrique de l'Ouest", 6.891566265060241, 0, 88, 'sport')
# ('Surfin Estate', 6.891566265060241, 0, 88, 'sport')
# ('Cold Brew', 6.891566265060241, 0, 22, 'sport')
# ('Go! Snails', 6.891566265060241, 0, 90, 'sport')
# ('Ligure sa Trebevica', 6.891566265060241, 0, 54, 'sport')
# ('Being 500 A Professional Wrestling Documentary', 6.891566265060241, 0, 88, 'sport')
# ('Rafting with Alex Ocoee Middle', 6.891566265060241, 0, 47, 'sport')
# ('Sculpting and Flowing with Marikah', 6.891566265060241, 0, 88, 'sport')
# ('CZW: Tournament of Death 21', 6.891566265060241, 0, 88, 'sport')
# ('Atlético Marbella. Aquel Fútbol de los 90', 6.891566265060241, 0, 88, 'sport')
# ('Mais Fortes', 6.891566265060241, 0, 54, 'sport')
# ('11 Brothers: The Movie', 6.891566265060241, 0, 88, 'sport')
# ('Kick Start', 6.891566265060241, 0, 88, 'sport')
# ('Natural Selection Tour 2024', 6.891566265060241, 0, 88, 'sport')
# ('Leuchtend Schwarz - Sturm und der Weg zum Double', 6.891566265060241, 0, 88, 'sport')
# ('1984: 40 Years Strong and True', 6.891566265060241, 0, 88, 'sport')

# %%
# Printing each row of imdb table
query = "select * from imdb"
cursor.execute(query)
for data in cursor:
    print(data)
# Out:
# ('Gladiator II', 6.5, 246000, 148, 'adventure')
# ('Dune: Part Two', 8.5, 637000, 166, 'adventure')
# ('Twisters', 6.5, 174000, 122, 'adventure')
# ('Kraven the Hunter', 5.5, 61000, 127, 'adventure')
# ('Deadpool & Wolverine', 7.5, 503000, 128, 'adventure')
# ('Venom: The Last Dance', 6.0, 126000, 110, 'adventure')
# ('Mufasa: The Lion King', 6.6, 69000, 118, 'adventure')
# ('Moana 2', 6.6, 107000, 100, 'adventure')
# ('Flow', 7.9, 81000, 85, 'adventure')
# ('The Count of Monte-Cristo', 7.6, 37000, 178, 'adventure')
# ('Sonic the Hedgehog 3', 6.9, 63000, 110, 'adventure')
# ('Furiosa: A Mad Max Saga', 7.5, 289000, 148, 'adventure')
# ('Paddington in Peru', 6.7, 24000, 106, 'adventure')
# ('Freaky Tales', 6.2, 6400, 107, 'adventure')
# ('Inside Out 2', 7.5, 220000, 96, 'adventure')
# ('The Unholy Trinity', 6.06921, 0, 93, 'adventure')
# ('Borderlands', 4.7, 50000, 101, 'adventure')
# ('Transformers One', 7.6, 53000, 104, 'adventure')
# ('Bad Boys: Ride or Die', 6.5, 102000, 115, 'adventure')
# ('Despicable Me 4', 6.2, 67000, 94, 'adventure')
# ('The Return', 6.2, 9800, 116, 'adventure')
# ('Godzilla x Kong: The New Empire', 6.0, 123000, 115, 'adventure')
# ('Kingdom of the Planet of the Apes', 6.8, 154000, 145, 'adventure')
# ('The Day the Earth Blew Up: A Looney Tunes Movie', 7.0, 5100, 91, 'adventure')
# ('The Lord of the Rings: The War of the Rohirrim', 6.3, 32000, 134, 'adventure')
# ('Damsel', 6.1, 111000, 110, 'adventure')
# ('Ghostbusters: Frozen Empire', 6.1, 95000, 115, 'adventure')
# ('Red One', 6.3, 142000, 123, 'adventure')
# ('Kung Fu Panda 4', 6.3, 70000, 94, 'adventure')
# ('Spaceman', 5.7, 44000, 107, 'adventure')
# ('Attack on Titan the Movie: The Last Attack', 9.2, 17000, 145, 'adventure')
# ('Uglies', 4.7, 33000, 100, 'adventure')
# ('The Garfield Movie', 5.7, 25000, 101, 'adventure')
# ('Solo Leveling: ReAwakening', 8.8, 13000, 121, 'adventure')
# ('Harold and the Purple Crayon', 5.7, 8700, 90, 'adventure')
# ('Sketch', 8.3, 63, 92, 'adventure')
# ('Arthur the King', 7.0, 35000, 107, 'adventure')
# ('Atlas', 5.6, 57000, 118, 'adventure')
# ('Wallace & Gromit: Vengeance Most Fowl', 7.5, 36000, 82, 'adventure')
# ('Kalki 2898 AD', 7.0, 67000, 180, 'adventure')
# ('Survive', 4.6, 2900, 90, 'adventure')
# ('Monster Summer', 5.7, 4000, 97, 'adventure')
# ('My Penguin Friend', 6.8, 5600, 97, 'adventure')
# ('Rebel Moon - Part Two: The Scargiver', 5.3, 60000, 122, 'adventure')
# ('Descendants: The Rise of Red', 4.7, 7200, 91, 'adventure')
# ('Spellbound', 5.5, 7700, 109, 'adventure')
# ('Sasquatch Sunset', 5.4, 5500, 88, 'adventure')
# ('Manjummel Boys', 8.2, 28000, 135, 'adventure')
# ('Lost on a Mountain in Maine', 6.1, 1400, 98, 'adventure')
# ('Orion and the Dark', 6.3, 17000, 93, 'adventure')
# ('Saint-Exupéry', 5.4, 453, 98, 'adventure')
# ('No Way Up', 4.6, 11000, 90, 'adventure')
# ('River of Blood', 5.1, 1900, 86, 'adventure')
# ('Family Pack', 5.5, 9400, 94, 'adventure')
# ('The Goat Life', 7.1, 48000, 173, 'adventure')
# ("Doraemon the Movie: Nobita's Earth Symphony", 6.6, 1600, 115, 'adventure')
# ('Crayon Shin-chan: Our Dinosaur Diary', 6.6, 559, 106, 'adventure')
# ('Justice League: Crisis on Infinite Earths - Part One', 6.2, 8700, 93, 'adventure')
# ('Winner', 6.5, 2600, 103, 'adventure')
# ('Badland Hunters', 5.9, 13000, 107, 'adventure')
# ('The Best Christmas Pageant Ever', 6.8, 6200, 99, 'adventure')
# ('Justice League: Crisis on Infinite Earths - Part Three', 6.1, 4700, 94, 'adventure')
# ('Escape from the 21st Century', 6.4, 971, 98, 'adventure')
# ('Sunlight', 7.8, 24, 96, 'adventure')
# ('Night of the Zoopocalypse', 6.0, 863, 91, 'adventure')
# ('Megamind vs. The Doom Syndicate', 2.5, 5700, 83, 'adventure')
# ('The Wages of Fear', 4.6, 4200, 104, 'adventure')
# ('Kaizen', 7.1, 717, 160, 'adventure')
# ("Son's Will", 7.4, 1000, 148, 'adventure')
# ('That Christmas', 6.8, 17000, 91, 'adventure')
# ('Bookworm', 6.0, 2000, 103, 'adventure')
# ('Escape', 6.4, 2200, 94, 'adventure')
# ('Justice League: Crisis on Infinite Earths - Part Two', 5.6, 5500, 94, 'adventure')
# ('Demon Slayer: Kimetsu No Yaiba - To the Hashira Training', 7.2, 8700, 104, 'adventure')
# ('Overlord: The Sacred Kingdom', 6.9, 1300, 135, 'adventure')
# ('Cult Killer', 4.8, 2800, 105, 'adventure')
# ('The Empire', 5.2, 1300, 110, 'adventure')
# ('Thelma the Unicorn', 5.7, 3000, 93, 'adventure')
# ('I, the Executioner', 6.3, 1900, 118, 'adventure')
# ('Golden Kamuy', 6.3, 2600, 127, 'adventure')
# ('Ultraman: Rising', 6.9, 6500, 117, 'adventure')
# ('Something in the Water', 4.1, 4900, 86, 'adventure')
# ('Unspeakable: Beyond the Wall of Sleep', 5.9, 63, 90, 'adventure')
# ('At Her Feet', 7.2, 50, 100, 'adventure')
# ("My Hero Academia: You're Next", 7.0, 2500, 110, 'adventure')
# ('Hanu Man', 7.7, 29000, 158, 'adventure')
# ('A.R.M', 7.1, 8900, 150, 'adventure')
# ('The Price of Money: A Largo Winch Adventure', 5.1, 1200, 100, 'adventure')
# ("Devil's Knight", 5.3, 955, 90, 'adventure')
# ('Lumina', 2.2, 692, 113, 'adventure')
# ('Bureau 749', 4.0, 568, 123, 'adventure')
# ('Seeds', 4.9, 209, 82, 'adventure')
# ('Panda Bear in Africa', 5.5, 364, 84, 'adventure')
# ('Bambi: A Tale of Life in the Woods', 5.6, 231, 78, 'adventure')
# ('Hitpig', 5.1, 1000, 86, 'adventure')
# ('No Chains No Masters', 6.3, 637, 98, 'adventure')
# ('The Courier', 6.0, 4500, 101, 'adventure')
# ('Sixty Minutes', 5.7, 5200, 88, 'adventure')
# ('A Legend', 4.7, 980, 129, 'adventure')
# ('Operation Blood Hunt', 3.5, 505, 93, 'adventure')
# ('Dongeng Sang Kancil', 6.7, 207, 99, 'adventure')
# ('Anaconda', 4.9, 657, 84, 'adventure')
# ('Formed Police Unit', 4.7, 1300, 120, 'adventure')
# ('The Firing Squad', 5.1, 5100, 93, 'adventure')
# ('Rebellious', 6.1, 226, 94, 'adventure')
# ('The Twisters', 2.5, 370, 86, 'adventure')
# ('Operation: Raqqa', 5.6, 283, 107, 'adventure')
# ('Dragonkeeper', 5.7, 1800, 98, 'adventure')
# ('Diplodocus', 6.3, 193, 90, 'adventure')
# ('Kanguva', 4.5, 15000, 152, 'adventure')
# ('Gracie and Pedro: Pets to the Rescue', 5.1, 283, 87, 'adventure')
# ('The Mountain', 6.6, 163, 89, 'adventure')
# ('Diving Into the Darkness', 9.1, 84, 96, 'adventure')
# ('Thangalaan', 6.5, 6700, 156, 'adventure')
# ('The Last Redemption', 6.8, 5200, 122, 'adventure')
# ('Buffalo Kids', 6.6, 755, 93, 'adventure')
# ('Dalia and the Red Book', 5.9, 140, 107, 'adventure')
# ('Saving Bikini Bottom: The Sandy Cheeks Movie', 3.7, 4000, 82, 'adventure')
# ('Robin and the Hoods', 4.3, 537, 100, 'adventure')
# ('Gladiators', 4.6, 106, 95, 'adventure')
# ('Empire Queen: The Golden Age of Magic', 3.2, 214, 148, 'adventure')
# ("The Tiger's Apprentice", 5.7, 2200, 84, 'adventure')
# ('Now or Never!', 2.2, 17000, 0, 'adventure')
# ('A Sloth Story', 5.6, 227, 90, 'adventure')
# ('Woody Woodpecker Goes to Camp', 4.5, 2600, 100, 'adventure')
# ('Autumn and the Black Jaguar', 5.6, 1000, 100, 'adventure')
# ('Angels Fallen: Warriors of Peace', 4.8, 5800, 103, 'adventure')
# ('Five Friends', 6.7, 944, 112, 'adventure')
# ('Cells at Work!', 6.7, 336, 109, 'adventure')
# ('Treasure Trackers', 5.8, 169, 92, 'adventure')
# ('200% Wolf', 5.9, 1300, 98, 'adventure')
# ('Never Look Away', 7.2, 282, 85, 'adventure')
# ('WWII: Operation Phoenix', 5.8, 98, 106, 'adventure')
# ('Naa Saami Ranga', 4.5, 1200, 150, 'adventure')
# ('Roadkill', 3.7, 690, 90, 'adventure')
# ('Kalvan', 5.6, 989, 142, 'adventure')
# ('Bade Miyan Chote Miyan', 3.7, 39000, 163, 'adventure')
# ('Man and Witch: The Dance of a Thousand Steps', 5.5, 343, 94, 'adventure')
# ('Big City Greens the Movie: Spacecation', 6.2, 562, 83, 'adventure')
# ('The Kingdom', 7.0, 131, 133, 'adventure')
# ('Return to Wickensburg', 5.2, 39, 88, 'adventure')
# ('Bionic', 4.3, 1700, 110, 'adventure')
# ('The Last Ronin', 4.9, 591, 115, 'adventure')
# ('The Last of Us: Immunity', 4.2, 29, 64, 'adventure')
# ("Noah's Ark", 4.3, 687, 96, 'adventure')
# ('War of the Worlds: Extinction', 3.0, 211, 84, 'adventure')
# ('Seven Seas Seven Hills', 8.5, 94, 90, 'adventure')
# ('Eat the Night', 6.0, 544, 106, 'adventure')
# ('Guest from the Future', 6.0, 1200, 141, 'adventure')
# ('No Time to Spy: A Loud House Movie', 6.3, 485, 81, 'adventure')
# ('Un lío de millones', 5.3, 248, 91, 'adventure')
# ('Dragon Ball Z Kai', 8.6, 79, 82, 'adventure')
# ('Mong Vuot', 5.0, 166, 96, 'adventure')
# ('My Oni Girl', 6.0, 1800, 112, 'adventure')
# ('School of Magical Animals 3', 5.8, 338, 105, 'adventure')
# ('This Too Shall Pass', 9.1, 17, 105, 'adventure')
# ('Marianengraben', 7.3, 92, 87, 'adventure')
# ("The Magician's Raincoat", 5.6, 125, 0, 'adventure')
# ('Chuck Billy and the Marvelous Guava Tree', 7.4, 1200, 90, 'adventure')
# ('The Keepers of the 5 Kingdoms', 4.0, 225, 109, 'adventure')
# ('Going Viral', 8.3, 300, 90, 'adventure')
# ('Pimpinero: Blood and Oil', 5.6, 568, 121, 'adventure')
# ('Era Oculta', 6.06921, 0, 80, 'adventure')
# ('My Freaky Family', 6.3, 419, 86, 'adventure')
# ('Mobile Suit Gundam SEED Freedom', 6.6, 975, 124, 'adventure')
# ('Niko: Beyond the Northern Lights', 6.2, 351, 86, 'adventure')
# ('Road Wars: Max Fury', 2.0, 365, 83, 'adventure')
# ('Barroz: Guardian of Treasures', 3.4, 1000, 155, 'adventure')
# ('The Casagrandes Movie', 5.6, 687, 89, 'adventure')
# ('The Waves of Madness', 5.9, 94, 68, 'adventure')
# ('Witch Hunter', 5.0, 25, 80, 'adventure')
# ('Ayalaan', 5.9, 4000, 155, 'adventure')
# ('Rally Caps', 5.5, 142, 100, 'adventure')
# ('Meanwhile on Earth', 6.0, 944, 89, 'adventure')
# ('One Million Babes BC', 2.1, 87, 75, 'adventure')
# ('Gaami', 6.3, 2000, 147, 'adventure')
# ('The Backrooms', 8.2, 15, 63, 'adventure')
# ('Ice Maiden', 8.6, 79, 90, 'adventure')
# ('Little Emma', 5.4, 129, 106, 'adventure')
# ('Sam and Colby: The Legends of the Paranormal', 4.8, 314, 98, 'adventure')
# ('Alpha.', 6.9, 256, 100, 'adventure')
# ('Buddy', 3.8, 355, 137, 'adventure')
# ('The Goat', 5.9, 386, 91, 'adventure')
# ('The Lost Tiger', 7.9, 50, 90, 'adventure')
# ('Storm Crashers', 6.2, 571, 88, 'adventure')
# ('The Adventures of Jurassic Pet: Return to the Wild', 5.5, 73, 90, 'adventure')
# ('Spiders on a Plane', 4.9, 379, 78, 'adventure')
# ('All for One', 1.4, 675, 97, 'adventure')
# ('Captain Miller', 6.9, 11000, 157, 'adventure')
# ('The Blinkless', 7.3, 14, 59, 'adventure')
# ('Z-Mom', 5.0, 46, 90, 'adventure')
# ('The Big Trip 3: Race Around the World', 5.7, 66, 85, 'adventure')
# ("My Fathers' Daughter", 6.5, 82, 78, 'adventure')
# ('Teenz', 4.4, 866, 122, 'adventure')
# ('Chhota Bheem and the Curse of Damyaan', 4.8, 2300, 145, 'adventure')
# ('Ghost Island', 7.4, 50, 95, 'adventure')
# ('Planetquake', 3.0, 319, 85, 'adventure')
# ('Major Grom: The Game', 6.1, 1900, 168, 'adventure')
# ('The Phantom Warrior', 2.4, 556, 119, 'adventure')
# ('Fox & Hare Save the Forest', 5.9, 213, 71, 'adventure')
# ('Space Ranger', 3.4, 81, 0, 'adventure')
# ('Nintama Rantaro Dokutake Ninja-tai Saikyou no Gunshi', 7.2, 32, 90, 'adventure')
# ('Elli and the Ghostly Ghost Train', 5.0, 108, 86, 'adventure')
# ('Stinky Summer', 5.6, 55, 90, 'adventure')
# ('Next to Us', 4.8, 228, 125, 'adventure')
# ('Earthquake Underground', 3.3, 201, 83, 'adventure')
# ('Oculus', 6.0, 15, 113, 'adventure')
# ('Shrek 5: The Contract - A Fan Made Film', 7.2, 21, 84, 'adventure')
# ('Appu', 8.5, 186, 92, 'adventure')
# ('Mr Zoo Keeper', 8.3, 17, 0, 'adventure')
# ('Jurassic Triangle', 2.4, 287, 84, 'adventure')
# ('The Epidemic', 5.9, 71, 95, 'adventure')
# ('The Secret of Pin-Up Island', 7.4, 97, 107, 'adventure')
# ('Its Name Was Mormo', 3.6, 123, 93, 'adventure')
# ('I Heart Robots', 4.6, 2400, 76, 'adventure')
# ('Tanning Zone', 6.06921, 0, 90, 'adventure')
# ('Taklee Genesis x Worlds Collide', 5.4, 426, 146, 'adventure')
# ('Trifole', 7.5, 59, 100, 'adventure')
# ('Dünya Varmis', 6.6, 65, 100, 'adventure')
# ('Molar', 6.06921, 0, 117, 'adventure')
# ('Game On', 2.6, 357, 85, 'adventure')
# ('The Traveller', 5.2, 212, 134, 'adventure')
# ("Luigi's Mansion", 6.2, 19, 60, 'adventure')
# ('Bull Shark 3', 3.5, 91, 76, 'adventure')
# ("Dead Dead Demon's Dededede Destruction", 7.1, 148, 120, 'adventure')
# ('Odio el verano', 5.1, 605, 103, 'adventure')
# ('Memes & Nightmares', 5.7, 90, 81, 'adventure')
# ('Ahl Al Kahf', 5.3, 281, 120, 'adventure')
# ('The Epic of Gilgamesh', 6.06921, 0, 79, 'adventure')
# ('Warrior Awang and Master Tok Gajah', 4.6, 481, 118, 'adventure')
# ('A Trip Elsewhere', 5.5, 109, 93, 'adventure')
# ('My Redneck Neighbor: Chapter 2 - Let the Games Begin', 6.6, 9, 55, 'adventure')
# ('Kodaikanal', 9.2, 70, 173, 'adventure')
# ('Vertical', 5.2, 146, 111, 'adventure')
# ("Transformers Prime: Galavatron's Revenge", 4.3, 14, 104, 'adventure')
# ('Death Game', 6.3, 26, 88, 'adventure')
# ('Birds Flying East', 5.8, 594, 100, 'adventure')
# ('Maya, donne-moi un titre', 6.4, 60, 61, 'adventure')
# ('Kvitebjørn', 5.9, 74, 85, 'adventure')
# ('I Left My Heart in Colombia', 8.7, 419, 0, 'adventure')
# ('Killer Witches from Outer Space', 6.9, 80, 0, 'adventure')
# ('Kiyma: Orman Kanunlari', 3.9, 40, 81, 'adventure')
# ('Tapori Nayak', 8.6, 19, 0, 'adventure')
# ('Ivan Tsarevich i Seryy Volk 6', 5.7, 97, 85, 'adventure')
# ("Peter Brook's the Mahabharata (8K)", 6.06921, 0, 173, 'adventure')
# ('LasseMajas detektivbyrå - Maskoten som försvann', 6.0, 62, 90, 'adventure')
# ('Bremenskie muzykanty', 4.6, 691, 115, 'adventure')
# ('Amazon Bullseye', 5.2, 216, 113, 'adventure')
# ('Zak & Wowo: The Legend of Lendarys', 5.7, 103, 85, 'adventure')
# ('Letuchiy korabl', 3.8, 303, 100, 'adventure')
# ('Rocky Road to Berlin', 7.2, 1500, 104, 'adventure')
# ('Tales from the Table', 6.06921, 0, 90, 'adventure')
# ('Hain', 2.9, 49, 95, 'adventure')
# ('Powder Pup', 6.1, 78, 89, 'adventure')
# ('Iron Dusk', 5.5, 19, 0, 'adventure')
# ('Spirit Riser', 6.6, 37, 98, 'adventure')
# ('Sentinelese', 6.06921, 0, 90, 'adventure')
# ('Duffle Bag Boy', 6.8, 60, 0, 'adventure')
# ('Güzel Bir Rüya', 4.6, 47, 79, 'adventure')
# ('Si Juki the Movie: Harta Pulau Monyet', 6.0, 127, 107, 'adventure')
# ("Triple 7: They Said It Couldn't Be Done", 8.5, 14, 97, 'adventure')
# ('Tokusou Sentai Dekaranger 20th: Fireball Booster', 7.2, 36, 50, 'adventure')
# ('STEVE (A Minecraft Movie)', 6.9, 12, 61, 'adventure')
# ('Water Park', 6.06921, 0, 25, 'adventure')
# ('StarGazer: The Need of the Many', 5.0, 11, 47, 'adventure')
# ('Oscar Wilde About America', 4.2, 33, 98, 'adventure')
# ('Samaya bolshaya luna', 2.5, 137, 105, 'adventure')
# ('Igrisca ne damo!', 7.1, 30, 79, 'adventure')
# ('Fuuto PI: Portrait of Kamen Rider Skull', 7.5, 48, 82, 'adventure')
# ('Game of Death: The Six Doors to Hell', 6.06921, 0, 145, 'adventure')
# ('Tulang Belulang Tulang', 7.1, 50, 95, 'adventure')
# ('Friendly Fire', 5.3, 65, 105, 'adventure')
# ('Dogman Territory: Werewolves in the Land Between the Lakes', 5.6, 35, 0, 'adventure')
# ('Mr. Blue Shirt: The Inspiration', 4.8, 10, 0, 'adventure')
# ('The Slave and the Sorcerer', 6.7, 42, 86, 'adventure')
# ('The Star City Murders', 4.1, 145, 79, 'adventure')
# ('Seeking the King', 6.06921, 0, 90, 'adventure')
# ('Art Work', 6.06921, 0, 91, 'adventure')
# ('Yolki 11', 4.7, 177, 92, 'adventure')
# ('Tay 2: Ebabil Takimi', 5.0, 44, 78, 'adventure')
# ('My Redneck Neighbor: Chapter 1 - The Rednecks Are Coming', 6.4, 10, 74, 'adventure')
# ('Ognivo', 5.5, 238, 105, 'adventure')
# ('Son of the Wolf', 6.06921, 0, 82, 'adventure')
# ('Permafrost', 5.7, 115, 80, 'adventure')
# ('76 Days Adrift', 6.06921, 0, 105, 'adventure')
# ('Kade', 6.3, 17, 92, 'adventure')
# ('Mountain Boy', 8.3, 28, 93, 'adventure')
# ('Finding Christmas', 6.3, 14, 0, 'adventure')
# ('Masha i Medved v kino: Park chudes', 7.4, 18, 58, 'adventure')
# ('Kral Sakir: Devler Uyandi', 5.3, 69, 0, 'adventure')
# ('Askepote', 3.5, 84, 72, 'adventure')
# ("Surge of Power: Where There's Smoke", 6.5, 13, 68, 'adventure')
# ("Dead Dead Demon's Dededede Destruction Zenpen", 7.1, 142, 120, 'adventure')
# ('Two Breaths', 7.9, 34, 18, 'adventure')
# ('The Worlds Divide', 7.9, 40, 120, 'adventure')
# ('Steal the Naughty List', 6.3, 126, 90, 'adventure')
# ('The Trail', 7.8, 38, 80, 'adventure')
# ('Arctic Hollow', 2.3, 184, 70, 'adventure')
# ('Anytime', 8.9, 25, 62, 'adventure')
# ('Silex and the City, le film', 5.0, 52, 77, 'adventure')
# ('Nanoshark', 5.3, 21, 0, 'adventure')
# ('Cazatesoros', 6.4, 29, 106, 'adventure')
# ('Baba Yaga spasaet Novyy god', 4.4, 122, 99, 'adventure')
# ('Six Nine Five (695)', 7.0, 706, 137, 'adventure')
# ('Tipppsy', 8.1, 33, 115, 'adventure')
# ('Shadows of Betrayal: Chronicles of Ian Blair', 7.5, 14, 65, 'adventure')
# ('Håkan Bråkan 2', 5.3, 142, 92, 'adventure')
# ('Turma da Mônica Jovem: Reflexos do Medo', 2.8, 259, 88, 'adventure')
# ('Life with Quincy 3', 6.06921, 0, 73, 'adventure')
# ('Daye: Seret ahl el Daye', 7.9, 18, 104, 'adventure')
# ('Poklad', 4.6, 44, 100, 'adventure')
# ('Colour Palette', 9.4, 52, 87, 'adventure')
# ('Captain Avispa', 5.7, 180, 96, 'adventure')
# ("Nature Cat's Nature Movie Special Extraordinaire", 7.3, 19, 53, 'adventure')
# ('Satu - Year of the Rabbit', 9.1, 58, 93, 'adventure')
# ('Orango', 7.3, 75, 94, 'adventure')
# ('Dreams', 6.9, 9, 106, 'adventure')
# ('Family Vacation', 6.6, 6, 0, 'adventure')
# ('Gepack', 6.6, 368, 97, 'adventure')
# ('The Forest', 6.3, 49, 77, 'adventure')
# ('Chernyy zamok', 4.9, 56, 115, 'adventure')
# ('Rocky and Bullwinkle', 9.2, 15, 100, 'adventure')
# ('Bar MoskvaChiki', 5.1, 106, 91, 'adventure')
# ('Return', 6.06921, 0, 90, 'adventure')
# ('Pui Pui Molcar the Movie: Molmax', 7.0, 9, 69, 'adventure')
# ('Tri kota. Zimnie kanikuly', 6.6, 35, 65, 'adventure')
# ('Benjamin Bat', 7.8, 33, 75, 'adventure')
# ('Wilhelm Gustloff', 8.7, 9, 110, 'adventure')
# ('Lion King: A Tale of Mufasa', 6.06921, 0, 90, 'adventure')
# ('Fights Break Sphere 3', 5.0, 11, 81, 'adventure')
# ('Gladiator II: The Art and Making of the Ridley Scott Film', 6.06921, 0, 90, 'adventure')
# ('Road to Dreamland', 6.06921, 0, 90, 'adventure')
# ('Yaren Leylek', 5.6, 33, 95, 'adventure')
# ('Shanghai Story', 8.2, 64, 71, 'adventure')
# ('Troy the Bharat Putra', 5.5, 33, 134, 'adventure')
# ('Tri bogatyrya. Ni dnya bez podviga', 5.7, 71, 61, 'adventure')
# ('Il cammino: Viaggio in Calabria', 6.06921, 0, 58, 'adventure')
# ('Wonderland', 6.8, 13, 120, 'adventure')
# ('Heavens: The Boy and His Robot', 6.3, 22, 98, 'adventure')
# ('Moy dikiy drug', 6.5, 63, 100, 'adventure')
# ('Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik', 7.4, 75, 70, 'adventure')
# ('Get Close 2', 5.7, 47, 0, 'adventure')
# ('Beyond existence', 4.1, 23, 95, 'adventure')
# ('Advent', 7.5, 6, 119, 'adventure')
# ('Die Chaosschwestern und Pinguin Paul', 5.6, 73, 100, 'adventure')
# ('QAnon Avenue', 10.0, 7, 57, 'adventure')
# ('Stranded Pearl', 6.0, 27, 90, 'adventure')
# ('Cândido', 6.3, 63, 99, 'adventure')
# ('Dikkie Dik en de Verdwenen Knuffel', 7.3, 131, 62, 'adventure')
# ('Wonderful Precure! The Movie! Doki Doki Game no Sekai de Daiboken', 6.8, 36, 71, 'adventure')
# ('Mama', 8.5, 7, 100, 'adventure')
# ("Penelope & Everly's Holiday Adventure", 6.06921, 0, 90, 'adventure')
# ('Tur s Ivanushkami', 5.3, 162, 111, 'adventure')
# ('Joachim and the Apocalypse', 7.5, 16, 90, 'adventure')
# ("Alex and Mia's Awesome Movie!!", 6.06921, 0, 75, 'adventure')
# ('Spider-Man: Blue', 5.8, 12, 0, 'adventure')
# ('Oro Negro', 6.06921, 0, 90, 'adventure')
# ('Uttarakaanda', 6.06921, 0, 90, 'adventure')
# ('Jathara', 6.2, 1100, 129, 'adventure')
# ('The Space in Between', 6.06921, 0, 90, 'adventure')
# ('Xibalba Monster', 6.7, 31, 76, 'adventure')
# ('The Very Last Christmas', 8.6, 12, 75, 'adventure')
# ('The Umbrella Fairy', 5.7, 61, 95, 'adventure')
# ('Manyunya. Priklyucheniya v Moskve', 5.7, 111, 87, 'adventure')
# ('Dünya Mali: Eksi Bir', 7.2, 18, 133, 'adventure')
# ('Mobile Suit Gundam: Silver Phantom', 6.1, 13, 90, 'adventure')
# ('Operation Wakaliga: Fate and Blood', 6.7, 11, 66, 'adventure')
# ('Fallen Leaves, Broken Lighters', 7.7, 8, 96, 'adventure')
# ('Famous Patrick (A Super SpongeBob Fan Movie)', 4.9, 29, 53, 'adventure')
# ('The Apples Gang: The Movie by Wright', 6.06921, 0, 90, 'adventure')
# ('The Yoshi Movie', 7.9, 14, 105, 'adventure')
# ('The Last Five Days: The Freak Building', 3.7, 59, 61, 'adventure')
# ("Dans l'ombre de Marlow", 6.06921, 0, 80, 'adventure')
# ('Elephant Steps', 6.9, 41, 0, 'adventure')
# ('Manyunya. Priklyucheniya v derevne', 5.8, 121, 84, 'adventure')
# ('Piraty galaktiki Barrakuda', 4.6, 86, 92, 'adventure')
# ('Dragon Gate Inn', 6.06921, 0, 90, 'adventure')
# ('Goodbye Hamdi', 6.2, 11, 85, 'adventure')
# ('BAM!', 7.0, 30, 80, 'adventure')
# ('Petualangan Anak Penangkap Hantu', 5.9, 27, 99, 'adventure')
# ('Boom!', 8.3, 11, 90, 'adventure')
# ('Tracing the Divide', 8.8, 173, 84, 'adventure')
# ('23 Horas', 7.0, 21, 0, 'adventure')
# ('The Eye of the Salamander', 8.4, 21, 81, 'adventure')
# ("Yasmeen's Element", 7.6, 21, 76, 'adventure')
# ('Spooky Society', 6.06921, 0, 90, 'adventure')
# ('Abudeka Is Back', 5.3, 40, 120, 'adventure')
# ('Moy lyubimyy chempion', 2.3, 420, 95, 'adventure')
# ('Vikaasaparva', 8.7, 542, 134, 'adventure')
# ('The Bigfoot Prophecy', 4.8, 23, 117, 'adventure')
# ('Banana Boat', 5.5, 21, 78, 'adventure')
# ('Hope & Glory', 6.6, 148, 44, 'adventure')
# ('Militant Monster 2024', 8.7, 29, 0, 'adventure')
# ('Treasure Fellowship', 6.06921, 0, 86, 'adventure')
# ('The Cold Father', 6.8, 19, 0, 'adventure')
# ('Pirates & Slaves', 5.8, 6, 53, 'adventure')
# ('No More Trouble - Cosa rimane di una tempesta', 8.6, 20, 97, 'adventure')
# ('Historia de pastores', 5.5, 34, 80, 'adventure')
# ('Zoloto Umalty', 4.9, 114, 109, 'adventure')
# ('Target Jeremy', 6.06921, 0, 90, 'adventure')
# ('Jaunt', 8.7, 8, 78, 'adventure')
# ("Lakeside's Mission: Impossible", 6.06921, 0, 90, 'adventure')
# ('The Sasqualogist', 6.06921, 0, 89, 'adventure')
# ('Minecraft But I Survive Again in Parkour Civilization', 9.0, 30, 0, 'adventure')
# ('Xin Longmen kezhan', 2.9, 7, 73, 'adventure')
# ('Knight', 6.06921, 0, 90, 'adventure')
# ('Adam i Eva', 5.1, 96, 95, 'adventure')
# ('This Land of Mine', 5.5, 11, 90, 'adventure')
# ('The Last Survivor', 6.06921, 0, 115, 'adventure')
# ('Abar Arownne Din Ratri', 8.0, 8, 111, 'adventure')
# ('Gumshoe Jon and the Mystery of the Saucer Men - The Even Better Version', 6.06921, 0, 90, 'adventure')
# ('Bratya', 2.7, 129, 103, 'adventure')
# ('Cursed Waters: Creature of Lake Okanagan', 6.06921, 0, 90, 'adventure')
# ('Oyunda Kal: Eglence Arenasi', 2.5, 38, 92, 'adventure')
# ('De Legende van Familie Vos', 5.7, 59, 81, 'adventure')
# ('Old Wild Mob', 6.06921, 0, 90, 'adventure')
# ('Toy Kids: The Movie', 6.06921, 0, 65, 'adventure')
# ('The Lost Colony', 6.06921, 0, 90, 'adventure')
# ('The Ballad of Straw Hat Sam', 9.1, 10, 45, 'adventure')
# ('Mai Martaba', 4.8, 10, 86, 'adventure')
# ('The Artifact', 6.06921, 0, 108, 'adventure')
# ('Cacophony the Animated Movie', 6.06921, 0, 81, 'adventure')
# ('Chyortov kamen', 4.4, 21, 105, 'adventure')
# ('Príncipe Lu e a Lenda do Dragão', 4.1, 29, 90, 'adventure')
# ('The Puffins & the Magic Portal', 7.7, 32, 0, 'adventure')
# ('The 9th Raider', 6.06921, 0, 105, 'adventure')
# ('Changle Zhen Gui Shi', 6.06921, 0, 88, 'adventure')
# ('Mesken (Messuage)', 7.3, 43, 102, 'adventure')
# ('A Christmas Carol', 9.8, 11, 39, 'adventure')
# ('Lo carga el diablo', 7.5, 28, 103, 'adventure')
# ('Adrian', 6.06921, 0, 90, 'adventure')
# ('Mera Number Beess', 6.06921, 0, 109, 'adventure')
# ('Robo Puffin', 6.06921, 0, 90, 'adventure')
# ('Hyacinthe', 6.06921, 0, 90, 'adventure')
# ('Commonheart. from A Childish Mind.', 6.06921, 0, 83, 'adventure')
# ('Il ricercatore', 6.4, 9, 71, 'adventure')
# ('The Pray', 6.06921, 0, 90, 'adventure')
# ('The Same Picture Group Holiday Special', 6.06921, 0, 55, 'adventure')
# ('The Farm', 6.06921, 0, 104, 'adventure')
# ('Jackpot', 6.06921, 0, 90, 'adventure')
# ('Emma', 6.06921, 0, 90, 'adventure')
# ('The Pizza Guys', 6.06921, 0, 89, 'adventure')
# ('Skazochnyy patrul. Shou prodolzhayetsya', 7.2, 11, 65, 'adventure')
# ('The Age Mate', 6.06921, 0, 87, 'adventure')
# ('Vasilisa i khraniteli vremeni', 3.1, 70, 98, 'adventure')
# ('Suchana', 8.7, 511, 90, 'adventure')
# ('Luccas e Gi em: Dinossauros', 3.5, 28, 91, 'adventure')
# ('La Familia del Barrio: La Película', 4.5, 7, 0, 'adventure')
# ("The Dragon's Tomb", 6.8, 52, 77, 'adventure')
# ('Lost and Found', 6.06921, 0, 60, 'adventure')
# ('V potoke trekh stikhiy', 5.2, 42, 85, 'adventure')
# ('The Embers of Domsheria', 6.06921, 0, 95, 'adventure')
# ('Dandelion', 8.9, 9, 95, 'adventure')
# ('Longe da Estrada', 6.0, 9, 68, 'adventure')
# ('Unhappy 25 Years Little Brat', 6.06921, 0, 90, 'adventure')
# ('The Lion Dog', 6.06921, 0, 122, 'adventure')
# ('Turbozavry. God drakona', 9.2, 43, 48, 'adventure')
# ('The Stand at Alder Creek', 6.06921, 0, 53, 'adventure')
# ('Dushu', 6.06921, 0, 96, 'adventure')
# ('Novyy god v Beryozovke', 7.1, 100, 94, 'adventure')
# ('Montserrat, Integral 107', 6.06921, 0, 85, 'adventure')
# ('I racconti del mare', 6.06921, 0, 89, 'adventure')
# ('Aliens Uncovered: Buried Cities & Lost Tribes', 8.8, 11, 0, 'adventure')
# ('Carjorski Clan: Tale of the Fallen Knight', 6.06921, 0, 90, 'adventure')
# ('Nijari', 6.06921, 0, 106, 'adventure')
# ('Tinpot & Yello', 6.06921, 0, 51, 'adventure')
# ('Kage & Celeste', 6.06921, 0, 69, 'adventure')
# ('Superman: Jubilation', 6.06921, 0, 176, 'adventure')
# ('The Long Quiet', 6.06921, 0, 94, 'adventure')
# ('Wild Boys', 6.06921, 0, 119, 'adventure')
# ('Bernadotte, Louise & Napoleon', 6.06921, 0, 74, 'adventure')
# ('Filmmaker', 6.06921, 0, 97, 'adventure')
# ('One Day the Movie', 6.06921, 0, 90, 'adventure')
# ('Applepictures the Poseidon Legacy', 6.4, 19, 84, 'adventure')
# ('Qianhe xiansheng', 6.06921, 0, 82, 'adventure')
# ('Wheelies Inc', 6.06921, 0, 90, 'adventure')
# ('LUDA', 7.2, 6, 86, 'adventure')
# ('Frankenstein Theater: The Magic Sword', 4.1, 24, 82, 'adventure')
# ('Big Water Theory', 6.06921, 0, 83, 'adventure')
# ('Antarctic Voyage', 6.8, 6, 48, 'adventure')
# ('Women, Dreams and Bread', 6.06921, 0, 90, 'adventure')
# ('Xiang Xi Gui Shi', 6.06921, 0, 72, 'adventure')
# ('The Lost Coast', 6.06921, 0, 90, 'adventure')
# ('Deux hommes un destin', 6.06921, 0, 94, 'adventure')
# ('Altered', 6.06921, 0, 90, 'adventure')
# ('Sathur: Part1', 6.06921, 0, 90, 'adventure')
# ('Piri Reis: The Incredible Chart', 7.0, 27, 138, 'adventure')
# ('Psycho Rhythm', 6.06921, 0, 90, 'adventure')
# ('Mortadella', 8.4, 8, 90, 'adventure')
# ('Purgatorio', 6.06921, 0, 59, 'adventure')
# ('Lajjpal', 9.0, 8, 252, 'adventure')
# ('Novogodniy ekspress', 8.5, 8, 47, 'adventure')
# ('Mult v kino. Vypusk # 168: Idyom na piknik!', 6.06921, 0, 51, 'adventure')
# ("Whites Only: Ade's Extremist Adventure", 7.0, 27, 65, 'adventure')
# ("Let's Go! Anpanman: Baikinman and Lulun", 6.5, 7, 64, 'adventure')
# ('Nothing Unusual', 8.8, 13, 92, 'adventure')
# ('Le mystère de Waza', 6.06921, 0, 90, 'adventure')
# ('A New Dawn', 6.06921, 0, 60, 'adventure')
# ('La bruja del bosque oscuro', 6.06921, 0, 92, 'adventure')
# ('The Road Long', 6.06921, 0, 90, 'adventure')
# ('Lapse', 6.06921, 0, 90, 'adventure')
# ('Poymay sobaku, esli smozhesh', 3.5, 39, 96, 'adventure')
# ('Ngesot', 4.8, 18, 87, 'adventure')
# ('Suvorovets 1944', 3.3, 27, 90, 'adventure')
# ('Tayna Chyornoy Ruki', 5.7, 24, 84, 'adventure')
# ('The Ghost of Annie Lee', 4.8, 5, 103, 'adventure')
# ('YA - medved', 5.0, 61, 97, 'adventure')
# ('Soul Trekkers', 6.06921, 0, 90, 'adventure')
# ('Dracu Ra', 5.6, 41, 106, 'adventure')
# ('A Babá - Operação Game Over', 4.9, 11, 0, 'adventure')
# ('Isle: Alpha One', 8.4, 7, 97, 'adventure')
# ('DCLXVI', 6.06921, 0, 200, 'adventure')
# ('Mukhadrakon', 5.3, 18, 109, 'adventure')
# ('Pra Sempre', 6.06921, 0, 75, 'adventure')
# ('The Bigfoot prophecy 2', 6.06921, 0, 118, 'adventure')
# ('Kyle and the Last Emerald 2', 8.4, 9, 15, 'adventure')
# ('Aruanda - Sentido da Vida', 6.06921, 0, 90, 'adventure')
# ('I am the girl 3 me and my girlfriend', 6.06921, 0, 90, 'adventure')
# ('Tobia e i colori del mondo', 4.2, 6, 0, 'adventure')
# ('Huaquero Tierra Maldita', 6.06921, 0, 90, 'adventure')
# ('Harmonie', 6.06921, 0, 74, 'adventure')
# ('Analogistan', 6.06921, 0, 85, 'adventure')
# ("Florp's Solar Vacation", 6.06921, 0, 2, 'adventure')
# ("I'm Professional", 3.7, 8, 95, 'adventure')
# ('Pueblo En Llamas', 6.06921, 0, 82, 'adventure')
# ('Unscripted - In the Heart of Africa', 6.06921, 0, 82, 'adventure')
# ('Fat Chance! the Movie', 7.6, 6, 0, 'adventure')
# ('Emu War: A Subtle Examination of the Sheer Caucasity of Colonialism', 6.06921, 0, 90, 'adventure')
# ('El Regreso Del Campero 3', 6.06921, 0, 81, 'adventure')
# ('Mult v kino. Vypusk # 174. Dobrye dela!', 6.06921, 0, 48, 'adventure')
# ('My Only Relative.', 6.06921, 0, 105, 'adventure')
# ('The Puffins: Arctic Games', 6.06921, 0, 90, 'adventure')
# ('The Road to OVC Champions', 6.06921, 0, 62, 'adventure')
# ("L'Elisir di Leonardo da Vinci e la Banda del Buffardello", 6.06921, 0, 90, 'adventure')
# ('The Veyshal Movie', 6.06921, 0, 120, 'adventure')
# ('Katzie in Marokko', 6.06921, 0, 90, 'adventure')
# ('EP Break the Multiverse', 6.06921, 0, 76, 'adventure')
# ('Upanga Kingdom', 6.06921, 0, 115, 'adventure')
# ('Bragow', 6.06921, 0, 120, 'adventure')
# ('Okhota na russkogo geniya', 5.1, 12, 71, 'adventure')
# ('ABC Life: The Movie', 6.06921, 0, 60, 'adventure')
# ('Moving Targets', 6.06921, 0, 90, 'adventure')
# ('Lost & Found', 6.06921, 0, 90, 'adventure')
# ('The Brofessors Return', 6.06921, 0, 78, 'adventure')
# ('Yan Hu Ji Hua', 6.06921, 0, 90, 'adventure')
# ('Bear Kid: Super Hero', 6.06921, 0, 80, 'adventure')
# ('The Seed', 6.06921, 0, 100, 'adventure')
# ("Melissa's Birthday", 6.06921, 0, 90, 'adventure')
# ('Ba Jie', 6.06921, 0, 90, 'adventure')
# ('Salem, SOS-ed!', 6.06921, 0, 91, 'adventure')
# ('Gostya iz kosmosa', 8.7, 7, 70, 'adventure')
# ('Road to Paradise', 6.06921, 0, 76, 'adventure')
# ('Marraia', 6.06921, 0, 77, 'adventure')
# ('Project Block', 6.06921, 0, 66, 'adventure')
# ('The Moon Asks for Help', 6.06921, 0, 96, 'adventure')
# ('PW V: Tears of the Fallen', 8.2, 11, 60, 'adventure')
# ('Kleurenpalet 3: De Definitie Van Het Multiversum', 6.06921, 0, 77, 'adventure')
# ('Selebryata', 3.8, 20, 93, 'adventure')
# ('Non succederà più', 6.06921, 0, 90, 'adventure')
# ('The Koopas', 6.06921, 0, 90, 'adventure')
# ('Cobrazilla', 6.06921, 0, 60, 'adventure')
# ('Madeline & Silverfrost', 6.06921, 0, 90, 'adventure')
# ('One in a million chance', 6.06921, 0, 70, 'adventure')
# ('Dream 1', 6.06921, 0, 90, 'adventure')
# ('Oda: Vlucht door de Eeuwen', 6.4, 7, 0, 'adventure')
# ('Beyaz Zenciler: Yapim Asamasi', 8.6, 5, 55, 'adventure')
# ('Hasta Que Nos Encontremos De Neuvo', 6.06921, 0, 90, 'adventure')
# ('Línguas de Fogo', 6.06921, 0, 69, 'adventure')
# ('Maverick from the Edge', 6.06921, 0, 107, 'adventure')
# ('Lung ta - Cavalli al vento', 6.06921, 0, 90, 'adventure')
# ("Le Vrai Kaizen (Vod // La Cacabox Monte L'everest - Grimkujow, Potatoz, Mnkway, Diego, Hugo)", 6.06921, 0, 63, 'adventure')
# ('Eroi in crestere: Aventura celor 7 ani de acasa', 6.06921, 0, 90, 'adventure')
# ('Amphibia: Endgame', 6.06921, 0, 84, 'adventure')
# ('The Kingfish 2', 7.9, 11, 72, 'adventure')
# ('Sehnsucht nach Firdaws', 8.5, 6, 103, 'adventure')
# ('Jake Danger and the Sword of the Explorer', 6.06921, 0, 90, 'adventure')
# ('Summer on a solitary beach', 6.06921, 0, 100, 'adventure')
# ('Katarina, ili Doch razboynika', 6.06921, 0, 157, 'adventure')
# ('Isola degli sguardi', 6.06921, 0, 90, 'adventure')
# ('The Grand Stroke', 6.06921, 0, 128, 'adventure')
# ('Demibook', 6.06921, 0, 90, 'adventure')
# ('SITV Presents: Tabsentia', 6.06921, 0, 80, 'adventure')
# ('Vandringen', 6.06921, 0, 78, 'adventure')
# ('Anywhere Wherever', 6.06921, 0, 46, 'adventure')
# ('New Day', 6.06921, 0, 48, 'adventure')
# ('Les Nouveaux Candides', 6.06921, 0, 90, 'adventure')
# ('NJPW SMP: The Movie', 6.06921, 0, 50, 'adventure')
# ('Stunts I', 6.06921, 0, 90, 'adventure')
# ("Five Nights at TK's: The Curse of TK", 6.06921, 0, 60, 'adventure')
# ('My New Country Biacuimyneco', 6.06921, 0, 95, 'adventure')
# ('Geo Magazine', 6.06921, 0, 90, 'adventure')
# ('Son Though He Was: the Young Saint Francis of Assisi', 6.06921, 0, 90, 'adventure')
# ('Captain Toad and the Mystery Mine', 6.06921, 0, 77, 'adventure')
# ('My World 2', 6.06921, 0, 90, 'adventure')
# ('Tripping', 6.06921, 0, 90, 'adventure')
# ('The Final Kick', 6.06921, 0, 10, 'adventure')
# ('Once upon a bridge in Vietnam', 6.06921, 0, 52, 'adventure')
# ('7 Day Fast', 6.06921, 0, 50, 'adventure')
# ('The Redemption of Zack & Heather (Remastered)', 6.06921, 0, 90, 'adventure')
# ('I V Y: World of the Future', 6.06921, 0, 90, 'adventure')
# ('Across America', 6.06921, 0, 48, 'adventure')
# ('Kamilota', 6.06921, 0, 90, 'adventure')
# ('The multiverse arc', 6.06921, 0, 82, 'adventure')
# ('Boyz', 6.06921, 0, 132, 'adventure')
# ("TAÏ: 33 jours dans la dernière forêt d'Afrique de l'Ouest", 6.06921, 0, 90, 'adventure')
# ('Mouse Tales Movie 2', 6.06921, 0, 60, 'adventure')
# ('Sur les Chemins du Temps', 6.06921, 0, 90, 'adventure')
# ('Mystic Odyssey', 6.06921, 0, 144, 'adventure')
# ('Dream of Resurrection', 6.06921, 0, 95, 'adventure')
# ('Meorisogeul', 6.06921, 0, 119, 'adventure')
# ('Spin War', 6.06921, 0, 104, 'adventure')
# ('Exipsosi', 6.06921, 0, 90, 'adventure')
# ('Phantom Lights: UAPs of the Forest', 6.06921, 0, 81, 'adventure')
# ('The Wild Robot', 8.2, 175000, 102, 'animation')
# ('Mufasa: The Lion King', 6.6, 69000, 118, 'animation')
# ('Moana 2', 6.6, 107000, 100, 'animation')
# ('Flow', 7.9, 81000, 85, 'animation')
# ('Paddington in Peru', 6.7, 24000, 106, 'animation')
# ('Inside Out 2', 7.5, 220000, 96, 'animation')
# ('Transformers One', 7.6, 53000, 104, 'animation')
# ('Despicable Me 4', 6.2, 67000, 94, 'animation')
# ('IF', 6.4, 59000, 104, 'animation')
# ('The Day the Earth Blew Up: A Looney Tunes Movie', 7.0, 5100, 91, 'animation')
# ('The Lord of the Rings: The War of the Rohirrim', 6.3, 32000, 134, 'animation')
# ('Kung Fu Panda 4', 6.3, 70000, 94, 'animation')
# ('Memoir of a Snail', 7.8, 19000, 95, 'animation')
# ('Attack on Titan the Movie: The Last Attack', 9.2, 17000, 145, 'animation')
# ('The Garfield Movie', 5.7, 25000, 101, 'animation')
# ('Solo Leveling: ReAwakening', 8.8, 13000, 121, 'animation')
# ('Harold and the Purple Crayon', 5.7, 8700, 90, 'animation')
# ('Look Back', 7.8, 16000, 58, 'animation')
# ('Wallace & Gromit: Vengeance Most Fowl', 7.5, 36000, 82, 'animation')
# ('Spellbound', 5.5, 7700, 109, 'animation')
# ('Orion and the Dark', 6.3, 17000, 93, 'animation')
# ('Dan Da Dan: First Encounter', 8.2, 2800, 83, 'animation')
# ('Spermageddon', 5.6, 967, 80, 'animation')
# ('Watchmen: Chapter I', 7.1, 6900, 83, 'animation')
# ('The Remarkable Life of Ibelin', 8.2, 13000, 103, 'animation')
# ("Doraemon the Movie: Nobita's Earth Symphony", 6.6, 1600, 115, 'animation')
# ('Crayon Shin-chan: Our Dinosaur Diary', 6.6, 559, 106, 'animation')
# ('Justice League: Crisis on Infinite Earths - Part One', 6.2, 8700, 93, 'animation')
# ('The Most Precious of Cargoes', 7.1, 1300, 81, 'animation')
# ('Justice League: Crisis on Infinite Earths - Part Three', 6.1, 4700, 94, 'animation')
# ('Night of the Zoopocalypse', 6.0, 863, 91, 'animation')
# ('Megamind vs. The Doom Syndicate', 2.5, 5700, 83, 'animation')
# ('Piece by Piece', 6.9, 5800, 93, 'animation')
# ('That Christmas', 6.8, 17000, 91, 'animation')
# ('Haikyu!! The Dumpster Battle', 7.7, 6400, 85, 'animation')
# ('Justice League: Crisis on Infinite Earths - Part Two', 5.6, 5500, 94, 'animation')
# ('Demon Slayer: Kimetsu No Yaiba - To the Hashira Training', 7.2, 8700, 104, 'animation')
# ('Overlord: The Sacred Kingdom', 6.9, 1300, 135, 'animation')
# ('Thelma the Unicorn', 5.7, 3000, 93, 'animation')
# ('Watchmen: Chapter II', 7.1, 3300, 90, 'animation')
# ('The Colors Within', 7.1, 1100, 101, 'animation')
# ('Grand Theft Hamlet', 6.9, 2100, 89, 'animation')
# ('Ultraman: Rising', 6.9, 6500, 117, 'animation')
# ('Boys Go to Jupiter', 6.9, 108, 90, 'animation')
# ('White Snake: Afloat', 6.9, 534, 133, 'animation')
# ('The Glassworker', 7.3, 1900, 98, 'animation')
# ('Mars', 8.3, 23, 84, 'animation')
# ("My Hero Academia: You're Next", 7.0, 2500, 110, 'animation')
# ('Given 3: To the Sea', 7.9, 110, 80, 'animation')
# ('10 Lives', 5.9, 2000, 88, 'animation')
# ('Panda Bear in Africa', 5.5, 364, 84, 'animation')
# ('Hitpig', 5.1, 1000, 86, 'animation')
# ('Baki Hanma VS Kengan Ashura', 5.7, 2000, 62, 'animation')
# ('Mononoke the Movie: The Phantom in the Rain', 6.7, 1300, 89, 'animation')
# ('Blue Lock: Episode Nagi', 6.6, 2600, 91, 'animation')
# ('Dongeng Sang Kancil', 6.7, 207, 99, 'animation')
# ('Savages', 6.8, 377, 87, 'animation')
# ('Rebellious', 6.1, 226, 94, 'animation')
# ('Dragonkeeper', 5.7, 1800, 98, 'animation')
# ('Sabbath Queen', 8.0, 68, 105, 'animation')
# ('Diplodocus', 6.3, 193, 90, 'animation')
# ('Gracie and Pedro: Pets to the Rescue', 5.1, 283, 87, 'animation')
# ('Ghost Cat Anzu', 6.5, 844, 97, 'animation')
# ('Buffalo Kids', 6.6, 755, 93, 'animation')
# ('From Ground Zero', 7.9, 562, 112, 'animation')
# ('Dalia and the Red Book', 5.9, 140, 107, 'animation')
# ('Saving Bikini Bottom: The Sandy Cheeks Movie', 3.7, 4000, 82, 'animation')
# ('Johnny Puff: Secret Mission', 4.9, 458, 87, 'animation')
# ('I Am What I Am 2', 7.5, 260, 134, 'animation')
# ("The Tiger's Apprentice", 5.7, 2200, 84, 'animation')
# ('A Sloth Story', 5.6, 227, 90, 'animation')
# ('Detective Conan: The Million-Dollar Pentagram', 6.7, 1500, 111, 'animation')
# ('Woody Woodpecker Goes to Camp', 4.5, 2600, 100, 'animation')
# ('Limonov: The Ballad of Eddie', 5.9, 1000, 138, 'animation')
# ('Super-Charlie', 5.8, 156, 80, 'animation')
# ('200% Wolf', 5.9, 1300, 98, 'animation')
# ('Out of the Nest', 6.4, 119, 84, 'animation')
# ("Ryan's World the Movie: Titan Universe Adventure", 1.8, 713, 80, 'animation')
# ('The Night Before Christmas in Wonderland', 6.3, 527, 80, 'animation')
# ('Big City Greens the Movie: Spacecation', 6.2, 562, 83, 'animation')
# ('Frida', 7.5, 1500, 87, 'animation')
# ("Noah's Ark", 4.3, 687, 96, 'animation')
# ('Terra Incognita 1901', 5.4, 61, 78, 'animation')
# ("Re: Zero - Starting Life in Another World- Season 3 Episode 1 90-minute Special 'Theatrical Malice'", 8.7, 1200, 90, 'animation')
# ('No Time to Spy: A Loud House Movie', 6.3, 485, 81, 'animation')
# ('Dragon Ball Z Kai', 8.6, 79, 82, 'animation')
# ('The Proud Princess', 6.5, 133, 84, 'animation')
# ('My Oni Girl', 6.0, 1800, 112, 'animation')
# ('Norbert', 6.7, 15, 75, 'animation')
# ('Mochi-chon', 8.2, 10, 0, 'animation')
# ('Boonie Bears: Time Twist', 6.0, 174, 105, 'animation')
# ('My Freaky Family', 6.3, 419, 86, 'animation')
# ('Mobile Suit Gundam SEED Freedom', 6.6, 975, 124, 'animation')
# ('Niko: Beyond the Northern Lights', 6.2, 351, 86, 'animation')
# ("Peppa's Cinema Party", 4.9, 155, 65, 'animation')
# ('The Casagrandes Movie', 5.6, 687, 89, 'animation')
# ('Movie Given Hiiragi Mix.', 7.6, 213, 70, 'animation')
# ('Little Emma', 5.4, 129, 106, 'animation')
# ('The Lost Tiger', 7.9, 50, 90, 'animation')
# ('Storm Crashers', 6.2, 571, 88, 'animation')
# ('Monkey King: The Beginning', 9.6, 6, 0, 'animation')
# ('Living Large', 7.0, 154, 80, 'animation')
# ('Rafadan Tayfa: Kapadokya', 6.6, 129, 84, 'animation')
# ('The Quintessential Quintuplets Specials 2', 6.9, 147, 46, 'animation')
# ("Peppa Pig: Peppa's Adventures Around the World", 8.0, 7, 0, 'animation')
# ('Uma & Haggen: Mitos', 7.4, 53, 94, 'animation')
# ('The Big Trip 3: Race Around the World', 5.7, 66, 85, 'animation')
# ('Mariposas Negras', 7.2, 67, 83, 'animation')
# ('Fox & Hare Save the Forest', 5.9, 213, 71, 'animation')
# ('Nintama Rantaro Dokutake Ninja-tai Saikyou no Gunshi', 7.2, 32, 90, 'animation')
# ('Isla Monstro', 7.8, 10, 0, 'animation')
# ('Elli and the Ghostly Ghost Train', 5.0, 108, 86, 'animation')
# ('Die Heinzels: Neue Mützen, Neue Mission', 6.4, 102, 76, 'animation')
# ('Shrek 5: The Contract - A Fan Made Film', 7.2, 21, 84, 'animation')
# ('Appu', 8.5, 186, 92, 'animation')
# ('Into the Mortal World', 6.8, 171, 118, 'animation')
# ('Kid Santa', 6.62577, 0, 78, 'animation')
# ('Uma Musume: Pretty Derby - Beginning of a New Era', 7.4, 145, 108, 'animation')
# ('Angelo dans la forêt mystérieuse', 6.0, 129, 81, 'animation')
# ('Sanatorium Under the Sign of the Hourglass', 5.4, 128, 75, 'animation')
# ('Trapezium', 6.2, 164, 95, 'animation')
# ('Bocchi the Rock! Recap Part 1', 7.5, 192, 90, 'animation')
# ('Bloody Escape: Bats out of Hell', 5.5, 57, 100, 'animation')
# ('Ya Boy Kongming! Road to Summer Sonia', 7.4, 40, 119, 'animation')
# ("Dead Dead Demon's Dededede Destruction", 7.1, 148, 120, 'animation')
# ('(S)KiDS', 8.6, 112, 85, 'animation')
# ('Kizumonogatari: Koyomi Vamp', 7.1, 102, 144, 'animation')
# ('Cille 2069', 7.1, 96, 0, 'animation')
# ('Exorcism Chronicles: The Beginning', 6.4, 123, 85, 'animation')
# ('Heartsping : Teenieping of Love', 7.1, 26, 0, 'animation')
# ('My Redneck Neighbor: Chapter 2 - Let the Games Begin', 6.6, 9, 55, 'animation')
# ("Transformers Prime: Galavatron's Revenge", 4.3, 14, 104, 'animation')
# ('Where the Robots Grow', 2.7, 523, 0, 'animation')
# ('Maya, donne-moi un titre', 6.4, 60, 61, 'animation')
# ('Inanimate Insanity II: The Movie', 8.3, 239, 106, 'animation')
# ('The Formula for Water', 4.6, 37, 86, 'animation')
# ('Kvitebjørn', 5.9, 74, 85, 'animation')
# ('Maxxie LaWow: Drag Super-shero', 8.7, 64, 114, 'animation')
# ('A Few Moments of Cheers', 7.2, 50, 68, 'animation')
# ('Fureru', 6.3, 38, 107, 'animation')
# ('Ivan Tsarevich i Seryy Volk 6', 5.7, 97, 85, 'animation')
# ('Rock Bottom', 6.4, 52, 86, 'animation')
# ('Bocchi the Rock! Recap Part 2', 7.4, 130, 77, 'animation')
# ('SuperKlaus', 4.3, 204, 88, 'animation')
# ('Zak & Wowo: The Legend of Lendarys', 5.7, 103, 85, 'animation')
# ('Tobias and the Arcane Merchant', 9.0, 45, 167, 'animation')
# ('Luntik. Vozvrashchenie domoy', 6.3, 79, 0, 'animation')
# ("Le parfum d'Irak", 8.0, 47, 95, 'animation')
# ('Taisu Xilie', 6.62577, 0, 100, 'animation')
# ('Schirkoa: In Lies We Trust', 5.6, 162, 103, 'animation')
# ('The Storm', 6.0, 144, 102, 'animation')
# ('Woolina and the No Birds', 8.1, 50, 80, 'animation')
# ('Si Juki the Movie: Harta Pulau Monyet', 6.0, 127, 107, 'animation')
# ('STEVE (A Minecraft Movie)', 6.9, 12, 61, 'animation')
# ('God with Three Eyes', 5.7, 23, 112, 'animation')
# ('Fuuto PI: Portrait of Kamen Rider Skull', 7.5, 48, 82, 'animation')
# ('Jon Vardar protiv Galaksijata', 8.2, 77, 86, 'animation')
# ('TWST: Things We Said Today', 7.0, 62, 86, 'animation')
# ('Ganbatte Ikimasshoi', 5.2, 13, 95, 'animation')
# ('Hola Frida', 7.2, 35, 82, 'animation')
# ('Tay 2: Ebabil Takimi', 5.0, 44, 78, 'animation')
# ('Code Geass: Rozé of the Recapture - Part 1', 7.6, 42, 74, 'animation')
# ("DreadClub: Vampire's Verdict", 4.9, 62, 0, 'animation')
# ('PAPmusic - Animation for Fashion', 1.0, 163, 85, 'animation')
# ('Masha i Medved v kino: Park chudes', 7.4, 18, 58, 'animation')
# ('Double Tuckerr', 4.9, 1200, 120, 'animation')
# ('Robotia, the Movie', 7.6, 31, 86, 'animation')
# ('Kral Sakir: Devler Uyandi', 5.3, 69, 0, 'animation')
# ('Askepote', 3.5, 84, 72, 'animation')
# ("Yumi's Cells: The Movie", 6.2, 53, 93, 'animation')
# ('Quo Vadis', 6.4, 514, 90, 'animation')
# ("Dead Dead Demon's Dededede Destruction Zenpen", 7.1, 142, 120, 'animation')
# ('Mustafa', 6.9, 76, 75, 'animation')
# ('Bob a Bobek ve filmu: Na stope Mrkvojeda', 7.2, 32, 80, 'animation')
# ('The Summer of Mermaid', 7.9, 108, 0, 'animation')
# ('The Worlds Divide', 7.9, 40, 120, 'animation')
# ('Steal the Naughty List', 6.3, 126, 90, 'animation')
# ('Silex and the City, le film', 5.0, 52, 77, 'animation')
# ('Slocum et moi', 7.3, 77, 75, 'animation')
# ('Lilla spöket Laban spökar igen', 6.1, 29, 44, 'animation')
# ('Hello My Beautiful Creatures', 6.8, 173, 142, 'animation')
# ('Astra', 6.8, 8, 80, 'animation')
# ('Life with Quincy 3', 6.62577, 0, 73, 'animation')
# ('Captain Avispa', 5.7, 180, 96, 'animation')
# ('Olivia & the Clouds', 7.3, 56, 81, 'animation')
# ("Nature Cat's Nature Movie Special Extraordinaire", 7.3, 19, 53, 'animation')
# ('Rocket Club: Across the Cosmos', 8.4, 19, 68, 'animation')
# ('Balentes', 6.62577, 0, 70, 'animation')
# ('Rocky and Bullwinkle', 9.2, 15, 100, 'animation')
# ('Apocalypse Love', 6.4, 5, 0, 'animation')
# ('Return', 6.62577, 0, 90, 'animation')
# ('Pui Pui Molcar the Movie: Molmax', 7.0, 9, 69, 'animation')
# ('Tri kota. Zimnie kanikuly', 6.6, 35, 65, 'animation')
# ('The Cheshire Cat', 6.62577, 0, 64, 'animation')
# ('Benjamin Bat', 7.8, 33, 75, 'animation')
# ("Teacher's Pet", 5.4, 36, 0, 'animation')
# ('Motu Patlu & The Race to the Diamond Valley', 7.8, 28, 72, 'animation')
# ('Tri bogatyrya. Ni dnya bez podviga', 5.7, 71, 61, 'animation')
# ('The Fifth Element', 6.62577, 0, 78, 'animation')
# ('Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik', 7.4, 75, 70, 'animation')
# ('Il segreto di Liberato', 7.3, 227, 90, 'animation')
# ('Love Live! Nijigasaki High School Idol Club Final Chapter Part 1', 7.4, 15, 59, 'animation')
# ('Inazuma Eleven Movie: The Legendary Kickoff', 8.3, 7, 0, 'animation')
# ('Transformers: 40th Anniversary Event', 7.4, 30, 96, 'animation')
# ('Becho', 7.2, 10, 0, 'animation')
# ('Riki Rhino: The Bird Kingdom', 5.1, 25, 109, 'animation')
# ('Dikkie Dik en de Verdwenen Knuffel', 7.3, 131, 62, 'animation')
# ('The Greatest Surf Movie in the Universe', 4.7, 9, 81, 'animation')
# ('Wonderful Precure! The Movie! Doki Doki Game no Sekai de Daiboken', 6.8, 36, 71, 'animation')
# ("Penelope & Everly's Holiday Adventure", 6.62577, 0, 78, 'animation')
# ("Alex and Mia's Awesome Movie!!", 6.62577, 0, 75, 'animation')
# ('Spider-Man: Blue', 5.8, 12, 0, 'animation')
# ('Kuramerukagari', 5.8, 84, 61, 'animation')
# ('Nie Xiaoqian', 6.2, 18, 112, 'animation')
# ('The Umbrella Fairy', 5.7, 61, 95, 'animation')
# ('Dinosaur Empire', 6.62577, 0, 78, 'animation')
# ('Mobile Suit Gundam: Silver Phantom', 6.1, 13, 90, 'animation')
# ('Bread Barbershop: Celeb in Bakery Town', 6.62577, 0, 77, 'animation')
# ('Pikmin Forever', 6.62577, 0, 78, 'animation')
# ('Love and Friendship', 6.62577, 0, 57, 'animation')
# ('Code Geass: Rozé of the Recapture: Part 2', 7.8, 28, 76, 'animation')
# ('Pleasant Goat and Big Big Wolf: The World Guardians', 6.6, 16, 96, 'animation')
# ('Adventures of Mickey Sherlock Mouse & Winnie the Pooh', 4.9, 12, 0, 'animation')
# ('Dinonauts', 6.62577, 0, 77, 'animation')
# ('Motu Patlu & The Rise of Zombies', 6.6, 15, 74, 'animation')
# ('Max Beyond', 6.6, 18, 93, 'animation')
# ('Treasure Fellowship', 6.62577, 0, 86, 'animation')
# ('Meitantei Conan Bâsasu Kaitô Kiddo', 6.1, 169, 81, 'animation')
# ('Arne Alligator och djungelkompisarna', 4.6, 49, 61, 'animation')
# ('Zuzubalândia: O Filme', 5.4, 11, 60, 'animation')
# ('Jin Ling Yu Mao', 7.8, 6, 97, 'animation')
# ('Shed 17 & Project G-1 the Movie', 6.62577, 0, 85, 'animation')
# ('Rhythm of a Flower', 7.4, 15, 81, 'animation')
# ('Piril: Sayilarin Gizemi', 9.0, 67, 0, 'animation')
# ('Gintama the Movie 2D: Courtesan of the Nation Arc', 8.0, 9, 109, 'animation')
# ('Luv You Shankar', 5.8, 44, 120, 'animation')
# ("Marvel's Civil War Full Comic Dub Movie", 6.62577, 0, 75, 'animation')
# ('Bigfoot in Wonderland', 6.62577, 0, 61, 'animation')
# ('Code Geass: Rozé of the Recapture: Part 4', 6.6, 15, 70, 'animation')
# ('The Ballad of Straw Hat Sam', 9.1, 10, 45, 'animation')
# ('Cacophony the Animated Movie', 6.62577, 0, 81, 'animation')
# ('The Puffins & the Magic Portal', 7.7, 32, 0, 'animation')
# ('King of Prism: Dramatic Prism 1', 6.62577, 0, 60, 'animation')
# ("Bartali's Bicycle", 7.5, 8, 80, 'animation')
# ('Code Geass: Rozé of the Recapture: Part 3', 7.4, 25, 76, 'animation')
# ('Kittened', 6.62577, 0, 78, 'animation')
# ('Rabbits Kingdom the Movie', 6.62577, 0, 94, 'animation')
# ('The Barkers Pursuit of Adventure', 6.62577, 0, 78, 'animation')
# ('Velký Pán', 7.0, 9, 73, 'animation')
# ('Eiga Oshiri Tantei Saraba Itoshiki Aibô (Oshiri) yo', 6.62577, 0, 71, 'animation')
# ('Bogyó és Babóca 6. - Csengettyuk', 7.8, 13, 0, 'animation')
# ('The Car Acrobatic Team Saga', 7.2, 11, 112, 'animation')
# ('Robo Puffin', 6.62577, 0, 78, 'animation')
# ("Dante's Divine Comedy", 6.62577, 0, 78, 'animation')
# ('Gujeyeog-eseo sal-a dol-aon dwaeji', 4.8, 12, 105, 'animation')
# ('Daughters of Monster Magnet', 6.62577, 0, 46, 'animation')
# ('Dance with the Finless Promise', 6.3, 20, 0, 'animation')
# ('Animal Adventures: Save the Forest', 7.7, 34, 85, 'animation')
# ('Ugly Sweater', 7.1, 13, 80, 'animation')
# ('Bizarros Peixes das Fossas Abissais', 8.0, 14, 75, 'animation')
# ('Skazochnyy patrul. Shou prodolzhayetsya', 7.2, 11, 65, 'animation')
# ('Hey, Tete', 6.4, 9, 151, 'animation')
# ('Nefertiti the Queen of Hearts', 6.62577, 0, 89, 'animation')
# ('The Delegator', 4.1, 17, 96, 'animation')
# ('La Familia del Barrio: La Película', 4.5, 7, 0, 'animation')
# ('Sunburnt Unicorn', 7.7, 13, 81, 'animation')
# ('Be Forever Yamato: Rebel 3199: Part 1: Dark Invasion', 7.0, 9, 50, 'animation')
# ('COPS VS WHORES', 6.62577, 0, 57, 'animation')
# ('Ekip: Siberay - Günes Firtinasi', 6.0, 14, 72, 'animation')
# ('Memory Hotel', 6.62577, 0, 100, 'animation')
# ('Kaptan Pengu ve Arkadaslari 4: Buzuldaki Sir', 5.3, 13, 0, 'animation')
# ("Ramayan the Hero's Path", 6.62577, 0, 78, 'animation')
# ('Happy Little Submarine: 80 Days Around the Earth', 6.62577, 0, 80, 'animation')
# ('The Halloween Shark', 6.62577, 0, 69, 'animation')
# ('Boundearth', 6.62577, 0, 108, 'animation')
# ...
# ('Freedom Shred: A Juneteenth Declaration', 6.77181, 0, 55, 'history')
# ('Christian Growth Through Hymns', 6.77181, 0, 50, 'history')
# ('Ritter, Burgen, Edelfrauen - Liebessagen aus dem Mittelalter', 6.77181, 0, 91, 'history')
# ('¿De qué casa eres?', 6.77181, 0, 72, 'history')
# ('Istanbul: Isgal ve Zafer', 6.77181, 0, 54, 'history')
# ('Tesouro Natterer', 6.77181, 0, 84, 'history')
# ('Un paese ci vuole', 6.77181, 0, 91, 'history')
# ('Castles in Haiti', 6.77181, 0, 91, 'history')
# ('Fast Track: Taking on the Speedway', 9.4, 9, 35, 'history')
# ('Vola Colomba - Trieste 1954', 6.77181, 0, 52, 'history')
# ('Manuscripts', 6.77181, 0, 54, 'history')
# ('Vernye', 6.77181, 0, 70, 'history')
# ('Oda: Vlucht door de Eeuwen', 6.4, 7, 0, 'history')
# ('Song of the Last Lacandon Holy Man', 6.77181, 0, 67, 'history')
# ('Maverick from the Edge', 6.77181, 0, 107, 'history')
# ('A Cowardly Rout: The Bull Run Account of William Howard Russell', 6.77181, 0, 18, 'history')
# ('2053 - A Best Case Scenario', 6.77181, 0, 58, 'history')
# ('Cintas, Fotocopias y Sellos Trucados', 6.77181, 0, 108, 'history')
# ('Svjedoci pravde - Ratni zlocini u Bosanskom Novom', 6.77181, 0, 91, 'history')
# ('Max Corvo for Freedom the Secret War of Oss in Italy 1943-1945', 6.77181, 0, 91, 'history')
# ('Triumf', 7.3, 9, 113, 'history')
# ('Ukku Satyagraham', 6.77181, 0, 139, 'history')
# ('Ek Chilte Jol', 9.2, 13, 119, 'history')
# ("C'era una volta il Derby Club", 7.4, 17, 90, 'history')
# ('The Canal Map of Britain', 6.8, 10, 59, 'history')
# ('Krigsvarsleren', 7.8, 8, 55, 'history')
# ('O Último Papagaio de Timneh', 6.77181, 0, 49, 'history')
# ('Zle smierci', 6.77181, 0, 91, 'history')
# ('Testimoni del tempo', 6.77181, 0, 91, 'history')
# ('Sivestan', 6.77181, 0, 91, 'history')
# ('The Way of Internal Strength', 6.77181, 0, 45, 'history')
# ('Al Kafi', 6.77181, 0, 110, 'history')
# ('Zhambyl: New Era', 6.77181, 0, 92, 'history')
# ('Nerah Documaentary Film', 6.77181, 0, 91, 'history')
# ('Testimoni del tempo', 6.77181, 0, 91, 'history')
# ('Area 2', 6.77181, 0, 91, 'history')
# ('The Coastal Map of Britain', 6.77181, 0, 60, 'history')
# ('Um Tempo de Todos', 6.77181, 0, 132, 'history')
# ('Okufere', 6.77181, 0, 91, 'history')
# ('Kabarettistinnen in der Weimarer Republik und im Dritten Reich', 6.77181, 0, 90, 'history')
# ('Nancy & Bill: The Story Before Oliver Twist', 6.77181, 0, 91, 'history')
# ('International Resonance of the April Uprising', 6.77181, 0, 51, 'history')
# ('Drachten Journaals', 6.77181, 0, 51, 'history')
# ('Twin Falls, 2001-2024', 6.77181, 0, 180, 'history')
# ('Tatai Patara 1597', 6.77181, 0, 70, 'history')
# ('On Air', 6.77181, 0, 91, 'history')
# ('The Storm', 6.77181, 0, 165, 'history')
# ("Le Temple d'Hatchepsout, Reine d'Egypte", 6.77181, 0, 91, 'history')
# ('Andrew Trimble: For Ulster & Ireland', 6.77181, 0, 91, 'history')
# ('Challengers', 7.0, 158000, 131, 'sport')
# ('Queen of the Ring', 6.4, 1900, 129, 'sport')
# ('The Fire Inside', 6.7, 2900, 109, 'sport')
# ('Arthur the King', 7.0, 35000, 107, 'sport')
# ('Under Paris', 5.2, 37000, 104, 'sport')
# ('Young Woman and the Sea', 7.5, 17000, 129, 'sport')
# ('Unstoppable', 6.8, 4400, 116, 'sport')
# ('Kill the Jockey', 6.4, 1800, 96, 'sport')
# ('You Gotta Believe', 5.8, 1400, 104, 'sport')
# ('Chandu Champion', 7.8, 34000, 142, 'sport')
# ('The Beautiful Game', 6.3, 8200, 125, 'sport')
# ('Haikyu!! The Dumpster Battle', 7.7, 6400, 85, 'sport')
# ('Uranus 2324', 6.4, 4900, 130, 'sport')
# ('Rez Ball', 6.3, 2600, 111, 'sport')
# ('Maidaan', 7.9, 23000, 181, 'sport')
# ('Race for Glory: Audi vs. Lancia', 5.8, 4900, 109, 'sport')
# ('Lubber Pandhu', 8.1, 6200, 146, 'sport')
# ('The Underdoggs', 5.6, 4600, 96, 'sport')
# ('Yolo', 6.9, 3800, 129, 'sport')
# ('Sweet Dreams', 5.4, 1500, 95, 'sport')
# ('Gundi: Legend of Love', 9.0, 5600, 166, 'sport')
# ('Baki Hanma VS Kengan Ashura', 5.7, 2000, 62, 'sport')
# ('Blue Lock: Episode Nagi', 6.6, 2600, 91, 'sport')
# ('Sixty Minutes', 5.7, 5200, 88, 'sport')
# ('The Swedish Torpedo', 6.3, 192, 120, 'sport')
# ('Diving Into the Darkness', 9.1, 84, 96, 'sport')
# ('My Sunshine', 7.0, 1400, 100, 'sport')
# ('Cup', 8.6, 82, 146, 'sport')
# ('Hayatla Baris', 6.3, 391, 125, 'sport')
# ('El Harifa 2: El Remontada', 6.4, 466, 130, 'sport')
# ('Boxer', 6.4, 1400, 150, 'sport')
# ('Mond', 7.0, 296, 92, 'sport')
# ('Bionic', 4.3, 1700, 110, 'sport')
# ('Little Wing', 6.1, 947, 100, 'sport')
# ('Mr. & Mrs. Mahi', 5.9, 16000, 139, 'sport')
# ('Vijay 69', 6.1, 1200, 112, 'sport')
# ('Balestra', 5.1, 538, 145, 'sport')
# ('Federer: Twelve Final Days', 7.3, 4200, 88, 'sport')
# ('Giannis: The Marvelous Journey', 8.3, 1800, 109, 'sport')
# ('Crakk: Jeetega... Toh Jiyegaa', 4.7, 6500, 154, 'sport')
# ('Samia', 6.8, 151, 102, 'sport')
# ('Havnaa', 7.1, 277, 110, 'sport')
# ('Color of Victory', 6.1, 40000, 157, 'sport')
# ('My Annoying Brother', 7.4, 274, 114, 'sport')
# ('Alpha.', 6.9, 256, 100, 'sport')
# ('The Champion', 5.5, 905, 106, 'sport')
# ('Untold: The Murder of Air McNair', 5.6, 2100, 57, 'sport')
# ('The Final: Attack on Wembley', 6.3, 2500, 82, 'sport')
# ('Lal Salaam', 4.4, 1300, 150, 'sport')
# ('El Hareefa', 6.8, 1100, 117, 'sport')
# ('Free Falling', 5.2, 300, 89, 'sport')
# ('Wingless', 7.3, 186, 110, 'sport')
# ('Uma Musume: Pretty Derby - Beginning of a New Era', 7.4, 145, 108, 'sport')
# ('Las super estrellas de la lucha libre', 8.8, 55, 98, 'sport')
# ('Concussed: The American Dream', 7.8, 43, 0, 'sport')
# ('Ski', 7.7, 70, 95, 'sport')
# ('The Miranda Brothers', 4.4, 191, 99, 'sport')
# ('Blue Star', 6.9, 1600, 166, 'sport')
# ('Memes & Nightmares', 5.7, 90, 81, 'sport')
# ('Nasty', 7.7, 1100, 103, 'sport')
# ('Off the Line', 8.6, 17, 0, 'sport')
# ('Pegasus 2', 6.9, 1300, 121, 'sport')
# ('Minor Leaguer', 5.1, 93, 77, 'sport')
# ('Champions of the Golden Valley', 9.2, 76, 81, 'sport')
# ('First Class: Full Speed!', 7.0, 334, 0, 'sport')
# ('Sunshine', 7.3, 64, 91, 'sport')
# ('Swamiji Club', 6.89157, 0, 88, 'sport')
# ('Grace by Night', 7.1, 25, 0, 'sport')
# ('Undisputed', 6.8, 106, 64, 'sport')
# ('Return to the Ring', 5.4, 733, 106, 'sport')
# ('The Tale of Texas Pool', 7.8, 79, 0, 'sport')
# ('Kulej. Dwie strony medalu', 6.4, 337, 148, 'sport')
# ('Pierce', 6.5, 144, 109, 'sport')
# ('Keluar Main 1994', 7.8, 55, 112, 'sport')
# ('Topuria Matador', 7.2, 168, 95, 'sport')
# ('4 Zéros', 3.6, 150, 105, 'sport')
# ('Friendly Fire', 5.3, 65, 105, 'sport')
# ('Nayab', 7.4, 269, 153, 'sport')
# ('GG (Good Game)', 5.9, 80, 100, 'sport')
# ('EFC', 7.7, 1200, 87, 'sport')
# ('Pay Dirt: The Story of Supercross', 6.89157, 0, 91, 'sport')
# ('Fuchsia Libre', 4.9, 60, 112, 'sport')
# ('Fight Like a Girl', 8.2, 19, 118, 'sport')
# ('Unbreakable: England 2003', 8.1, 38, 66, 'sport')
# ('Gold', 7.7, 75, 126, 'sport')
# ('Anytime', 8.9, 25, 62, 'sport')
# ('Challenger', 5.6, 179, 95, 'sport')
# ('Lyod 3', 6.0, 311, 134, 'sport')
# ('Final Heat', 3.8, 214, 83, 'sport')
# ('Knock Out Blonde: The Kellie Maloney Story', 6.0, 23, 90, 'sport')
# ('Padu', 5.1, 81, 97, 'sport')
# ("It's All Over: The Kiss That Changed Spanish Football", 6.9, 639, 95, 'sport')
# ('Game Changers', 4.7, 232, 78, 'sport')
# ('Dabaru', 8.9, 651, 131, 'sport')
# ('Numéro 10', 5.3, 51, 91, 'sport')
# ('I am Al Ittihad', 4.9, 230, 90, 'sport')
# ('Home Plate', 6.89157, 0, 85, 'sport')
# ('Salty Amazons', 6.89157, 0, 32, 'sport')
# ('A Horse Named Winx', 8.7, 99, 117, 'sport')
# ('Runaway Wrestler', 7.6, 16, 105, 'sport')
# ('See Her Be Her', 7.1, 27, 110, 'sport')
# ('Inazuma Eleven Movie: The Legendary Kickoff', 8.3, 7, 0, 'sport')
# ('Harimau Malaya: The Untold Journey', 8.2, 23, 125, 'sport')
# ("Argentina '78", 7.1, 209, 0, 'sport')
# ('Daley', 7.8, 180, 102, 'sport')
# ('Ice Aged', 7.0, 8, 110, 'sport')
# ('La valanga azzurra', 7.6, 11, 90, 'sport')
# ('Loser is Winner', 8.1, 554, 0, 'sport')
# ('The Unbreakable Tatiana Suarez', 6.6, 171, 78, 'sport')
# ('Tracing the Divide', 8.8, 173, 84, 'sport')
# ('Patang', 6.89157, 0, 88, 'sport')
# ('Nos Amours: The Saga of the Montreal Expos', 6.2, 23, 92, 'sport')
# ('V de Victor', 5.2, 77, 100, 'sport')
# ('In Inima Nationalei', 7.8, 200, 103, 'sport')
# ('All American', 9.6, 18, 87, 'sport')
# ('Clash of Dynasties: St. Edward vs Walsh Jesuit', 6.89157, 0, 88, 'sport')
# ('Puffing Iron', 7.5, 20, 98, 'sport')
# ('Linford', 7.3, 149, 89, 'sport')
# ('Parviz Khan', 5.9, 216, 110, 'sport')
# ('Dolly: Story of a Warrior', 6.89157, 0, 88, 'sport')
# ('Graciano Rocchigiani - Das Herz eines Boxers', 9.2, 51, 123, 'sport')
# ('The Spoils: Selling the Future of American Basketball', 6.8, 7, 87, 'sport')
# ('Gabru Gang', 8.7, 214, 123, 'sport')
# ('DitO', 4.4, 23, 117, 'sport')
# ('The Streak', 6.89157, 0, 87, 'sport')
# ('Together: 4-in-a-Row', 6.4, 68, 92, 'sport')
# ('Il tempo è ancora nostro', 6.89157, 0, 88, 'sport')
# ('Below the Rim', 5.0, 16, 89, 'sport')
# ('Trailblazers', 6.4, 18, 38, 'sport')
# ('1600 Meter', 6.89157, 0, 106, 'sport')
# ('Hatching Eagles', 6.9, 23, 63, 'sport')
# ("UFC 299: O'Malley vs. Vera 2", 7.4, 83, 180, 'sport')
# ("Bartali's Bicycle", 7.5, 8, 80, 'sport')
# ('Qajymuqan', 4.8, 5, 0, 'sport')
# ('Take the Steps', 8.3, 74, 83, 'sport')
# ('The Netflix Slam', 7.2, 147, 150, 'sport')
# ('Volare più in alto', 6.89157, 0, 51, 'sport')
# ('Fedya. Narodnyy futbolist', 6.0, 130, 125, 'sport')
# ('Battle of the Baddest', 6.1, 94, 61, 'sport')
# ('Deathgrip 2', 6.89157, 0, 59, 'sport')
# ('Giroud', 6.4, 25, 80, 'sport')
# ('Fútbol desde el corazón', 6.89157, 0, 90, 'sport')
# ('Rafa Márquez: El Capitán', 6.6, 199, 82, 'sport')
# ('For the Love of Basketball', 6.89157, 0, 88, 'sport')
# ('Grudge', 6.89157, 0, 104, 'sport')
# ('Ping pang nan hai', 7.1, 19, 108, 'sport')
# ('Ice Cross: Life on the Edge', 8.5, 16, 90, 'sport')
# ('Hai, Romania!', 8.1, 426, 98, 'sport')
# ('Welcome to the J-Rod Show', 6.89157, 0, 44, 'sport')
# ('Khapsyhyy', 5.4, 7, 90, 'sport')
# ('V potoke trekh stikhiy', 5.2, 42, 85, 'sport')
# ('Top Rider', 6.89157, 0, 84, 'sport')
# ('Rylan: Homophobia, Football & Me', 5.5, 24, 0, 'sport')
# ('Beta Squad vs AMP Charity Match 2024', 6.89157, 0, 210, 'sport')
# ('Quote 10.35', 8.0, 24, 35, 'sport')
# ('Traineras, pasión por el remo', 6.0, 7, 0, 'sport')
# ('Nema ne mogu', 6.89157, 0, 54, 'sport')
# ('Gyakorlat teszi a mestert', 6.1, 15, 46, 'sport')
# ('Eclipse', 9.4, 84, 79, 'sport')
# ('Roman Kostomarov. Rozhdennyy dvazhdy', 6.89157, 0, 77, 'sport')
# ('Passion of Iron', 9.3, 18, 0, 'sport')
# ('The Incredibles', 9.3, 116, 0, 'sport')
# ('Basketball Jones: The First Chapter', 6.89157, 0, 88, 'sport')
# ('A Game of Two Halves', 7.3, 24, 100, 'sport')
# ('87 Candles', 9.0, 10, 55, 'sport')
# ('Beyond the Podium: Celebrating Canadian Women Champions', 6.89157, 0, 88, 'sport')
# ('Big Water Theory', 6.89157, 0, 83, 'sport')
# ('Vincenzo Nibali - Il 7° campione', 6.89157, 0, 52, 'sport')
# ('Surf on, Europe!', 7.5, 25, 92, 'sport')
# ('Rhythm Masters: A Mickey Hart Experience', 7.3, 23, 0, 'sport')
# ('Welcome Back', 7.4, 5, 119, 'sport')
# ('UFC 303: Pereira vs. Prochazka 2', 6.4, 71, 195, 'sport')
# ('¡Qué suerte hemos tenido!', 7.5, 16, 62, 'sport')
# ('EL DESAFÍO IMPOSIBLE: LA CUMBRE DE LOS 7000 METROS', 6.89157, 0, 88, 'sport')
# ('Episodes: Ukraine at the World Cup (2024)', 8.1, 72, 79, 'sport')
# ('Veljko od mora', 7.2, 16, 53, 'sport')
# ('Senza volto - Storia di Fabrizio Maiello', 6.89157, 0, 99, 'sport')
# ('The Next Centimeter', 7.5, 35, 26, 'sport')
